# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/ch4_scores400.csv')
scores = np.array(df['score'])
scores[:10]
# Out:
# array([76, 55, 80, 80, 74, 61, 81, 76, 23, 80], dtype=int64)

# %%
np.random.choice([1,2,3],3) ## 복원추출 / replace=True(복원추출)
# Out:
# array([2, 2, 1])

# %%
np.random.choice([1,2,3],3, replace=False) ## replace=False(비복원추출)
# Out:
# array([3, 2, 1])

# %%
## 시드를 0으로 하는 무작위 추출은 매번 동일한 결과 / 시드값을 고정하면 해당 추출값도 고정
np.random.seed(1)
np.random.choice([1,2,3],3)
# Out:
# array([2, 1, 1])

# %%
# np.random.seed(0)
sample = np.random.choice(scores, 20)
sample.mean()
# Out:
# 72.7

# %%
scores.mean()
# Out:
# 69.53

# %%
for i in range(5):
    sample = np.random.choice(scores, 20)
    print(f"{i+1}번째 무작위 추출로 얻은 표본평균", sample.mean())
# Out:
# 1번째 무작위 추출로 얻은 표본평균 71.45
# 2번째 무작위 추출로 얻은 표본평균 70.5
# 3번째 무작위 추출로 얻은 표본평균 67.75
# 4번째 무작위 추출로 얻은 표본평균 74.85
# 5번째 무작위 추출로 얻은 표본평균 77.25

# %%
dice = [1,2,3,4,5,6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %%
num_trial = 100000
sample = np.random.choice(dice, num_trial, p=prob)
sample
# Out:
# array([6, 6, 6, ..., 6, 6, 5])

# %%
freq, _ = np.histogram(sample, bins=6, range=(1,7))

# %%
pd.DataFrame({'frequency':freq,
              'relative frequency':freq/num_trial},
             index = pd.Index(np.arange(1, 7),
                              name='dice'))
# Out:
#       frequency  relative frequency
# dice
# 1          4710             0.04710
# 2          9655             0.09655
# 3         14258             0.14258
# 4         19026             0.19026
# 5         23728             0.23728
# 6         28623             0.28623

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1,7), density=True, rwidth=0.8)
ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray') ## hlines 수평으로 선을 그음 / vlines 수직으로 선을 그음
ax.set_xticks(np.linspace(1.5, 6.5, 6))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(scores, bins=100, range=(0, 100),density=True)
ax.set_xlim(20, 100)
ax.set_ylim(0, 0.042)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
np.random.choice(scores)
# Out:
# 90

# %%
sample = np.random.choice(scores, 100000)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=100, range=(0, 100), density=True)
ax.set_xlim(20, 100)
ax.set_ylim(0, 0.042)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
sample_means = [ np.random.choice(scores, 20).mean() for _ in range(100000)]
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample_means, bins=100, range=(0, 100), density=True)
ax.set_xlim(50, 90)
ax.set_ylim(0, 0.13)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()
