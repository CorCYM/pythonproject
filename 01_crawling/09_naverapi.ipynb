# %%
Client_ID = 'uBUu4FjdSESn5naeFWZ_'
Client_Secret = 'TofNzWmeuU'

# %%
# 네이버 검색 API 예제 - 블로그 검색

import urllib.request
import json

client_id = "uBUu4FjdSESn5naeFWZ_"
client_secret = "TofNzWmeuU"
query = input('검색할 단어>>')
encText = urllib.parse.quote(query)
print(encText)

# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
url = "https://openapi.naver.com/v1/search/blog?display=100&query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
data = response_body.decode('utf-8')
print(type(data))
# Out:
# 검색할 단어>> 여름
# %EC%97%AC%EB%A6%84
# {
# 	"lastBuildDate":"Sun, 23 Apr 2023 20:14:02 +0900",
# 	"total":35118614,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"안산에어컨청소 <b>여름<\/b>대비 살균세척",
# 			"link":"https:\/\/blog.naver.com\/chezleecody\/223078906426",
# 			"description":"<b>여름<\/b>이 오기전에 에어컨 청소를 해야할것 같아서 업체 불러서 작업을 맡겼어요. 신우토탈케어8호점... 하나하나 먼지 가득한게 눈에 띄었고 이런 상태로 <b>여름<\/b>에 에어컨 가동하는건 말도 안되겠더라고요. 고압... ",
# 			"bloggername":"디자이너 메텔의 엉뚱한 秀(수)作(작)",
# 			"bloggerlink":"blog.naver.com\/chezleecody",
# 			"postdate":"20230419"
# 		},
# 		{
# 			"title":"<b>여름<\/b>방학캠프 철저한 관리로 완성한 목표",
# 			"link":"https:\/\/blog.naver.com\/modellien\/223080005724",
# 			"description":"하고 <b>여름<\/b>방학캠프에 참여하게 되었어요. 부모님께서도 권유를 해주신 과정이라 눈여겨볼 수 있었습니다. <b>여름<\/b>방학캠프는 이왕 집중해서 공부하는 거 빡세게 학습을 할 수 있었으면 좋겠다고 생각했어요. 학기... ",
# 			"bloggername":"다재다능한 진다맘의 인생 메뉴얼",
# 			"bloggerlink":"blog.naver.com\/modellien",
# 			"postdate":"20230420"
# 		},
# 		{
# 			"title":"시원하고 쾌적한 <b>여름<\/b>이불",
# ...

# %%
result = json.loads(data)
print(result)
# Out:
# {'lastBuildDate': 'Sun, 23 Apr 2023 20:14:02 +0900', 'total': 35118614, 'start': 1, 'display': 100, 'items': [{'title': '안산에어컨청소 <b>여름</b>대비 살균세척', 'link': 'https://blog.naver.com/chezleecody/223078906426', 'description': '<b>여름</b>이 오기전에 에어컨 청소를 해야할것 같아서 업체 불러서 작업을 맡겼어요. 신우토탈케어8호점... 하나하나 먼지 가득한게 눈에 띄었고 이런 상태로 <b>여름</b>에 에어컨 가동하는건 말도 안되겠더라고요. 고압... ', 'bloggername': '디자이너 메텔의 엉뚱한 秀(수)作(작)', 'bloggerlink': 'blog.naver.com/chezleecody', 'postdate': '20230419'}, {'title': '<b>여름</b>방학캠프 철저한 관리로 완성한 목표', 'link': 'https://blog.naver.com/modellien/223080005724', 'description': '하고 <b>여름</b>방학캠프에 참여하게 되었어요. 부모님께서도 권유를 해주신 과정이라 눈여겨볼 수 있었습니다. <b>여름</b>방학캠프는 이왕 집중해서 공부하는 거 빡세게 학습을 할 수 있었으면 좋겠다고 생각했어요. 학기... ', 'bloggername': '다재다능한 진다맘의 인생 메뉴얼', 'bloggerlink': 'blog.naver.com/modellien', 'postdate': '20230420'}, {'title': '시원하고 쾌적한 <b>여름</b>이불', 'link': 'https://blog.naver.com/dlsdo23/223080269995', 'description': '오늘은 제가 <b>여름</b>이불을 알아보고 샀던 후기를 말해보려고요. 먼저 후기를 통해 메리트가 있는 곳인지... 그렇게 이곳을 찾게 되었
# ...

# %%
result['items']
# Out:
# [{'title': '안산에어컨청소 <b>여름</b>대비 살균세척',
#   'link': 'https://blog.naver.com/chezleecody/223078906426',
#   'description': '<b>여름</b>이 오기전에 에어컨 청소를 해야할것 같아서 업체 불러서 작업을 맡겼어요. 신우토탈케어8호점... 하나하나 먼지 가득한게 눈에 띄었고 이런 상태로 <b>여름</b>에 에어컨 가동하는건 말도 안되겠더라고요. 고압... ',
#   'bloggername': '디자이너 메텔의 엉뚱한 秀(수)作(작)',
#   'bloggerlink': 'blog.naver.com/chezleecody',
#   'postdate': '20230419'},
#  {'title': '<b>여름</b>방학캠프 철저한 관리로 완성한 목표',
#   'link': 'https://blog.naver.com/modellien/223080005724',
#   'description': '하고 <b>여름</b>방학캠프에 참여하게 되었어요. 부모님께서도 권유를 해주신 과정이라 눈여겨볼 수 있었습니다. <b>여름</b>방학캠프는 이왕 집중해서 공부하는 거 빡세게 학습을 할 수 있었으면 좋겠다고 생각했어요. 학기... ',
#   'bloggername': '다재다능한 진다맘의 인생 메뉴얼',
#   'bloggerlink': 'blog.naver.com/modellien',
#   'postdate': '20230420'},
#  {'title': '시원하고 쾌적한 <b>여름</b>이불',
#   'link': 'https://blog.naver.com/dlsdo23/223080269995',
#   'description': '오늘은 제가 <b>여름</b>이불을 알아보고 샀던 후기를 말해보려고요. 먼저 후기를 통해 메리트가 있는 곳인지... 그렇게 이곳을 찾게 되었고 본격적으로 <b>여름</b>이불 쇼핑을 했답니다. 보통 이불은 폴리에스터와 면 두... ',
# ...

# %%
for item in result['items']:
    print(item['link'])
# Out:
# https://blog.naver.com/blogdanielland/223064119766
# https://blog.naver.com/mj_hudadak/223064366015
# https://blog.naver.com/leafy333/223064801796
# https://blog.naver.com/greenjeonnam/223064204515
# https://blog.naver.com/yee1036/223064116383
# https://blog.naver.com/aloneagain_/223062628727
# https://blog.naver.com/007crr/223062542937
# https://blog.naver.com/bongs1021/223062264446
# https://blog.naver.com/jspjd/223063804589
# https://blog.naver.com/majara78/223059107850
# https://blog.naver.com/pinkmay12/223064166782
# https://blog.naver.com/hitomi1228/223064305309
# https://blog.naver.com/yummycook/223059752622
# https://blog.naver.com/meekcho/223063464036
# https://blog.naver.com/bookey3/223063113018
# https://blog.naver.com/jeehsong/223063149889
# https://blog.naver.com/yungwook2/223063810955
# https://blog.naver.com/seogwipo-si/223062343396
# https://blog.naver.com/baby0817/223064306072
# https://blog.naver.com/goldjin__/223065042627
# ...

# %% [markdown]
# ## 네이버 오타 검색

# %%
import urllib.request
import json

client_id = "uBUu4FjdSESn5naeFWZ_"
client_secret = "TofNzWmeuU"
query = input('오타변환>>')
encText = urllib.parse.quote(query)
# print(encText)

# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
url = "https://openapi.naver.com/v1/search/errata.json?&query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 오타변환>> 벗꽃
# {
# 	"errata":"벚꽃"
# }
