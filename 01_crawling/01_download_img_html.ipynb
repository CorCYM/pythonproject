# %% [markdown]
# # 1. 이미지 다운로드
# ## 01. urllib

# %%
from urllib import request

# %%
url = 'https://mediahub.seoul.go.kr/uploads/mediahub/2022/03/HVcoUqjrSNnmlMuKSXqxLVDqIIgzHrUv.jpg'
savename = 'test.jpg'

# %%
request.urlretrieve(url, savename)
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x1e7a9b8c350>)

# %% [markdown]
# ## 02. html 소스 다운로드

# %% [markdown]
# ### 01. urllib이용

# %%
from urllib import request

# %%
url = 'https://www.naver.com/'
request.urlopen(url).read().decode('utf8')
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20230302.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"L ...

# %% [markdown]
# ### 02. requests 이용

# %%
import requests

# %%
url = 'https://www.naver.com'
r = requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20230302.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"L ...

# %%
r = requests.get('https://api.github.com/events', auth=('user', 'pass'))

# %%
r.text
# Out:
# '[{"id":"28589964005","type":"PullRequestEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":316123363,"name":"jineshsubedi/cv","url":"https://api.github.com/repos/jineshsubedi/cv"},"payload":{"action":"closed","number":3,"pull_request":{"url":"https://api.github.com/repos/jineshsubedi/cv/pulls/3","id":938174949,"node_id":"PR_kwDOEteo484362nl","html_url":"https://github.com/jineshsubedi/cv/pull/3","diff_url":"https://github.com/jineshsubedi/cv/pull/3.diff","patch_url":"https://github.com/jineshsubedi/cv/pull/3.patch","issue_url":"https://api.github.com/repos/jineshsubedi/cv/issues/3","number":3,"state":"closed","locked":false,"title":"Bump minimist from 1.2.0 to 1.2.6","user":{"login":"dependabot[bot]","id":49699333,"node_id":"MDM6Qm90NDk2OTkzMzM=","avatar_url":"https://avatars.githubusercontent.com/in/29110?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot%5Bbot%5D","html_url":"https://github.com/apps/dependabot","followers_url":"https://api.github.com/users/dependabot%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [minimist](https://github.com/substack/minimist) from 1.2.0 to 1.2.6.\\n<details>\\n<summary>Commits</summary>\\n<ul>\\n<li><a href=\\"https://github.com/substack/minimist/commit/7efb22a518b53b06f5b02a1038a88bd6290c2846\\"><code>7efb22a</code></a> 1.2.6</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/ef88b9325f77b5ee643ccfc97e2ebda577e4c4e2\\"><code>ef88b93</code></a> security notice for additional prototype pollution issue</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/c2b981977fa834b223b408cfb860f933c9811e4d\\"><code>c2b9819</code></a> isConstructorOrProto adapted from PR</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/bc8ecee43875261f4f17eb20b1243d3ed15e70eb\\"><code>bc8ecee</code></a> test from prototype pollution PR</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/aeb3e27dae0412de5c0494e9563a5f10c82cc7a9\\"><code>aeb3e27</code></a> 1.2.5</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/278677b171d956b46613a158c6c486c3ef979b20\\"><code>278677b</code></a> 1.2.4</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/4cf1354839cb972e38496d35e12f806eea92c11f\\"><code>4cf1354</code></a> security notice</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/1043d212c3caaf871966e710f52cfdf02f9eea4b\\"><code>1043d21</code></a> additional test for constructor prototype pollution</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/6457d7440a47f329c12c4a5abfbce211c4235b93\\"><code>6457d74</code></a> 1.2.3</li>\\n<li><a href=\\"https://github.com/substack/minimist/commit/38a4d1caead72ef99e824bb420a2528eec03d9ab\\"><code>38a4d1c</code></a> even more aggressive checks for protocol pollution</li>\\n<li>Additional commits viewable in <a href=\\"https://github.com/substack/minimist/compare/1.2.0...1.2.6\\">compare view</a></li>\\n</ul>\\n</details>\\n<br />\\n\\n\\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=minimist&package-manager=npm_and_yarn&previous-version=1.2.0&new ...

# %%
r.json()
# Out:
# [{'id': '28589964005',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 316123363,
#    'name': 'jineshsubedi/cv',
#    'url': 'https://api.github.com/repos/jineshsubedi/cv'},
#   'payload': {'action': 'closed',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3',
#     'id': 938174949,
#     'node_id': 'PR_kwDOEteo484362nl',
#     'html_url': 'https://github.com/jineshsubedi/cv/pull/3',
#     'diff_url': 'https://github.com/jineshsubedi/cv/pull/3.diff',
#     'patch_url': 'https://github.com/jineshsubedi/cv/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/3',
#     'number': 3,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump minimist from 1.2.0 to 1.2.6',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [minimist](https://github.com/substack/minimist) from 1.2.0 to 1.2.6.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/substack/minimist/commit/7efb22a518b53b06f5b02a1038a88bd6290c2846"><code>7efb22a</code></a> 1.2.6</li>\n<li><a href="https://github.com/substack/minimist/commit/ef88b9325f77b5ee643ccfc97e2ebda577e4c4e2"><code>ef88b93</code></a> security notice for additional prototype pollution issue</li>\n<li><a href="https://github.com/substack/minimist/commit/c2b981977fa834b223b408cfb860f933c9811e4d"><code>c2b9819</code></a> isConstructorOrProto adapted from PR</li>\n<li><a href="https://github.com/substack/minimist/commit/bc8ecee43875261f4f17eb20b1243d3ed15e70eb"><code>bc8ecee</code></a> test from prototype pollution PR</li>\n<li><a href="https://github.com/substack/minimist/commit/aeb3e27dae0412de5c0494e9563a5f10c82cc7a9"><code>aeb3e27</code></a> 1.2.5</li>\n<li><a href="https://github.com/substack/minimist/commit/278677b171d956b46613a158c6c486c3ef979b20"><code>278677b</code></a> 1.2.4</li>\n<li><a href="https://github.com/substack/minimist/commit/4cf1354839cb972e38496d35e12f806eea92c11f"><code>4cf1354</code></a> security notice</li>\n<li><a href="https://github.com/substack/minimist/commit/1043d212c3caaf871966e710f52cfdf02f9eea4b"><code>1043d21</code></a> additional test for constructor prototype pollution</li>\n<li><a href="https://github.com/substack/minimist/commit/6457d7440a47f329c12c4a5abfbce211c4235b93"><code>6457d74</code></a> 1.2.3</li>\n<li><a href="https://github.com/substack/minimist/commit/38a4d1caead72ef99e824bb420a2528eec03d9ab"><code>38a4d1c</code></a> even more aggressive checks for protocol pollution</li>\n<li>Additional commits viewable in <a href="https://github.com/substack/minimist/compare/1.2.0...1.2.6">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=minimist&package-manager=npm_and_yarn&previous-version=1.2.0&new-version=1.2.6)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignee ...
#     'created_at': '2022-05-17T00:54:45Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'closed_at': '2023-04-22T04:46:07Z',
#     'merged_at': None,
#     'merge_commit_sha': '7a1cdef48d3c9171056685dc8dd1d7a06b7abfbf',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 4138263792,
#       'node_id': 'LA_kwDOEteo4872qOTw',
#       'url': 'https://api.github.com/repos/jineshsubedi/cv/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/jineshsubedi/cv/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/jineshsubedi/cv/statuses/7ec5a03e38efe6cde2cd7c0930aba93113dd0224',
#     'head': {'label': 'jineshsubedi:dependabot/npm_and_yarn/minimist-1.2.6',
#      'ref': 'dependabot/npm_and_yarn/minimist-1.2.6',
#      'sha': '7ec5a03e38efe6cde2cd7c0930aba93113dd0224',
#      'user': {'login': 'jineshsubedi',
#       'id': 26435664,
#       'node_id': 'MDQ6VXNlcjI2NDM1NjY0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/26435664?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jineshsubedi',
#       'html_url': 'https://github.com/jineshsubedi',
#       'followers_url': 'https://api.github.com/users/jineshsubedi/followers',
#       'following_url': 'https://api.github.com/users/jineshsubedi/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jineshsubedi/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jineshsubedi/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jineshsubedi/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jineshsubedi/orgs',
#       'repos_url': 'https://api.github.com/users/jineshsubedi/repos',
#       'events_url': 'https://api.github.com/users/jineshsubedi/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jineshsubedi/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 316123363,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTYxMjMzNjM=',
#       'name': 'cv',
#       'full_name': 'jineshsubedi/cv',
#       'private': False,
#       'owner': {'login': 'jineshsubedi',
#        'id': 26435664,
#        'node_id': 'MDQ6VXNlcjI2NDM1NjY0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/26435664?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jineshsubedi',
#        'html_url': 'https://github.com/jineshsubedi',
#        'followers_url': 'https://api.github.com/users/jineshsubedi/followers',
#        'following_url': 'https://api.github.com/users/jineshsubedi/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jineshsubedi/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jineshsubedi/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jineshsubedi/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jineshsubedi/orgs',
#        'repos_url': 'https://api.github.com/users/jineshsubedi/repos',
#        'events_url': 'https://api.github.com/users/jineshsubedi/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jineshsubedi/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jineshsubedi/cv',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jineshsubedi/cv',
#       'forks_url': 'https://api.github.com/repos/jineshsubedi/cv/forks',
#       'keys_url': 'https://api.github.com/repos/jineshsubedi/cv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jineshsubedi/cv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jineshsubedi/cv/teams',
#       'hooks_url': 'https://api.github.com/repos/jineshsubedi/cv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jineshsubedi/cv/events',
#       'assignees_url': 'https://api.github.com/repos/jineshsubedi/cv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jineshsubedi/cv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jineshsubedi/cv/tags',
#       'blobs_url': 'https://api.github.com/repos/jineshsubedi/cv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jineshsubedi/cv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jineshsubedi/cv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jineshsubedi/cv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jineshsubedi/cv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jineshsubedi/cv/languages',
#       'stargazers_url': 'https://api.github.com/repos/jineshsubedi/cv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jineshsubedi/cv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jineshsubedi/cv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jineshsubedi/cv/subscription',
#       'commits_url': 'https://api.github.com/repos/jineshsubedi/cv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jineshsubedi/cv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jineshsubedi/cv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jineshsubedi/cv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jineshsubedi/cv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jineshsubedi/cv/merges',
#       'archive_url': 'https://api.github.com/repos/jineshsubedi/cv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jineshsubedi/cv/downloads',
#       'issues_url': 'https://api.github.com/repos/jineshsubedi/cv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jineshsubedi/cv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jineshsubedi/cv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jineshsubedi/cv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jineshsubedi/cv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jineshsubedi/cv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jineshsubedi/cv/deployments',
#       'created_at': '2020-11-26T04:33:44Z',
#       'updated_at': '2020-11-26T04:33:51Z',
#       'pushed_at': '2023-04-22T04:46:05Z',
#       'git_url': 'git://github.com/jineshsubedi/cv.git',
#       'ssh_url': 'git@github.com:jineshsubedi/cv.git',
#       'clone_url': 'https://github.com/jineshsubedi/cv.git',
#       'svn_url': 'https://github.com/jineshsubedi/cv',
#       'homepage': None,
#       'size': 322,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jineshsubedi:master',
#      'ref': 'master',
#      'sha': '487d4dfc83fc66cdd2e416730d5c67bb40264b90',
#      'user': {'login': 'jineshsubedi',
#       'id': 26435664,
#       'node_id': 'MDQ6VXNlcjI2NDM1NjY0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/26435664?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jineshsubedi',
#       'html_url': 'https://github.com/jineshsubedi',
#       'followers_url': 'https://api.github.com/users/jineshsubedi/followers',
#       'following_url': 'https://api.github.com/users/jineshsubedi/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jineshsubedi/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jineshsubedi/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jineshsubedi/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jineshsubedi/orgs',
#       'repos_url': 'https://api.github.com/users/jineshsubedi/repos',
#       'events_url': 'https://api.github.com/users/jineshsubedi/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jineshsubedi/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 316123363,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTYxMjMzNjM=',
#       'name': 'cv',
#       'full_name': 'jineshsubedi/cv',
#       'private': False,
#       'owner': {'login': 'jineshsubedi',
#        'id': 26435664,
#        'node_id': 'MDQ6VXNlcjI2NDM1NjY0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/26435664?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jineshsubedi',
#        'html_url': 'https://github.com/jineshsubedi',
#        'followers_url': 'https://api.github.com/users/jineshsubedi/followers',
#        'following_url': 'https://api.github.com/users/jineshsubedi/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jineshsubedi/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jineshsubedi/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jineshsubedi/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jineshsubedi/orgs',
#        'repos_url': 'https://api.github.com/users/jineshsubedi/repos',
#        'events_url': 'https://api.github.com/users/jineshsubedi/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jineshsubedi/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jineshsubedi/cv',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jineshsubedi/cv',
#       'forks_url': 'https://api.github.com/repos/jineshsubedi/cv/forks',
#       'keys_url': 'https://api.github.com/repos/jineshsubedi/cv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jineshsubedi/cv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jineshsubedi/cv/teams',
#       'hooks_url': 'https://api.github.com/repos/jineshsubedi/cv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jineshsubedi/cv/events',
#       'assignees_url': 'https://api.github.com/repos/jineshsubedi/cv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jineshsubedi/cv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jineshsubedi/cv/tags',
#       'blobs_url': 'https://api.github.com/repos/jineshsubedi/cv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jineshsubedi/cv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jineshsubedi/cv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jineshsubedi/cv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jineshsubedi/cv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jineshsubedi/cv/languages',
#       'stargazers_url': 'https://api.github.com/repos/jineshsubedi/cv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jineshsubedi/cv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jineshsubedi/cv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jineshsubedi/cv/subscription',
#       'commits_url': 'https://api.github.com/repos/jineshsubedi/cv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jineshsubedi/cv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jineshsubedi/cv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jineshsubedi/cv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jineshsubedi/cv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jineshsubedi/cv/merges',
#       'archive_url': 'https://api.github.com/repos/jineshsubedi/cv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jineshsubedi/cv/downloads',
#       'issues_url': 'https://api.github.com/repos/jineshsubedi/cv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jineshsubedi/cv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jineshsubedi/cv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jineshsubedi/cv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jineshsubedi/cv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jineshsubedi/cv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jineshsubedi/cv/deployments',
#       'created_at': '2020-11-26T04:33:44Z',
#       'updated_at': '2020-11-26T04:33:51Z',
#       'pushed_at': '2023-04-22T04:46:05Z',
#       'git_url': 'git://github.com/jineshsubedi/cv.git',
#       'ssh_url': 'git@github.com:jineshsubedi/cv.git',
#       'clone_url': 'https://github.com/jineshsubedi/cv.git',
#       'svn_url': 'https://github.com/jineshsubedi/cv',
#       'homepage': None,
#       'size': 322,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3'},
#      'html': {'href': 'https://github.com/jineshsubedi/cv/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/jineshsubedi/cv/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/jineshsubedi/cv/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jineshsubedi/cv/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jineshsubedi/cv/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jineshsubedi/cv/statuses/7ec5a03e38efe6cde2cd7c0930aba93113dd0224'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 11,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963989',
#   'type': 'PushEvent',
#   'actor': {'id': 12813051,
#    'login': 'wdkGitHub',
#    'display_login': 'wdkGitHub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wdkGitHub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12813051?'},
#   'repo': {'id': 235477414,
#    'name': 'wdkGitHub/wdkGitHub.github.io',
#    'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io'},
#   'payload': {'repository_id': 235477414,
#    'push_id': 13388392992,
#    'size': 56,
#    'distinct_size': 56,
#    'ref': 'refs/heads/master',
#    'head': 'c31996d4113c14a7eb3ff7dc36ad590685b4f386',
#    'before': '870ec90ee3ae5638a51f09a706a1f1a62bf6ae48',
#    'commits': [{'sha': '49716b752ca9841aae75d624f07ec7e8e6a20b51',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'First commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/49716b752ca9841aae75d624f07ec7e8e6a20b51'},
#     {'sha': 'f56eb735c4d406a488c2e54d617158a7ce3dcfd9',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-11 18:40:52',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/f56eb735c4d406a488c2e54d617158a7ce3dcfd9'},
#     {'sha': '4fea1b187eeca57fb3ff3e472342d99a2f2f261b',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-11 18:53:33',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/4fea1b187eeca57fb3ff3e472342d99a2f2f261b'},
#     {'sha': '73343bcfeee996df2fac9101700b9c5fcae021ae',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-11 18:55:47',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/73343bcfeee996df2fac9101700b9c5fcae021ae'},
#     {'sha': '8d3d18392b7a47a44d37f0743ba078d373f0311f',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-11 19:21:15',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/8d3d18392b7a47a44d37f0743ba078d373f0311f'},
#     {'sha': '233cc129be187c3b13450b78c0858e540f50c08c',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-11 19:42:08',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/233cc129be187c3b13450b78c0858e540f50c08c'},
#     {'sha': 'c8ceef0c290fc60a5104290718b01a67b0256db8',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-19 18:16:28',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/c8ceef0c290fc60a5104290718b01a67b0256db8'},
#     {'sha': 'caba4a5c28feaa84fb880b25851b426134cea62b',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-19 18:20:16',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/caba4a5c28feaa84fb880b25851b426134cea62b'},
#     {'sha': 'b96c54328cf4d84db1c00813868bca6ab33c77e4',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-19 18:27:34',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/b96c54328cf4d84db1c00813868bca6ab33c77e4'},
#     {'sha': '4d55ac068359aa70c3b6039ea0950e3b9b28960a',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-04-19 18:34:30',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/4d55ac068359aa70c3b6039ea0950e3b9b28960a'},
#     {'sha': 'e2fd6f89e093a172d9a9789aee422d81d6387489',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-07-10 16:30:51',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/e2fd6f89e093a172d9a9789aee422d81d6387489'},
#     {'sha': '8a094afc7f769e368be3dcfd34005224cdb62c0a',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-07-31 15:44:10',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/8a094afc7f769e368be3dcfd34005224cdb62c0a'},
#     {'sha': '84c6a940a6a87584005727c1d4c230de7698c0cb',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-07-31 16:57:00',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/84c6a940a6a87584005727c1d4c230de7698c0cb'},
#     {'sha': '64bee3982f13bb41b051f22995383eb4f955de48',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-07-31 16:58:11',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/64bee3982f13bb41b051f22995383eb4f955de48'},
#     {'sha': '29c6aa78638b44dd46e9ab1d0f42d51c08d4b302',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-12-21 12:47:56',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/29c6aa78638b44dd46e9ab1d0f42d51c08d4b302'},
#     {'sha': '83ad8d35b29a2dca80d2b0b952e271d1a3c030d6',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2020-12-21 12:49:17',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/83ad8d35b29a2dca80d2b0b952e271d1a3c030d6'},
#     {'sha': '1275cdaf6f21e7120b67a683518aabe92d79d86a',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2021-06-30 16:15:21',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/1275cdaf6f21e7120b67a683518aabe92d79d86a'},
#     {'sha': '1a4fb822640cf630a507b858ec98174ed01ef245',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2021-07-01 11:47:43',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/1a4fb822640cf630a507b858ec98174ed01ef245'},
#     {'sha': '94dfa59bf03758beb4bc9c472162fd36de6e032b',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2021-07-01 11:57:19',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/94dfa59bf03758beb4bc9c472162fd36de6e032b'},
#     {'sha': '3dc6def60ce832713e00bacbbcfb1ea4825c0e56',
#      'author': {'email': 'wangdekunemail@gmail.com', 'name': 'wangdekun'},
#      'message': 'Site updated: 2021-07-02 12:29:47',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wdkGitHub/wdkGitHub.github.io/commits/3dc6def60ce832713e00bacbbcfb1ea4825c0e56'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963995',
#   'type': 'PushEvent',
#   'actor': {'id': 101238574,
#    'login': 'vinodkumarbotta',
#    'display_login': 'vinodkumarbotta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vinodkumarbotta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101238574?'},
#   'repo': {'id': 630452572,
#    'name': 'vinodkumarbotta/app',
#    'url': 'https://api.github.com/repos/vinodkumarbotta/app'},
#   'payload': {'repository_id': 630452572,
#    'push_id': 13388393003,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '70cf061b337ef0935821d44ed450f04ae9ea4b70',
#    'before': 'b41a9f68ca97b0f882fe68285e4a9d1374d77774',
#    'commits': [{'sha': '70cf061b337ef0935821d44ed450f04ae9ea4b70',
#      'author': {'email': 'vinodkumarbotta@gmail.com',
#       'name': 'vinodkumarbotta'},
#      'message': 'added sonar docker compose',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vinodkumarbotta/app/commits/70cf061b337ef0935821d44ed450f04ae9ea4b70'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963999',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 631146962,
#    'name': 'Silvrbckw/interface',
#    'url': 'https://api.github.com/repos/Silvrbckw/interface'},
#   'payload': {'ref': 'dependabot/github_actions/crowdin/github-action-1.7.1',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'An open source interface for the decentralized liquidity protocol Aave',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963977',
#   'type': 'PushEvent',
#   'actor': {'id': 97563852,
#    'login': 'simonsar',
#    'display_login': 'simonsar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonsar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97563852?'},
#   'repo': {'id': 569928198,
#    'name': 'simonsar/grupo_5_CreativePlace',
#    'url': 'https://api.github.com/repos/simonsar/grupo_5_CreativePlace'},
#   'payload': {'repository_id': 569928198,
#    'push_id': 13388392994,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0281a147ecab370d39a022a2e960dc13f9bcd719',
#    'before': '26420a23f1fc0521fdec15d74be7015e67da2cc9',
#    'commits': [{'sha': '0281a147ecab370d39a022a2e960dc13f9bcd719',
#      'author': {'email': 'simonsara989@gmail.com', 'name': 'simonsar'},
#      'message': 'casi terminadas validaciones',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/simonsar/grupo_5_CreativePlace/commits/0281a147ecab370d39a022a2e960dc13f9bcd719'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963994',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 631147418,
#    'name': 'DaiYu-233/chat',
#    'url': 'https://api.github.com/repos/DaiYu-233/chat'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/DaiYu-233/chat/comments/110072110',
#     'html_url': 'https://github.com/DaiYu-233/chat/commit/e9139abb70766cb6583d3868f8d2e8b40030798b#commitcomment-110072110',
#     'id': 110072110,
#     'node_id': 'CC_kwDOJZ6Lms4Gj5Eu',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': 'e9139abb70766cb6583d3868f8d2e8b40030798b',
#     'created_at': '2023-04-22T04:46:08Z',
#     'updated_at': '2023-04-22T04:46:08Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## chat – ./\n\n[chat-three-orcin.vercel.app](https://chat-three-orcin.vercel.app)  \n[chat-git-main-daiyu-233.vercel.app](https://chat-git-main-daiyu-233.vercel.app)  \n[chat-daiyu-233.vercel.app](https://chat-daiyu-233.vercel.app)',
#     'reactions': {'url': 'https://api.github.com/repos/DaiYu-233/chat/comments/110072110/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963988',
#   'type': 'ForkEvent',
#   'actor': {'id': 17399705,
#    'login': 'seemasim',
#    'display_login': 'seemasim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seemasim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17399705?'},
#   'repo': {'id': 560603751,
#    'name': 'LinkedInLearning/cpp-code-challenges-3096958',
#    'url': 'https://api.github.com/repos/LinkedInLearning/cpp-code-challenges-3096958'},
#   'payload': {'forkee': {'id': 631147821,
#     'node_id': 'R_kgDOJZ6NLQ',
#     'name': 'cpp-code-challenges-3096958',
#     'full_name': 'seemasim/cpp-code-challenges-3096958',
#     'private': False,
#     'owner': {'login': 'seemasim',
#      'id': 17399705,
#      'node_id': 'MDQ6VXNlcjE3Mzk5NzA1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/17399705?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/seemasim',
#      'html_url': 'https://github.com/seemasim',
#      'followers_url': 'https://api.github.com/users/seemasim/followers',
#      'following_url': 'https://api.github.com/users/seemasim/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/seemasim/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/seemasim/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/seemasim/subscriptions',
#      'organizations_url': 'https://api.github.com/users/seemasim/orgs',
#      'repos_url': 'https://api.github.com/users/seemasim/repos',
#      'events_url': 'https://api.github.com/users/seemasim/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/seemasim/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/seemasim/cpp-code-challenges-3096958',
#     'description': 'This repo is for the Linkedin Learning course: Level up: C++',
#     'fork': True,
#     'url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958',
#     'forks_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/forks',
#     'keys_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/teams',
#     'hooks_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/hooks',
#     'issue_events_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/events',
#     'assignees_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/tags',
#     'blobs_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/languages',
#     'stargazers_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/stargazers',
#     'contributors_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/contributors',
#     'subscribers_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/subscribers',
#     'subscription_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/subscription',
#     'commits_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/merges',
#     'archive_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/downloads',
#     'issues_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/seemasim/cpp-code-challenges-3096958/deployments',
#     'created_at': '2023-04-22T04:46:07Z',
#     'updated_at': '2023-04-22T04:46:08Z',
#     'pushed_at': '2023-02-08T19:29:20Z',
#     'git_url': 'git://github.com/seemasim/cpp-code-challenges-3096958.git',
#     'ssh_url': 'git@github.com:seemasim/cpp-code-challenges-3096958.git',
#     'clone_url': 'https://github.com/seemasim/cpp-code-challenges-3096958.git',
#     'svn_url': 'https://github.com/seemasim/cpp-code-challenges-3096958',
#     'homepage': '',
#     'size': 82,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z',
#   'org': {'id': 28577987,
#    'login': 'LinkedInLearning',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/LinkedInLearning',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28577987?'}},
#  {'id': '28589963993',
#   'type': 'CreateEvent',
#   'actor': {'id': 98934812,
#    'login': 'risasoft',
#    'display_login': 'risasoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/risasoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98934812?'},
#   'repo': {'id': 465514827,
#    'name': 'risastaking/delegation-dashboard',
#    'url': 'https://api.github.com/repos/risastaking/delegation-dashboard'},
#   'payload': {'ref': 'fix/web-wallet',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z',
#   'org': {'id': 117410027,
#    'login': 'risastaking',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/risastaking',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117410027?'}},
#  {'id': '28589963970',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 508523816,
#    'name': 'keropamera/machine',
#    'url': 'https://api.github.com/repos/keropamera/machine'},
#   'payload': {'repository_id': 508523816,
#    'push_id': 13388392983,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '97f308e96d995e8ab2877ef66b691104787379e3',
#    'before': '14ef060438de747f1336e494df2e9bfdc178e57a',
#    'commits': [{'sha': '97f308e96d995e8ab2877ef66b691104787379e3',
#      'author': {'email': 'renataropes@outlook.com', 'name': 'renataropes'},
#      'message': 'Sync... Machine',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/keropamera/machine/commits/97f308e96d995e8ab2877ef66b691104787379e3'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963982',
#   'type': 'DeleteEvent',
#   'actor': {'id': 104743882,
#    'login': 'IcebergVerse',
#    'display_login': 'IcebergVerse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IcebergVerse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104743882?'},
#   'repo': {'id': 542269516,
#    'name': 'IcebergVerse/examples',
#    'url': 'https://api.github.com/repos/IcebergVerse/examples'},
#   'payload': {'ref': 'snyk-upgrade-52714a7f4453f48223dd8aa9299f9822',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-04-22T04:46:08Z'},
#  {'id': '28589963973',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 45773732,
#    'login': 'joseharriaga',
#    'display_login': 'joseharriaga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joseharriaga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45773732?'},
#   'repo': {'id': 2928944,
#    'name': 'Azure/azure-sdk-for-net',
#    'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/pulls/comments/1174289560',
#     'pull_request_review_id': 1396565630,
#     'id': 1174289560,
#     'node_id': 'PRRC_kwDOACyxMM5F_jyY',
#     'diff_hunk': '@@ -34,20 +34,23 @@ private static bool ShouldRetry(TestExecutionContext context)\n \n             // A known transient issue where the server returns a successful 200 OK response status but reports an\n             // internal server error in the response body for one or more text analysis tasks.\n+            // https://github.com/Azure/azure-sdk-for-net/issues/35677',
#     'path': 'sdk/textanalytics/Azure.AI.TextAnalytics/tests/Infrastructure/RetryOnInternalServerErrorAttribute.cs',
#     'commit_id': '20db2731c97e4881fe775e1d26c342563e12c553',
#     'original_commit_id': 'a86406c3463ace2a9e80e78b5168eb0adb5489cc',
#     'user': {'login': 'joseharriaga',
#      'id': 45773732,
#      'node_id': 'MDQ6VXNlcjQ1NzczNzMy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/45773732?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/joseharriaga',
#      'html_url': 'https://github.com/joseharriaga',
#      'followers_url': 'https://api.github.com/users/joseharriaga/followers',
#      'following_url': 'https://api.github.com/users/joseharriaga/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/joseharriaga/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/joseharriaga/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/joseharriaga/subscriptions',
#      'organizations_url': 'https://api.github.com/users/joseharriaga/orgs',
#      'repos_url': 'https://api.github.com/users/joseharriaga/repos',
#      'events_url': 'https://api.github.com/users/joseharriaga/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/joseharriaga/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Fixed!',
#     'created_at': '2023-04-22T04:46:07Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'html_url': 'https://github.com/Azure/azure-sdk-for-net/pull/35712#discussion_r1174289560',
#     'pull_request_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/pulls/35712',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/Azure/azure-sdk-for-net/pulls/comments/1174289560'},
#      'html': {'href': 'https://github.com/Azure/azure-sdk-for-net/pull/35712#discussion_r1174289560'},
#      'pull_request': {'href': 'https://api.github.com/repos/Azure/azure-sdk-for-net/pulls/35712'}},
#     'reactions': {'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/pulls/comments/1174289560/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
# ...
#     'reactions': {'url': 'https://api.github.com/repos/jineshsubedi/cv/issues/3/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/3/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/jineshsubedi/cv/issues/comments/1518508776',
#     'html_url': 'https://github.com/jineshsubedi/cv/pull/3#issuecomment-1518508776',
#     'issue_url': 'https://api.github.com/repos/jineshsubedi/cv/issues/3',
#     'id': 1518508776,
#     'node_id': 'IC_kwDOEteo485agpro',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2023-04-22T04:46:07Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #7.',
#     'reactions': {'url': 'https://api.github.com/repos/jineshsubedi/cv/issues/comments/1518508776/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963930',
#   'type': 'PushEvent',
#   'actor': {'id': 104743882,
#    'login': 'IcebergVerse',
#    'display_login': 'IcebergVerse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IcebergVerse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104743882?'},
#   'repo': {'id': 542269516,
#    'name': 'IcebergVerse/examples',
#    'url': 'https://api.github.com/repos/IcebergVerse/examples'},
#   'payload': {'repository_id': 542269516,
#    'push_id': 13388392950,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/snyk-upgrade-52714a7f4453f48223dd8aa9299f9822',
#    'head': '6eefdb32479360068d239cb204fae2f82e412f03',
#    'before': '49e29ed02e16d10b7c04ea1b2d21c41be5ea84e7',
#    'commits': [{'sha': '6eefdb32479360068d239cb204fae2f82e412f03',
#      'author': {'email': 'snyk-bot@snyk.io', 'name': 'snyk-bot'},
#      'message': 'fix: upgrade @vercel/examples-ui from 0.3.6 to 0.3.51\n\nSnyk has created this PR to upgrade @vercel/examples-ui from 0.3.6 to 0.3.51.\n\nSee this package in npm:\nhttps://www.npmjs.com/package/@vercel/examples-ui\n\nSee this project in Snyk:\nhttps://app.snyk.io/org/icebergverse/project/ea1922fe-e425-4bab-9f26-73c0902b8380?utm_source=github&utm_medium=referral&page=upgrade-pr',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IcebergVerse/examples/commits/6eefdb32479360068d239cb204fae2f82e412f03'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963934',
#   'type': 'PushEvent',
#   'actor': {'id': 5115931,
#    'login': 'mwright-pivotal',
#    'display_login': 'mwright-pivotal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mwright-pivotal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5115931?'},
#   'repo': {'id': 614896064,
#    'name': 'mwright-pivotal/openvino_object_detection',
#    'url': 'https://api.github.com/repos/mwright-pivotal/openvino_object_detection'},
#   'payload': {'repository_id': 614896064,
#    'push_id': 13388392954,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6f49475b624406b69068e9b2ca74867ffc98484a',
#    'before': 'a8c3ff95f91166833952a93657889b770f4748e1',
#    'commits': [{'sha': '6f49475b624406b69068e9b2ca74867ffc98484a',
#      'author': {'email': 'wrightmi@vmware.com', 'name': 'mwright-pivotal'},
#      'message': 'Update from SEBU TAP Supply Chain Choreographer',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mwright-pivotal/openvino_object_detection/commits/6f49475b624406b69068e9b2ca74867ffc98484a'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963929',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 22971406,
#    'login': 'coolhugh',
#    'display_login': 'coolhugh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/coolhugh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22971406?'},
#   'repo': {'id': 434453442,
#    'name': 'JXA-a/aixiaoju-AXJ',
#    'url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1',
#     'repository_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ',
#     'labels_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1/events',
#     'html_url': 'https://github.com/JXA-a/aixiaoju-AXJ/issues/1',
#     'id': 1679299546,
#     'node_id': 'I_kwDOGeU7ws5kGBPa',
#     'number': 1,
#     'title': '500错误',
#     'user': {'login': 'ShuangruiYang',
#      'id': 40386448,
#      'node_id': 'MDQ6VXNlcjQwMzg2NDQ4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/40386448?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ShuangruiYang',
#      'html_url': 'https://github.com/ShuangruiYang',
#      'followers_url': 'https://api.github.com/users/ShuangruiYang/followers',
#      'following_url': 'https://api.github.com/users/ShuangruiYang/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ShuangruiYang/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ShuangruiYang/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ShuangruiYang/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ShuangruiYang/orgs',
#      'repos_url': 'https://api.github.com/users/ShuangruiYang/repos',
#      'events_url': 'https://api.github.com/users/ShuangruiYang/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ShuangruiYang/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2023-04-22T03:19:24Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '运营商: 电信\r\nVPN: 香港\r\n\r\n从 2023-04-21 开始, 返回都是500错误.',
#     'reactions': {'url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/comments/1518508777',
#     'html_url': 'https://github.com/JXA-a/aixiaoju-AXJ/issues/1#issuecomment-1518508777',
#     'issue_url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/1',
#     'id': 1518508777,
#     'node_id': 'IC_kwDOGeU7ws5agprp',
#     'user': {'login': 'coolhugh',
#      'id': 22971406,
#      'node_id': 'MDQ6VXNlcjIyOTcxNDA2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/22971406?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/coolhugh',
#      'html_url': 'https://github.com/coolhugh',
#      'followers_url': 'https://api.github.com/users/coolhugh/followers',
#      'following_url': 'https://api.github.com/users/coolhugh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/coolhugh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/coolhugh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/coolhugh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/coolhugh/orgs',
#      'repos_url': 'https://api.github.com/users/coolhugh/repos',
#      'events_url': 'https://api.github.com/users/coolhugh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/coolhugh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-04-22T04:46:07Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'author_association': 'NONE',
#     'body': '> 听说已经跑路了。\r\n> \r\n> 同志们有什么资源站推荐\r\n\r\n从哪里听说？',
#     'reactions': {'url': 'https://api.github.com/repos/JXA-a/aixiaoju-AXJ/issues/comments/1518508777/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963915',
#   'type': 'PushEvent',
#   'actor': {'id': 124311528,
#    'login': 'ImWezzz',
#    'display_login': 'ImWezzz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ImWezzz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124311528?'},
#   'repo': {'id': 608740653,
#    'name': 'ImWezzz/ImWezzz',
#    'url': 'https://api.github.com/repos/ImWezzz/ImWezzz'},
#   'payload': {'repository_id': 608740653,
#    'push_id': 13388392940,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'efb8c7e8b667e5eb6dff1e308384f4d449e31d41',
#    'before': '6b0056a7e1649960851d69576c4244fca58828d5',
#    'commits': [{'sha': 'efb8c7e8b667e5eb6dff1e308384f4d449e31d41',
#      'author': {'email': '124311528+ImWezzz@users.noreply.github.com',
#       'name': 'ImWez'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ImWezzz/ImWezzz/commits/efb8c7e8b667e5eb6dff1e308384f4d449e31d41'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963922',
#   'type': 'PushEvent',
#   'actor': {'id': 126175821,
#    'login': 'jhonalexander1606',
#    'display_login': 'jhonalexander1606',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jhonalexander1606',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126175821?'},
#   'repo': {'id': 630514057,
#    'name': 'jhonalexander1606/ejercicios_for',
#    'url': 'https://api.github.com/repos/jhonalexander1606/ejercicios_for'},
#   'payload': {'repository_id': 630514057,
#    'push_id': 13388392952,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b22fa5c7b3a5439231e1f8a0a4584293b4edd89d',
#    'before': '7b1f2c585037f7d8413819b22d853c59530ff264',
#    'commits': [{'sha': 'b22fa5c7b3a5439231e1f8a0a4584293b4edd89d',
#      'author': {'email': 'jhonalexandercalderonmunoz@gmail.com',
#       'name': 'jhonalexander1606'},
#      'message': 'se agrego el codigo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jhonalexander1606/ejercicios_for/commits/b22fa5c7b3a5439231e1f8a0a4584293b4edd89d'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963913',
#   'type': 'PushEvent',
#   'actor': {'id': 105415861,
#    'login': 'juisaeva',
#    'display_login': 'juisaeva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juisaeva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105415861?'},
#   'repo': {'id': 631145848,
#    'name': 'juisaeva/clean-code-s1e1',
#    'url': 'https://api.github.com/repos/juisaeva/clean-code-s1e1'},
#   'payload': {'repository_id': 631145848,
#    'push_id': 13388392942,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/clean-code-s1e1',
#    'head': '35c8e76e5cea9d8996aa798149c32b529b7fbfae',
#    'before': '1ea9e07c31ede058bf669763ac1d96b04899d818',
#    'commits': [{'sha': '35c8e76e5cea9d8996aa798149c32b529b7fbfae',
#      'author': {'email': 'pulinu@icloud.com', 'name': 'Yulia Isaeva'},
#      'message': 'refactor: change CSS tabs on spaces according to rule 1.1 in html-and-css.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/juisaeva/clean-code-s1e1/commits/35c8e76e5cea9d8996aa798149c32b529b7fbfae'}]},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'},
#  {'id': '28589963919',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 35613825,
#    'login': 'vercel[bot]',
#    'display_login': 'vercel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vercel[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613825?'},
#   'repo': {'id': 629875906,
#    'name': 'brandonwie/poc-t3-sita',
#    'url': 'https://api.github.com/repos/brandonwie/poc-t3-sita'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/brandonwie/poc-t3-sita/comments/110072109',
#     'html_url': 'https://github.com/brandonwie/poc-t3-sita/commit/81181b53a8bcfe695d87d97f6bb65747629dfcc5#commitcomment-110072109',
#     'id': 110072109,
#     'node_id': 'CC_kwDOJYskws4Gj5Et',
#     'user': {'login': 'vercel[bot]',
#      'id': 35613825,
#      'node_id': 'MDM6Qm90MzU2MTM4MjU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/8329?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vercel%5Bbot%5D',
#      'html_url': 'https://github.com/apps/vercel',
#      'followers_url': 'https://api.github.com/users/vercel%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vercel%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vercel%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/vercel%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vercel%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': '81181b53a8bcfe695d87d97f6bb65747629dfcc5',
#     'created_at': '2023-04-22T04:46:07Z',
#     'updated_at': '2023-04-22T04:46:07Z',
#     'author_association': 'NONE',
#     'body': 'Successfully deployed to the following URLs:\n\n## sita-test-t3 – ./\n\n[sita-test-t3-git-main-brandonwie.vercel.app](https://sita-test-t3-git-main-brandonwie.vercel.app)  \n[poc-t3-sita.vercel.app](https://poc-t3-sita.vercel.app)  \n[sita-test-t3-brandonwie.vercel.app](https://sita-test-t3-brandonwie.vercel.app)',
#     'reactions': {'url': 'https://api.github.com/repos/brandonwie/poc-t3-sita/comments/110072109/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0}}},
#   'public': True,
#   'created_at': '2023-04-22T04:46:07Z'}]

# %%
url = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20120101'
r = requests.get(url)

# %%
r.json()
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20120101~20120101',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112207',
#     'movieNm': '미션임파서블:고스트프로토콜',
#     'openDt': '2011-12-15',
#     'salesAmt': '2776060500',
#     'salesShare': '36.3',
#     'salesInten': '-415699000',
#     'salesChange': '-13',
#     'salesAcc': '40541108500',
#     'audiCnt': '353274',
#     'audiInten': '-60106',
#     'audiChange': '-14.5',
#     'audiAcc': '5328435',
#     'scrnCnt': '697',
#     'showCnt': '3223'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20110295',
#     'movieNm': '마이 웨이',
#     'openDt': '2011-12-21',
#     'salesAmt': '1189058500',
#     'salesShare': '15.6',
#     'salesInten': '-105894500',
#     'salesChange': '-8.2',
#     'salesAcc': '13002897500',
#     'audiCnt': '153501',
#     'audiInten': '-16465',
#     'audiChange': '-9.7',
#     'audiAcc': '1739543',
#     'scrnCnt': '588',
#     'showCnt': '2321'},
#    {'rnum': '3',
#     'rank': '3',
#     'rankInten': '-1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112621',
#     'movieNm': '셜록홈즈 : 그림자 게임',
#     'openDt': '2011-12-21',
#     'salesAmt': '1176022500',
#     'salesShare': '15.4',
#     'salesInten': '-210328500',
#     'salesChange': '-15.2',
#     'salesAcc': '10678327500',
#     'audiCnt': '153004',
#     'audiInten': '-31283',
#     'audiChange': '-17',
#     'audiAcc': '1442861',
#     'scrnCnt': '360',
#     'showCnt': '1832'},
#    {'rnum': '4',
#     'rank': '4',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20113260',
#     'movieNm': '퍼펙트 게임',
#     'openDt': '2011-12-21',
#     'salesAmt': '644532000',
#     'salesShare': '8.4',
#     'salesInten': '-75116500',
#     'salesChange': '-10.4',
#     'salesAcc': '6640940000',
#     'audiCnt': '83644',
#     'audiInten': '-12225',
#     'audiChange': '-12.8',
#     'audiAcc': '895416',
#     'scrnCnt': '396',
#     'showCnt': '1364'},
#    {'rnum': '5',
#     'rank': '5',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20113271',
#     'movieNm': '프렌즈: 몬스터섬의비밀 ',
#     'openDt': '2011-12-29',
#     'salesAmt': '436753500',
#     'salesShare': '5.7',
#     'salesInten': '-89051000',
#     'salesChange': '-16.9',
#     'salesAcc': '1523037000',
#     'audiCnt': '55092',
#     'audiInten': '-15568',
#     'audiChange': '-22',
#     'audiAcc': '202909',
#     'scrnCnt': '290',
#     'showCnt': '838'},
#    {'rnum': '6',
#     'rank': '6',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '19940256',
#     'movieNm': '라이온 킹',
#     'openDt': '1994-07-02',
#     'salesAmt': '507115500',
#     'salesShare': '6.6',
#     'salesInten': '-114593500',
#     'salesChange': '-18.4',
#     'salesAcc': '1841625000',
#     'audiCnt': '45750',
#     'audiInten': '-11699',
#     'audiChange': '-20.4',
#     'audiAcc': '171285',
#     'scrnCnt': '244',
#     'showCnt': '895'},
#    {'rnum': '7',
#     'rank': '7',
#     'rankInten': '-1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20113381',
#     'movieNm': '오싹한 연애',
#     'openDt': '2011-12-01',
#     'salesAmt': '344871000',
#     'salesShare': '4.5',
#     'salesInten': '-107005500',
#     'salesChange': '-23.7',
#     'salesAcc': '20634684500',
#     'audiCnt': '45062',
#     'audiInten': '-15926',
#     'audiChange': '-26.1',
#     'audiAcc': '2823060',
#     'scrnCnt': '243',
#     'showCnt': '839'},
#    {'rnum': '8',
#     'rank': '8',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112709',
#     'movieNm': '극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」',
#     'openDt': '2011-12-22',
#     'salesAmt': '167809500',
#     'salesShare': '2.2',
#     'salesInten': '-45900500',
#     'salesChange': '-21.5',
#     'salesAcc': '1897120000',
#     'audiCnt': '24202',
#     'audiInten': '-7756',
#     'audiChange': '-24.3',
#     'audiAcc': '285959',
#     'scrnCnt': '186',
#     'showCnt': '348'},
#    {'rnum': '9',
#     'rank': '9',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20113311',
#     'movieNm': '앨빈과 슈퍼밴드3',
#     'openDt': '2011-12-15',
#     'salesAmt': '137030000',
#     'salesShare': '1.8',
#     'salesInten': '-35408000',
#     'salesChange': '-20.5',
#     'salesAcc': '3416675000',
#     'audiCnt': '19729',
#     'audiInten': '-6461',
#     'audiChange': '-24.7',
#     'audiAcc': '516289',
#     'scrnCnt': '169',
#     'showCnt': '359'},
#    {'rnum': '10',
#     'rank': '10',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112708',
#     'movieNm': '극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」',
#     'openDt': '2011-12-22',
#     'salesAmt': '125535500',
#     'salesShare': '1.6',
#     'salesInten': '-40756000',
#     'salesChange': '-24.5',
#     'salesAcc': '1595695000',
#     'audiCnt': '17817',
#     'audiInten': '-6554',
#     'audiChange': '-26.9',
#     'audiAcc': '235070',
#     'scrnCnt': '175',
#     'showCnt': '291'}]}}

# %% [markdown]
# ### 03. 검색어 넣어서 html페이지 가져오기
# #### 01. urllib이용

# %%
'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EB%B2%9A%EA%BD%83'
# Out:
# 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EB%B2%9A%EA%BD%83'

# %%
from urllib import request,parse

# %%
query = input('검색할 키 >>>')
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query='+query
request.urlopen(url).read()
# Out:
# 검색할 키 >>> 봄
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[17], line 3
#       1 query = input('검색할 키 >>>')
#       2 url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query='+query
# ----> 3 request.urlopen(url).read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1279 def request(self, method, url, body=None, headers={}, *,
#    1280             encode_chunked=False):
#    1281     """Send a complete request to the server."""
# -> 1282     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1293, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1290 if 'accept-encoding' in header_names:
#    1291     skips['skip_accept_encoding'] = 1
# -> 1293 self.putrequest(method, url, **skips)
#    1295 # chunked encoding will happen if HTTP/1.1 is used and either
#    1296 # the caller passes encode_chunked=True or the following
#    1297 # conditions hold:
#    1298 # 1. content-length has not been explicitly set
#    1299 # 2. the body is a file or iterable, but not a str or bytes-like
#    1300 # 3. Transfer-Encoding has NOT been explicitly set by the caller
#    1302 if 'content-length' not in header_names:
#    1303     # only chunk body if not explicitly set for backwards
#    1304     # compatibility, assuming the client code is already handling the
#    1305     # chunking
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1131, in HTTPConnection.putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1127 self._validate_path(url)
#    1129 request = '%s %s %s' % (method, url, self._http_vsn_str)
# -> 1131 self._output(self._encode_request(request))
#    1133 if self._http_vsn == 11:
#    1134     # Issue some standard headers for better HTTP/1.1 compliance
#    1136     if not skip_host:
#    1137         # this header is issued *only* for HTTP/1.1
#    1138         # connections. more specifically, this means it is
#    (...)
#    1148         # but the host of the actual URL, not the host of the
#    1149         # proxy.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1211, in HTTPConnection._encode_request(self, request)
#    1209 def _encode_request(self, request):
#    1210     # ASCII also helps prevent CVE-2019-9740.
# -> 1211     return request.encode('ascii')
#
# UnicodeEncodeError: 'ascii' codec can't encode character '\ubd04' in position 64: ordinal not in range(128)

# %%
url = 'https://search.naver.com/search.naver?'
query = input('검색할 키 >>>')
values = {
    # 'where':'nexearch',
    # 'sm':'top_hty',
    # 'fbm':'1',
    # 'ie':'utf8',
    'query':query
}

params = parse.urlencode(values)
url = url + params
print(url)

request.urlopen(url).read().decode('utf8')
# Out:
# 검색할 키 >>> 여름
# https://search.naver.com/search.naver?query=%EC%97%AC%EB%A6%84
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="여름 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'여름\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'여름\'의 네이버 통합검색 결과입니다."> <title>여름 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230420.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230420.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { \'use strict\'; if (!((typeof func === \'Function\' || typeof func === \'function\') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire ...

# %% [markdown]
# #### 02. requests 이용

# %%
import requests

# %%
query =  input('검색할 키 >>>')
url = 'https://search.naver.com/search.naver?'
values = {
    # 'where':'nexearch',
    # 'sm':'top_hty',
    # 'fbm':'1',
    # 'ie':'utf8',
    'query':query
}
r = requests.get(url,params=values)
r.text
# Out:
# 검색할 키 >>> 여름
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="여름 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'여름\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'여름\'의 네이버 통합검색 결과입니다."> <title>여름 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230420.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230420.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { \'use strict\'; if (!((typeof func === \'Function\' || typeof func === \'function\') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire ...
