# %%
key = 'b33cddf89427c02f7073aea1735fe76a'
targetDt='20230409'

# %%
url=f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={targetDt}'

# %%
import urllib.request
import json
import pandas as pd
import time, datetime

# %%
r = urllib.request.urlopen(url)
# print(r.read().decode('utf8'))
data = json.loads(r.read())
# data
data['boxOfficeResult']['dailyBoxOfficeList']
# Out:
# [{'rnum': '1',
#   'rank': '1',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226270',
#   'movieNm': '스즈메의 문단속',
#   'openDt': '2023-03-08',
#   'salesAmt': '1545928390',
#   'salesShare': '46.1',
#   'salesInten': '-343679878',
#   'salesChange': '-18.2',
#   'salesAcc': '44785596803',
#   'audiCnt': '154555',
#   'audiInten': '-33196',
#   'audiChange': '-17.7',
#   'audiAcc': '4344048',
#   'scrnCnt': '1323',
#   'showCnt': '5109'},
#  {'rnum': '2',
#   'rank': '2',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226489',
#   'movieNm': '리바운드',
#   'openDt': '2023-04-05',
#   'salesAmt': '802904347',
#   'salesShare': '23.9',
#   'salesInten': '-84295396',
#   'salesChange': '-9.5',
#   'salesAcc': '2769532376',
#   'audiCnt': '82900',
#   'audiInten': '-7973',
#   'audiChange': '-8.8',
#   'audiAcc': '290162',
#   'scrnCnt': '1154',
#   'showCnt': '4413'},
#  {'rnum': '3',
#   'rank': '3',
#   'rankInten': '1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231089',
#   'movieNm': '존 윅 4',
#   'openDt': '2023-04-12',
#   'salesAmt': '207856297',
#   'salesShare': '6.2',
#   'salesInten': '-22596911',
#   'salesChange': '-9.8',
#   'salesAcc': '459525505',
#   'audiCnt': '17993',
#   'audiInten': '-1907',
#   'audiChange': '-9.6',
#   'audiAcc': '39141',
#   'scrnCnt': '173',
#   'showCnt': '364'},
#  {'rnum': '4',
#   'rank': '4',
#   'rankInten': '-1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226410',
#   'movieNm': '던전 앤 드래곤: 도적들의 명예',
#   'openDt': '2023-03-29',
#   'salesAmt': '168873437',
#   'salesShare': '5.0',
#   'salesInten': '-50270169',
#   'salesChange': '-22.9',
#   'salesAcc': '2664541507',
#   'audiCnt': '16719',
#   'audiInten': '-4638',
#   'audiChange': '-21.7',
#   'audiAcc': '267773',
#   'scrnCnt': '623',
#   'showCnt': '1317'},
#  {'rnum': '5',
#   'rank': '5',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231010',
#   'movieNm': '에어',
#   'openDt': '2023-04-05',
#   'salesAmt': '145256413',
#   'salesShare': '4.3',
#   'salesInten': '-52693051',
#   'salesChange': '-26.6',
#   'salesAcc': '750881362',
#   'audiCnt': '14493',
#   'audiInten': '-5402',
#   'audiChange': '-27.2',
#   'audiAcc': '77550',
#   'scrnCnt': '629',
#   'showCnt': '1962'},
#  {'rnum': '6',
#   'rank': '6',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20228555',
#   'movieNm': '더 퍼스트 슬램덩크',
#   'openDt': '2023-01-04',
#   'salesAmt': '188916500',
#   'salesShare': '5.6',
#   'salesInten': '-37243500',
#   'salesChange': '-16.5',
#   'salesAcc': '46190437867',
#   'audiCnt': '10805',
#   'audiInten': '-1836',
#   'audiChange': '-14.5',
#   'audiAcc': '4447450',
#   'scrnCnt': '22',
#   'showCnt': '126'},
#  {'rnum': '7',
#   'rank': '7',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20210544',
#   'movieNm': '웅남이',
#   'openDt': '2023-03-22',
#   'salesAmt': '44281046',
#   'salesShare': '1.3',
#   'salesInten': '-4838843',
#   'salesChange': '-9.9',
#   'salesAcc': '2725478652',
#   'audiCnt': '4793',
#   'audiInten': '-566',
#   'audiChange': '-10.6',
#   'audiAcc': '297332',
#   'scrnCnt': '363',
#   'showCnt': '558'},
#  {'rnum': '8',
#   'rank': '8',
#   'rankInten': '1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20230484',
#   'movieNm': '치킨래빗: 잃어버린 보물을 찾아서',
#   'openDt': '2023-03-18',
#   'salesAmt': '33462000',
#   'salesShare': '1.0',
#   'salesInten': '-1266500',
#   'salesChange': '-3.6',
#   'salesAcc': '546366000',
#   'audiCnt': '3557',
#   'audiInten': '6',
#   'audiChange': '0.2',
#   'audiAcc': '61162',
#   'scrnCnt': '138',
#   'showCnt': '208'},
#  {'rnum': '9',
#   'rank': '9',
#   'rankInten': '-1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20230764',
#   'movieNm': '오글리스: 웰컴 투 냄새 마을',
#   'openDt': '2023-04-06',
#   'salesAmt': '30223090',
#   'salesShare': '0.9',
#   'salesInten': '-1948798',
#   'salesChange': '-6.1',
#   'salesAcc': '74771876',
#   'audiCnt': '3406',
#   'audiInten': '-223',
#   'audiChange': '-6.1',
#   'audiAcc': '8611',
#   'scrnCnt': '249',
#   'showCnt': '294'},
#  {'rnum': '10',
#   'rank': '10',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231035',
#   'movieNm': '카구야 님은 고백받고 싶어 -첫 키스는 끝나지 않아-',
#   'openDt': '2023-04-06',
#   'salesAmt': '27178300',
#   'salesShare': '0.8',
#   'salesInten': '-12885900',
#   'salesChange': '-32.2',
#   'salesAcc': '136089900',
#   'audiCnt': '2383',
#   'audiInten': '-1137',
#   'audiChange': '-32.3',
#   'audiAcc': '11980',
#   'scrnCnt': '107',
#   'showCnt': '221'}]

# %%
movieDate = time.strftime('%Y%m%d',time.localtime(time.time())) ## strftime 시간 -> 문자열
movieDate

date_obj = datetime.datetime.strptime(movieDate, '%Y%m%d') ## strptime 문자열 -> 시간
date_obj
# Out:
# datetime.datetime(2023, 4, 23, 0, 0)

# %%
def cineBoxInfo():
    movieDate = time.strftime('%Y%m%d',time.localtime(time.time()))
    cine=[]
    for i in range(30):
        date_obj = datetime.datetime.strptime(movieDate, '%Y%m%d')
        date_obj_temp = date_obj - datetime.timedelta(days=1)
        movieDate = date_obj_temp.strftime('%Y%m%d')
        # print(movieDate, end=" ")
        url=f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={movieDate}'
        r = urllib.request.urlopen(url)
        data = json.loads(r.read())
        result = data['boxOfficeResult']['dailyBoxOfficeList']
        for i in range(len(result)):
            result[i]['targetDt'] = movieDate
            cine.append(result[i])
    df = pd.DataFrame(cine)
    df.to_csv('cine.csv', index=False)
    return df

# %%
cineBoxInfo()
# Out:
#     rnum rank rankInten rankOldAndNew   movieCd                   movieNm
# 0      1    1         0           OLD  20231089                     존 윅 4  \
# 1      2    2         0           OLD  20226270                  스즈메의 문단속
# 2      3    3         0           OLD  20226489                      리바운드
# 3      4    4         0           OLD  20225865                     옥수역귀신
# 4      5    5         0           OLD  20200154                    킬링 로맨스
# ..   ...  ...       ...           ...       ...                       ...
# 295    6    6         1           OLD  20230340        에브리씽 에브리웨어 올 앳 원스+
# 296    7    7         1           OLD  20230533  귀멸의 칼날: 상현집결, 그리고 도공 마을로
# 297    8    8        -2           OLD  20224780               모나리자와 블러드 문
# 298    9    9         4           OLD  20230081                샤잠! 신들의 분노
# 299   10   10         0           OLD  20230495              아임 히어로 더 파이널
#
#          openDt    salesAmt salesShare salesInten salesChange     salesAcc
# 0    2023-04-12  1467837459       41.3  788457035       116.1  11742599842  \
# 1    2023-03-08   761403353       21.4  506736557         199  49996315086
# 2    2023-04-05   297109742        8.4  158513808       114.4   5506617128
# 3    2023-04-19   238837100        6.7  110527500        86.1    602689500
# 4    2023-04-14   158179565        4.5   74978570        90.1   1206313184
# ..          ...         ...        ...        ...         ...          ...
# 295  2023-03-01    34464872        1.9    9551189        38.3    801844669
# 296  2023-03-02    38870800        2.1   10675500        37.9   6282557300
# 297  2023-03-22    21233692        1.2   -3143783       -12.9    100783943
# 298  2023-03-15    11988185        0.7    3512689        41.4    769832057
# 299  2023-03-01    27048000        1.5     -39000        -0.1   5311157500
#
#     audiCnt audiInten audiChange  audiAcc scrnCnt showCnt  targetDt
# 0    138902     74905        117  1118053    1535    4592  20230422
# 1     74834     50202      203.8  4859965     995    2849  20230422
# 2     30067     15793      110.6   572260     709    1639  20230422
# 3     22358     10154       83.2    58996     314     927  20230422
# 4     16251      7746       91.1   125507     614    1311  20230422
# ..      ...       ...        ...      ...     ...     ...       ...
# 295    3309       824       33.2    77531     219     384  20230324
# 296    2980       724       32.1   510487     174     394  20230324
# 297    2191      -723      -24.8    11186     318     519  20230324
# 298    1164       310       36.3    72691     250     336  20230324
# 299    1127        -2       -0.2   219656      47     118  20230324
#
# [300 rows x 19 columns]
