# %%
import pandas as pd
import numpy as np

# %%
first_df = pd.read_csv('data/data/전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv', encoding='cp949')

# %%
first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
#  20  2015년7월   17 non-null     int64
#  21  2015년8월   17 non-null     int64
# dtypes: int64(21), object(1)
# memory usage: 3.0+ KB

# %%
last_df = pd.read_csv('data/data/주택도시보증공사_전국_평균_분양가격(2019년_12월).csv', encoding='cp949')

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
last_df.head(2)
# Out:
#   지역명        규모구분    연도   월 분양가격(㎡)
# 0  서울          전체  2015  10    5841
# 1  서울  전용면적 60㎡이하  2015  10    5652

# %%
first_df.head(2)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0  서울     18189    17925    17925    18016    18098    19446    18867  \
# 1  부산      8111     8111     9078     8965     9402     9501     9453
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월
# 0    18742    19274  ...     20242     20269    20670    20670    19415  \
# 1     9457     9411  ...      9208      9208     9204     9235     9279
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
#
# [2 rows x 22 columns]

# %%
last_df.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# dtype: int64

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
True + True +False
# Out:
# 2

# %%
first_df.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
# last_df['분양가격(㎡)'].astype(float)
last_df['분양가격'] = pd.to_numeric(last_df['분양가격(㎡)'], errors='coerce')

# %%
last_df.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# 분양가격       378
# dtype: int64

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 203.3+ KB

# %%
type(np.NaN)
# Out:
# float

# %%
last_df['평당분양가격'] = last_df['분양가격'] * 3.3

# %%
last_df['분양가격(㎡)'].describe() ## describe() 해당 칼럼의 정보를 보여줌 // 칼럼 타입이 object일때와 float일때 보여지는 정보가 다름
# Out:
# count     4058
# unique    1753
# top       2221
# freq        17
# Name: 분양가격(㎡), dtype: object

# %%
last_df['분양가격'].describe()
# Out:
# count     3957.000000
# mean      3238.128633
# std       1264.309933
# min       1868.000000
# 25%       2441.000000
# 50%       2874.000000
# 75%       3561.000000
# max      12728.000000
# Name: 분양가격, dtype: float64

# %%
last_df['규모구분'].nunique()
# Out:
# 5

# %%
last_df['규모구분'].unique()
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
## 전용면적은 제거, 초과는 ~, 이하는 제거

# %%
last_df['전용면적'] = last_df['규모구분'].str.replace('전용면적','')
last_df['전용면적'] = last_df['전용면적'].str.replace('초과','~')
last_df['전용면적'] = last_df['전용면적'].str.replace('이하','').str.strip()
last_df['전용면적']
# Out:
# 0              전체
# 1             60㎡
# 2        60㎡~ 85㎡
# 3       85㎡~ 102㎡
# 4           102㎡~
#           ...
# 4330           전체
# 4331          60㎡
# 4332     60㎡~ 85㎡
# 4333    85㎡~ 102㎡
# 4334        102㎡~
# Name: 전용면적, Length: 4335, dtype: object

# %%
## 필요없는 컬럼 제거

# %%
last_df.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당분양가격', '전용면적'], dtype='object')

# %%
last_df.info() #271.1 + KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당분양가격   3957 non-null   float64
#  7   전용면적     4335 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 271.1+ KB

# %%
last_df.drop(columns=['규모구분', '분양가격(㎡)'], inplace=True)

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     4335 non-null   object
#  1   연도      4335 non-null   int64
#  2   월       4335 non-null   int64
#  3   분양가격    3957 non-null   float64
#  4   평당분양가격  3957 non-null   float64
#  5   전용면적    4335 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 203.3+ KB

# %%
last_df.groupby?
# Out:
# Signature:
# last_df.groupby(
#     by=None,
#     axis: 'Axis' = 0,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool' = False,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
#     aligned; see ``.align()`` method). If a list or ndarray of length
#     equal to the selected axis is passed (see the `groupby user guide
#     <https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#splitting-an-object-into-groups>`_),
#     the values are used as-is to determine the groups. A label or list
#     of labels may be passed to group by the columns in ``self``.
#     Notice that a tuple is interpreted as a (single) key.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Split along rows (0) or columns (1). For `Series` this parameter
#     is unused and defaults to 0.
# level : int, level name, or sequence of such, default None
#     If the axis is a MultiIndex (hierarchical), group by a particular
#     level or levels. Do not specify both ``by`` and ``level``.
# as_index : bool, default True
#     For aggregated output, return object with group labels as the
#     index. Only relevant for DataFrame input. as_index=False is
#     effectively "SQL-style" grouped output.
# sort : bool, default True
#     Sort group keys. Get better performance by turning this off.
#     Note this does not influence the order of observations within each
#     group. Groupby preserves the order of rows within each group.
#
#     .. versionchanged:: 2.0.0
#
#         Specifying ``sort=False`` with an ordered categorical grouper will no
#         longer sort the values.
#
# group_keys : bool, default True
#     When calling apply and the ``by`` argument produces a like-indexed
#     (i.e. :ref:`a transform <groupby.transform>`) result, add group keys to
#     index to identify pieces. By default group keys are not included
#     when the result's index (and column) labels match the inputs, and
#     are included otherwise.
#
#     .. versionchanged:: 1.5.0
#
#        Warns that ``group_keys`` will no longer be ignored when the
#        result from ``apply`` is a like-indexed Series or DataFrame.
#        Specify ``group_keys`` explicitly to include the group keys or
#        not.
#
#     .. versionchanged:: 2.0.0
#
#        ``group_keys`` now defaults to ``True``.
#
# observed : bool, default False
#     This only applies if any of the groupers are Categoricals.
#     If True: only show observed values for categorical groupers.
#     If False: show all values for categorical groupers.
# dropna : bool, default True
#     If True, and if group keys contain NA values, NA values together
#     with row/column will be dropped.
#     If False, NA values will also be treated as the key in groups.
#
#     .. versionadded:: 1.1.0
#
# Returns
# -------
# DataFrameGroupBy
#     Returns a groupby object that contains information about the groups.
#
# See Also
# --------
# resample : Convenience method for frequency conversion and resampling
#     of time series.
#
# Notes
# -----
# See the `user guide
# <https://pandas.pydata.org/pandas-docs/stable/groupby.html>`__ for more
# detailed usage and examples, including splitting an object into groups,
# iterating through groups, selecting a group, aggregation, and more.
#
# Examples
# --------
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0
# >>> df.groupby(['Animal']).mean()
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0
#
# **Hierarchical Indexes**
#
# We can groupby different levels of a hierarchical index
# using the `level` parameter:
#
# >>> arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
# ...           ['Captive', 'Wild', 'Captive', 'Wild']]
# >>> index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
# >>> df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
# ...                   index=index)
# >>> df
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0
# >>> df.groupby(level=0).mean()
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0
# >>> df.groupby(level="Type").mean()
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0
#
# We can also choose to include NA in group keys or not by setting
# `dropna` parameter, the default setting is `True`.
#
# >>> l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by=["b"]).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
#
# >>> df.groupby(by=["b"], dropna=False).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
# NaN 1   4
#
# >>> l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by="a").sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
#
# >>> df.groupby(by="a", dropna=False).sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
# NaN 12.3   33.0
#
# When using ``.apply()``, use ``group_keys`` to include or exclude the group keys.
# The ``group_keys`` argument defaults to ``True`` (include).
#
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df.groupby("Animal", group_keys=True).apply(lambda x: x)
#           Animal  Max Speed
# Animal
# Falcon 0  Falcon      380.0
#        1  Falcon      370.0
# Parrot 2  Parrot       24.0
#        3  Parrot       26.0
#
# >>> df.groupby("Animal", group_keys=False).apply(lambda x: x)
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0
# File:      c:\users\admin\appdata\local\programs\python\python311\lib\site-packages\pandas\core\frame.py
# Type:      method

# %%
help(last_df.groupby)
# Out:
# Help on method groupby in module pandas.core.frame:
#
# groupby(by=None, axis: 'Axis' = 0, level: 'IndexLabel | None' = None, as_index: 'bool' = True, sort: 'bool' = True, group_keys: 'bool' = True, observed: 'bool' = False, dropna: 'bool' = True) -> 'DataFrameGroupBy' method of pandas.core.frame.DataFrame instance
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, pd.Grouper or list of such
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
#         will be used to determine the groups (the Series' values are first
#         aligned; see ``.align()`` method). If a list or ndarray of length
#         equal to the selected axis is passed (see the `groupby user guide
#         <https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#splitting-an-object-into-groups>`_),
#         the values are used as-is to determine the groups. A label or list
#         of labels may be passed to group by the columns in ``self``.
#         Notice that a tuple is interpreted as a (single) key.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Split along rows (0) or columns (1). For `Series` this parameter
#         is unused and defaults to 0.
#     level : int, level name, or sequence of such, default None
#         If the axis is a MultiIndex (hierarchical), group by a particular
#         level or levels. Do not specify both ``by`` and ``level``.
#     as_index : bool, default True
#         For aggregated output, return object with group labels as the
#         index. Only relevant for DataFrame input. as_index=False is
#         effectively "SQL-style" grouped output.
#     sort : bool, default True
#         Sort group keys. Get better performance by turning this off.
#         Note this does not influence the order of observations within each
#         group. Groupby preserves the order of rows within each group.
#
#         .. versionchanged:: 2.0.0
#
#             Specifying ``sort=False`` with an ordered categorical grouper will no
#             longer sort the values.
#
#     group_keys : bool, default True
#         When calling apply and the ``by`` argument produces a like-indexed
#         (i.e. :ref:`a transform <groupby.transform>`) result, add group keys to
#         index to identify pieces. By default group keys are not included
#         when the result's index (and column) labels match the inputs, and
#         are included otherwise.
#
#         .. versionchanged:: 1.5.0
#
#            Warns that ``group_keys`` will no longer be ignored when the
#            result from ``apply`` is a like-indexed Series or DataFrame.
#            Specify ``group_keys`` explicitly to include the group keys or
#            not.
#
#         .. versionchanged:: 2.0.0
#
#            ``group_keys`` now defaults to ``True``.
#
#     observed : bool, default False
#         This only applies if any of the groupers are Categoricals.
#         If True: only show observed values for categorical groupers.
#         If False: show all values for categorical groupers.
#     dropna : bool, default True
#         If True, and if group keys contain NA values, NA values together
#         with row/column will be dropped.
#         If False, NA values will also be treated as the key in groups.
#
#         .. versionadded:: 1.1.0
#
#     Returns
#     -------
#     DataFrameGroupBy
#         Returns a groupby object that contains information about the groups.
#
#     See Also
#     --------
#     resample : Convenience method for frequency conversion and resampling
#         of time series.
#
#     Notes
#     -----
#     See the `user guide
#     <https://pandas.pydata.org/pandas-docs/stable/groupby.html>`__ for more
#     detailed usage and examples, including splitting an object into groups,
#     iterating through groups, selecting a group, aggregation, and more.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
#     ...                               'Parrot', 'Parrot'],
#     ...                    'Max Speed': [380., 370., 24., 26.]})
#     >>> df
#        Animal  Max Speed
#     0  Falcon      380.0
#     1  Falcon      370.0
#     2  Parrot       24.0
#     3  Parrot       26.0
#     >>> df.groupby(['Animal']).mean()
#             Max Speed
#     Animal
#     Falcon      375.0
#     Parrot       25.0
#
#     **Hierarchical Indexes**
#
#     We can groupby different levels of a hierarchical index
#     using the `level` parameter:
#
#     >>> arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
#     ...           ['Captive', 'Wild', 'Captive', 'Wild']]
#     >>> index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
#     >>> df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
#     ...                   index=index)
#     >>> df
#                     Max Speed
#     Animal Type
#     Falcon Captive      390.0
#            Wild         350.0
#     Parrot Captive       30.0
#            Wild          20.0
#     >>> df.groupby(level=0).mean()
#             Max Speed
#     Animal
#     Falcon      370.0
#     Parrot       25.0
#     >>> df.groupby(level="Type").mean()
#              Max Speed
#     Type
#     Captive      210.0
#     Wild         185.0
#
#     We can also choose to include NA in group keys or not by setting
#     `dropna` parameter, the default setting is `True`.
#
#     >>> l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
#     >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
#     >>> df.groupby(by=["b"]).sum()
#         a   c
#     b
#     1.0 2   3
#     2.0 2   5
#
#     >>> df.groupby(by=["b"], dropna=False).sum()
#         a   c
#     b
#     1.0 2   3
#     2.0 2   5
#     NaN 1   4
#
#     >>> l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
#     >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
#     >>> df.groupby(by="a").sum()
#         b     c
#     a
#     a   13.0   13.0
#     b   12.3  123.0
#
#     >>> df.groupby(by="a", dropna=False).sum()
#         b     c
#     a
#     a   13.0   13.0
#     b   12.3  123.0
#     NaN 12.3   33.0
#
#     When using ``.apply()``, use ``group_keys`` to include or exclude the group keys.
#     The ``group_keys`` argument defaults to ``True`` (include).
#
#     >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
#     ...                               'Parrot', 'Parrot'],
#     ...                    'Max Speed': [380., 370., 24., 26.]})
#     >>> df.groupby("Animal", group_keys=True).apply(lambda x: x)
#               Animal  Max Speed
#     Animal
#     Falcon 0  Falcon      380.0
#            1  Falcon      370.0
#     Parrot 2  Parrot       24.0
#            3  Parrot       26.0
#
#     >>> df.groupby("Animal", group_keys=False).apply(lambda x: x)
#        Animal  Max Speed
#     0  Falcon      380.0
#     1  Falcon      370.0
#     2  Parrot       24.0
#     3  Parrot       26.0

# %%
def custom():
    '''
    함수 샘플 작성
    
    '''
    a = 'kkk'
    print('ggg')
    return a

# %%
custom?
# Out:
# Signature: custom()
# Docstring: 함수 샘플 작성
# File:      c:\users\admin\appdata\local\temp\ipykernel_4480\1001910268.py
# Type:      function

# %%
last_df.head(3)
# Out:
#   지역명    연도   월    분양가격   평당분양가격      전용면적
# 0  서울  2015  10  5841.0  19275.3        전체
# 1  서울  2015  10  5652.0  18651.6       60㎡
# 2  서울  2015  10  5882.0  19410.6  60㎡~ 85㎡

# %%
last_df.groupby(['지역명'])['평당분양가격'].mean()
# Out:
# 지역명
# 강원     7890.750000
# 경기    13356.895200
# 경남     9268.778138
# 경북     8376.536515
# 광주     9951.535821
# 대구    11980.895455
# 대전    10253.333333
# 부산    12087.121200
# 서울    23599.976400
# 세종     9796.516456
# 울산    10014.902013
# 인천    11915.320732
# 전남     7565.316532
# 전북     7724.235484
# 제주    11241.276712
# 충남     8233.651883
# 충북     7634.655600
# Name: 평당분양가격, dtype: float64

# %%
last_df[last_df['전용면적']=='전체'].groupby(['지역명'])['평당분양가격'].mean()
# Out:
# 지역명
# 강원     7477.536000
# 경기    12559.602000
# 경남     8658.672000
# 경북     8078.532000
# 광주     9903.630000
# 대구    11771.298000
# 대전     9786.018000
# 부산    11936.166000
# 서울    22610.346000
# 세종     9805.422000
# 울산    10492.712195
# 인천    11257.026000
# 전남     7283.562000
# 전북     7292.604000
# 제주    10784.994000
# 충남     7815.324000
# 충북     7219.014000
# Name: 평당분양가격, dtype: float64

# %%
last_df.groupby(['전용면적'])['평당분양가격'].mean()
# Out:
# 전용면적
# 102㎡~        11517.705634
# 60㎡          10375.137421
# 60㎡~ 85㎡     10271.040071
# 85㎡~ 102㎡    11097.599573
# 전체           10276.086207
# Name: 평당분양가격, dtype: float64

# %%
## reset_index() // 인덱스를 컬럼으로 뺄 경우

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().to_frame()
# Out:
#                  평당분양가격
# 전용면적  지역명
# 102㎡~ 강원    8311.380000
#       경기   14771.790000
#       경남   10358.363265
#       경북    9157.302000
#       광주   11041.532432
# ...                 ...
# 전체    전남    7283.562000
#       전북    7292.604000
#       제주   10784.994000
#       충남    7815.324000
#       충북    7219.014000
#
# [85 rows x 1 columns]

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().to_frame().reset_index()
# Out:
#      전용면적 지역명        평당분양가격
# 0   102㎡~  강원   8311.380000
# 1   102㎡~  경기  14771.790000
# 2   102㎡~  경남  10358.363265
# 3   102㎡~  경북   9157.302000
# 4   102㎡~  광주  11041.532432
# ..    ...  ..           ...
# 80     전체  전남   7283.562000
# 81     전체  전북   7292.604000
# 82     전체  제주  10784.994000
# 83     전체  충남   7815.324000
# 84     전체  충북   7219.014000
#
# [85 rows x 3 columns]

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().unstack()
# Out:
# 지역명                 강원         경기            경남           경북            광주
# 전용면적
# 102㎡~      8311.380000  14771.790  10358.363265  9157.302000  11041.532432  \
# 60㎡        7567.098000  13251.744   8689.175000  7883.172000   9430.666667
# 60㎡~ 85㎡   7485.588000  12523.566   8618.676000  8061.372000   9910.692000
# 85㎡~ 102㎡  8749.557143  13677.774  10017.612000  8773.814634   9296.100000
# 전체         7477.536000  12559.602   8658.672000  8078.532000   9903.630000
#
# 지역명                  대구            대전         부산         서울            세종
# 전용면적
# 102㎡~      13087.338000  14876.871429  13208.250  23446.038  10106.976000  \
# 60㎡        11992.068000   9176.475000  11353.782  23212.794   9323.927027
# 60㎡~ 85㎡   11778.690000   9711.372000  11864.820  22786.830   9775.458000
# 85㎡~ 102㎡  11140.642857   9037.430769  12072.588  25943.874   9847.926000
# 전체         11771.298000   9786.018000  11936.166  22610.346   9805.422000
#
# 지역명                  울산            인천         전남          전북            제주
# 전용면적
# 102㎡~       9974.448000  14362.030435  8168.4900  8193.57000  10522.787234  \
# 60㎡         9202.106897  11241.318000  7210.1700  7609.93200  14022.221053
# 60㎡~ 85㎡   10502.531707  11384.406000  7269.2400  7271.35200  10621.314000
# 85㎡~ 102㎡   8861.007692  11527.560000  7908.8625  8275.78125  10709.082353
# 전체         10492.712195  11257.026000  7283.5620  7292.60400  10784.994000
#
# 지역명                 충남        충북
# 전용면적
# 102㎡~      8689.169388  8195.352
# 60㎡        7911.156000  7103.118
# 60㎡~ 85㎡   7818.954000  7264.488
# 85㎡~ 102㎡  9120.045000  8391.306
# 전체         7815.324000  7219.014

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().unstack().T  ##.transpose()도 동일함 // 컬럼과 인덱스 교환
# Out:
# 전용면적         102㎡~           60㎡      60㎡~ 85㎡     85㎡~ 102㎡            전체
# 지역명
# 강원     8311.380000   7567.098000   7485.588000   8749.557143   7477.536000
# 경기    14771.790000  13251.744000  12523.566000  13677.774000  12559.602000
# 경남    10358.363265   8689.175000   8618.676000  10017.612000   8658.672000
# 경북     9157.302000   7883.172000   8061.372000   8773.814634   8078.532000
# 광주    11041.532432   9430.666667   9910.692000   9296.100000   9903.630000
# 대구    13087.338000  11992.068000  11778.690000  11140.642857  11771.298000
# 대전    14876.871429   9176.475000   9711.372000   9037.430769   9786.018000
# 부산    13208.250000  11353.782000  11864.820000  12072.588000  11936.166000
# 서울    23446.038000  23212.794000  22786.830000  25943.874000  22610.346000
# 세종    10106.976000   9323.927027   9775.458000   9847.926000   9805.422000
# 울산     9974.448000   9202.106897  10502.531707   8861.007692  10492.712195
# 인천    14362.030435  11241.318000  11384.406000  11527.560000  11257.026000
# 전남     8168.490000   7210.170000   7269.240000   7908.862500   7283.562000
# 전북     8193.570000   7609.932000   7271.352000   8275.781250   7292.604000
# 제주    10522.787234  14022.221053  10621.314000  10709.082353  10784.994000
# 충남     8689.169388   7911.156000   7818.954000   9120.045000   7815.324000
# 충북     8195.352000   7103.118000   7264.488000   8391.306000   7219.014000

# %%
df = pd.DataFrame({'col_1':[1,2]}, index=['one','two'])
df
# Out:
#      col_1
# one      1
# two      2

# %%
df.stack() ## stack //  컬럼을 인덱스로 보내는 것
# Out:
# one  col_1    1
# two  col_1    2
# dtype: int64

# %%
## unstack // 인덱스로 되어있는것을 컬럼으로 빼는 것

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().unstack(level=0)
# Out:
# 전용면적         102㎡~           60㎡      60㎡~ 85㎡     85㎡~ 102㎡            전체
# 지역명
# 강원     8311.380000   7567.098000   7485.588000   8749.557143   7477.536000
# 경기    14771.790000  13251.744000  12523.566000  13677.774000  12559.602000
# 경남    10358.363265   8689.175000   8618.676000  10017.612000   8658.672000
# 경북     9157.302000   7883.172000   8061.372000   8773.814634   8078.532000
# 광주    11041.532432   9430.666667   9910.692000   9296.100000   9903.630000
# 대구    13087.338000  11992.068000  11778.690000  11140.642857  11771.298000
# 대전    14876.871429   9176.475000   9711.372000   9037.430769   9786.018000
# 부산    13208.250000  11353.782000  11864.820000  12072.588000  11936.166000
# 서울    23446.038000  23212.794000  22786.830000  25943.874000  22610.346000
# 세종    10106.976000   9323.927027   9775.458000   9847.926000   9805.422000
# 울산     9974.448000   9202.106897  10502.531707   8861.007692  10492.712195
# 인천    14362.030435  11241.318000  11384.406000  11527.560000  11257.026000
# 전남     8168.490000   7210.170000   7269.240000   7908.862500   7283.562000
# 전북     8193.570000   7609.932000   7271.352000   8275.781250   7292.604000
# 제주    10522.787234  14022.221053  10621.314000  10709.082353  10784.994000
# 충남     8689.169388   7911.156000   7818.954000   9120.045000   7815.324000
# 충북     8195.352000   7103.118000   7264.488000   8391.306000   7219.014000

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().unstack(level=1)
# Out:
# 지역명                 강원         경기            경남           경북            광주
# 전용면적
# 102㎡~      8311.380000  14771.790  10358.363265  9157.302000  11041.532432  \
# 60㎡        7567.098000  13251.744   8689.175000  7883.172000   9430.666667
# 60㎡~ 85㎡   7485.588000  12523.566   8618.676000  8061.372000   9910.692000
# 85㎡~ 102㎡  8749.557143  13677.774  10017.612000  8773.814634   9296.100000
# 전체         7477.536000  12559.602   8658.672000  8078.532000   9903.630000
#
# 지역명                  대구            대전         부산         서울            세종
# 전용면적
# 102㎡~      13087.338000  14876.871429  13208.250  23446.038  10106.976000  \
# 60㎡        11992.068000   9176.475000  11353.782  23212.794   9323.927027
# 60㎡~ 85㎡   11778.690000   9711.372000  11864.820  22786.830   9775.458000
# 85㎡~ 102㎡  11140.642857   9037.430769  12072.588  25943.874   9847.926000
# 전체         11771.298000   9786.018000  11936.166  22610.346   9805.422000
#
# 지역명                  울산            인천         전남          전북            제주
# 전용면적
# 102㎡~       9974.448000  14362.030435  8168.4900  8193.57000  10522.787234  \
# 60㎡         9202.106897  11241.318000  7210.1700  7609.93200  14022.221053
# 60㎡~ 85㎡   10502.531707  11384.406000  7269.2400  7271.35200  10621.314000
# 85㎡~ 102㎡   8861.007692  11527.560000  7908.8625  8275.78125  10709.082353
# 전체         10492.712195  11257.026000  7283.5620  7292.60400  10784.994000
#
# 지역명                 충남        충북
# 전용면적
# 102㎡~      8689.169388  8195.352
# 60㎡        7911.156000  7103.118
# 60㎡~ 85㎡   7818.954000  7264.488
# 85㎡~ 102㎡  9120.045000  8391.306
# 전체         7815.324000  7219.014

# %%
## unstack에서 level을 이용해 여러 인덱스 중 내가 컬렴으로 올리고 싶은 것만 올릴수 있음

# %%
last_df.groupby(['전용면적','지역명'])['평당분양가격'].mean().unstack(level=1).round()
# Out:
# 지역명            강원       경기       경남      경북       광주       대구       대전
# 전용면적
# 102㎡~      8311.0  14772.0  10358.0  9157.0  11042.0  13087.0  14877.0  \
# 60㎡        7567.0  13252.0   8689.0  7883.0   9431.0  11992.0   9176.0
# 60㎡~ 85㎡   7486.0  12524.0   8619.0  8061.0   9911.0  11779.0   9711.0
# 85㎡~ 102㎡  8750.0  13678.0  10018.0  8774.0   9296.0  11141.0   9037.0
# 전체         7478.0  12560.0   8659.0  8079.0   9904.0  11771.0   9786.0
#
# 지역명             부산       서울       세종       울산       인천      전남      전북
# 전용면적
# 102㎡~      13208.0  23446.0  10107.0   9974.0  14362.0  8168.0  8194.0  \
# 60㎡        11354.0  23213.0   9324.0   9202.0  11241.0  7210.0  7610.0
# 60㎡~ 85㎡   11865.0  22787.0   9775.0  10503.0  11384.0  7269.0  7271.0
# 85㎡~ 102㎡  12073.0  25944.0   9848.0   8861.0  11528.0  7909.0  8276.0
# 전체         11936.0  22610.0   9805.0  10493.0  11257.0  7284.0  7293.0
#
# 지역명             제주      충남      충북
# 전용면적
# 102㎡~      10523.0  8689.0  8195.0
# 60㎡        14022.0  7911.0  7103.0
# 60㎡~ 85㎡   10621.0  7819.0  7264.0
# 85㎡~ 102㎡  10709.0  9120.0  8391.0
# 전체         10785.0  7815.0  7219.0

# %%
## 연도별 지역별 평당분양가격

# %%
last_df.groupby(['지역명','연도'])['평당분양가격'].mean().unstack()
# Out:
# 연도        2015          2016          2017          2018          2019
# 지역명
# 강원    7188.060   7162.903846   7273.560000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12304.980000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8786.760000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8280.800000   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9613.977551   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12206.700000  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9957.158491  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11560.680000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21831.060000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.505556  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10666.935714  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11640.600000  11881.532143  13249.775000
# 전남    6798.880   6936.600000   7372.920000   7929.845000   8219.275862
# 전북    7110.400   6906.625000   7398.973585   8174.595000   8532.260000
# 제주    7951.075   9567.480000  12566.730000  11935.968000  11828.469231
# 충남    7689.880   7958.225000   8198.422222   8201.820000   8748.840000
# 충북    6828.800   7133.335000   7473.120000   8149.295000   7970.875000

# %%
## 지역별 평당분양가격 평균 피벗테이블

# %%
last_df.pivot_table(index='지역명', values='평당분양가격', aggfunc='mean')
# Out:
#            평당분양가격
# 지역명
# 강원    7890.750000
# 경기   13356.895200
# 경남    9268.778138
# 경북    8376.536515
# 광주    9951.535821
# 대구   11980.895455
# 대전   10253.333333
# 부산   12087.121200
# 서울   23599.976400
# 세종    9796.516456
# 울산   10014.902013
# 인천   11915.320732
# 전남    7565.316532
# 전북    7724.235484
# 제주   11241.276712
# 충남    8233.651883
# 충북    7634.655600

# %%
## 지역별 평당분양가격 가장 큰 가격

# %%
last_df.pivot_table(index='지역명', values='평당분양가격', aggfunc='max')
# Out:
#       평당분양가격
# 지역명
# 강원   11873.4
# 경기   18711.0
# 경남   14199.9
# 경북   11408.1
# 광주   16107.3
# 대구   17021.4
# 대전   16094.1
# 부산   15255.9
# 서울   42002.4
# 세종   12972.3
# 울산   11860.2
# 인천   17120.4
# 전남   10074.9
# 전북   10071.6
# 제주   18024.6
# 충남   10563.3
# 충북    9421.5

# %%
## 전용면적별 평당 분양가격
last_df.pivot_table(index='전용면적', values='평당분양가격', aggfunc='mean')
# Out:
#                  평당분양가격
# 전용면적
# 102㎡~      11517.705634
# 60㎡        10375.137421
# 60㎡~ 85㎡   10271.040071
# 85㎡~ 102㎡  11097.599573
# 전체         10276.086207

# %%
last_df.groupby(['지역명','전용면적'])['평당분양가격'].mean().unstack(level=0).round()
# Out:
# 지역명            강원       경기       경남      경북       광주       대구       대전
# 전용면적
# 102㎡~      8311.0  14772.0  10358.0  9157.0  11042.0  13087.0  14877.0  \
# 60㎡        7567.0  13252.0   8689.0  7883.0   9431.0  11992.0   9176.0
# 60㎡~ 85㎡   7486.0  12524.0   8619.0  8061.0   9911.0  11779.0   9711.0
# 85㎡~ 102㎡  8750.0  13678.0  10018.0  8774.0   9296.0  11141.0   9037.0
# 전체         7478.0  12560.0   8659.0  8079.0   9904.0  11771.0   9786.0
#
# 지역명             부산       서울       세종       울산       인천      전남      전북
# 전용면적
# 102㎡~      13208.0  23446.0  10107.0   9974.0  14362.0  8168.0  8194.0  \
# 60㎡        11354.0  23213.0   9324.0   9202.0  11241.0  7210.0  7610.0
# 60㎡~ 85㎡   11865.0  22787.0   9775.0  10503.0  11384.0  7269.0  7271.0
# 85㎡~ 102㎡  12073.0  25944.0   9848.0   8861.0  11528.0  7909.0  8276.0
# 전체         11936.0  22610.0   9805.0  10493.0  11257.0  7284.0  7293.0
#
# 지역명             제주      충남      충북
# 전용면적
# 102㎡~      10523.0  8689.0  8195.0
# 60㎡        14022.0  7911.0  7103.0
# 60㎡~ 85㎡   10621.0  7819.0  7264.0
# 85㎡~ 102㎡  10709.0  9120.0  8391.0
# 전체         10785.0  7815.0  7219.0

# %%
last_df.pivot_table(index='전용면적', columns='지역명', values='평당분양가격')
# Out:
# 지역명                 강원         경기            경남           경북            광주
# 전용면적
# 102㎡~      8311.380000  14771.790  10358.363265  9157.302000  11041.532432  \
# 60㎡        7567.098000  13251.744   8689.175000  7883.172000   9430.666667
# 60㎡~ 85㎡   7485.588000  12523.566   8618.676000  8061.372000   9910.692000
# 85㎡~ 102㎡  8749.557143  13677.774  10017.612000  8773.814634   9296.100000
# 전체         7477.536000  12559.602   8658.672000  8078.532000   9903.630000
#
# 지역명                  대구            대전         부산         서울            세종
# 전용면적
# 102㎡~      13087.338000  14876.871429  13208.250  23446.038  10106.976000  \
# 60㎡        11992.068000   9176.475000  11353.782  23212.794   9323.927027
# 60㎡~ 85㎡   11778.690000   9711.372000  11864.820  22786.830   9775.458000
# 85㎡~ 102㎡  11140.642857   9037.430769  12072.588  25943.874   9847.926000
# 전체         11771.298000   9786.018000  11936.166  22610.346   9805.422000
#
# 지역명                  울산            인천         전남          전북            제주
# 전용면적
# 102㎡~       9974.448000  14362.030435  8168.4900  8193.57000  10522.787234  \
# 60㎡         9202.106897  11241.318000  7210.1700  7609.93200  14022.221053
# 60㎡~ 85㎡   10502.531707  11384.406000  7269.2400  7271.35200  10621.314000
# 85㎡~ 102㎡   8861.007692  11527.560000  7908.8625  8275.78125  10709.082353
# 전체         10492.712195  11257.026000  7283.5620  7292.60400  10784.994000
#
# 지역명                 충남        충북
# 전용면적
# 102㎡~      8689.169388  8195.352
# 60㎡        7911.156000  7103.118
# 60㎡~ 85㎡   7818.954000  7264.488
# 85㎡~ 102㎡  9120.045000  8391.306
# 전체         7815.324000  7219.014

# %%
## groupby는 Series로 리턴
## pivot_table은 DataFrame으로 리턴

# %%
import matplotlib.pyplot as plt

# %%
## 지역별 평당 분양가격의 평균값을 선 그래프로 작성

# %%
g = last_df.groupby(['지역명'])['평당분양가격'].mean().to_frame()
g
# Out:
#            평당분양가격
# 지역명
# 강원    7890.750000
# 경기   13356.895200
# 경남    9268.778138
# 경북    8376.536515
# 광주    9951.535821
# 대구   11980.895455
# 대전   10253.333333
# 부산   12087.121200
# 서울   23599.976400
# 세종    9796.516456
# 울산   10014.902013
# 인천   11915.320732
# 전남    7565.316532
# 전북    7724.235484
# 제주   11241.276712
# 충남    8233.651883
# 충북    7634.655600

# %%
g.plot()
# Out:
# <AxesSubplot: xlabel='지역명'>

# %%
g.plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='지역명'>

# %%
g.plot.bar(figsize=(10,3), rot=0)
# Out:
# <AxesSubplot: xlabel='지역명'>

# %%
## 지역별 평당분양가격을 그래프로... 분양가격이 높은 순서대로
g = last_df.groupby(['지역명'])['평당분양가격'].mean().sort_values(ascending=False).to_frame()
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot: xlabel='지역명'>

# %%
# 연도별 평당분양가격 분양가격이 높은 순서대로

# %%
g = last_df.groupby(['연도'])['평당분양가격'].mean().sort_values(ascending=False).to_frame()

# %%
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot: xlabel='연도'>

# %%
## 연도별 평당분양가격 박스플롯으로 작성

# %%
g.T.plot.box()
# Out:
# <AxesSubplot: >

# %%
g.T
# Out:
# 연도              2019          2018          2017      2016         2015
# 평당분양가격  12188.293092  10978.938411  10360.487653  9683.025  9202.735802

# %%
g = last_df.pivot_table(index='월',columns='연도',values='평당분양가격')
g
# Out:
# 연도         2015          2016          2017          2018          2019
# 월
# 1           NaN   9334.029630  10095.132143  10719.148000  11535.540789
# 2           NaN   9361.440000  10110.885714  10766.668000  11574.793421
# 3           NaN   9423.276923  10107.428571  10905.488000  11610.094737
# 4           NaN   9601.993902  10217.232143  10920.728571  11777.876000
# 5           NaN   9602.396341  10358.819277  11087.485714  11976.394737
# 6           NaN   9676.042683  10431.618072  10921.928571  12401.884000
# 7           NaN   9700.551220  10549.536585  10868.376316  12424.852000
# 8           NaN   9719.023171  10564.869512  10811.147368  12523.896000
# 9           NaN   9737.656098  10583.601266  10915.257692  12527.571429
# 10  9086.488889   9924.225882  10399.845570  11133.269231  12619.073077
# 11  9218.122222   9972.757143           NaN  11224.762025  12647.785714
# 12  9303.596296  10092.264286  10597.620000  11453.822368  12622.847368

# %%
g.plot.box(figsize=(10,3))
# Out:
# <AxesSubplot: >

# %%
## 전용면적별 박스플롯 그려보기

# %%
g = last_df.pivot_table(index='월',columns='전용면적',values='평당분양가격')

# %%
g.plot.box(figsize=(10,3))
# Out:
# <AxesSubplot: >

# %%
## 연도별 평당분양가격 파이그래프 그려보기

# %%
g = last_df.pivot_table(index='연도',values='평당분양가격')

# %%
g['평당분양가격'].plot.pie()
# Out:
# <AxesSubplot: ylabel='평당분양가격'>

# %%
import seaborn as sns

# %%
sorted_df = last_df.sort_values('평당분양가격', ascending=False)
# sorted_df

# %%
sns.barplot(data=last_df, x='지역명', y='평당분양가격')
# Out:
# <AxesSubplot: xlabel='지역명', ylabel='평당분양가격'>

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=sorted_df, x='지역명', y='평당분양가격')
# Out:
# <AxesSubplot: xlabel='지역명', ylabel='평당분양가격'>

# %%
sns.catplot(data=last_df, x='연도', y='평당분양가격', kind='violin', col='지역명', col_wrap=4)

# %%
sns.relplot(data=last_df, x='연도', y='평당분양가격', kind='scatter', col='지역명', col_wrap=4, hue='월')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=last_df, x='연도', y='평당분양가격', hue='지역명')
plt.legend(bbox_to_anchor=(0,1), loc=2)

# %%
sorted_df = last_df.pivot_table(index='지역명', values='평당분양가격').sort_values('평당분양가격', ascending=False).reset_index()
sorted_df
# Out:
#    지역명        평당분양가격
# 0   서울  23599.976400
# 1   경기  13356.895200
# 2   부산  12087.121200
# 3   대구  11980.895455
# 4   인천  11915.320732
# 5   제주  11241.276712
# 6   대전  10253.333333
# 7   울산  10014.902013
# 8   광주   9951.535821
# 9   세종   9796.516456
# 10  경남   9268.778138
# 11  경북   8376.536515
# 12  충남   8233.651883
# 13  강원   7890.750000
# 14  전북   7724.235484
# 15  충북   7634.655600
# 16  전남   7565.316532

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=sorted_df, x='지역명', y='평당분양가격')
# Out:
# <AxesSubplot: xlabel='지역명', ylabel='평당분양가격'>

# %%
first_df.head(2)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0  서울     18189    17925    17925    18016    18098    19446    18867  \
# 1  부산      8111     8111     9078     8965     9402     9501     9453
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월
# 0    18742    19274  ...     20242     20269    20670    20670    19415  \
# 1     9457     9411  ...      9208      9208     9204     9235     9279
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
#
# [2 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None) ## 중간 줄임표시 없이 다 보이게
pd.set_option('display.max_rows', None) ## 처리할 양이 지나치게 많은 경우 렉이 걸리거나 주피터 랩이 멈추는 경우도 발생

# %%
first_df
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월
# 0   서울     18189    17925    17925    18016    18098    19446    18867  \
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월
# 0     18742    19274    19404     19759     20242     20269    20670    20670  \
# 1      9457     9411     9258      9110      9208      9208     9204     9235
# 2      8360     8370     8449      8403      8439      8253     8327     8416
# 3      9974     9973     9973     10016     10020     10020    10017     9876
# 4      7612     7622     7802      7707      7752      7748     7752     7756
# 5      8333     8333     8048      8038      8067      8067     8067     8067
# 6      8153     8493     8493      8627      8891      8891     8526     8526
# 7     10124    10134    10501     10397     10356     10379    10391    10355
# 8      8067     8141     8282      8527      8592      8560     8560     8560
# 9      6268     6268     6419      6631      6365      6365     6348     6350
# 10     6586     6586     6584      6529      6724      6743     6749     6747
# 11     6805     6914     6882      6831      6940      6989     6976     6980
# 12     6319     6436     6719      6581      6583      6583     6583     6583
# 13     5780     5685     5804      5753      5768      5784     5784     5833
# 14     6556     6563     6577      6778      6881      6989     6992     6953
# 15     6613     6606     6767      6881      7125      7332     7592     7588
# 16     7914     7914     7833      7724      7724      7739     7739     7739
#
#     2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0     19415    18842    18367    18374    18152    18443
# 1      9279     9327     9345     9515     9559     9581
# 2      8441     8446     8568     8542     8542     8795
# 3      9876     9938    10551    10443    10443    10449
# 4      7861     7914     7877     7881     8089     8231
# 5      8067     8145     8272     8079     8079     8079
# 6      8629     9380     9192     9190     9190     9215
# 7     10469    10684    10685    10573    10518    10573
# 8      8555     8546     8546     8671     8669     8695
# 9      6182     6924     6846     6986     7019     7008
# 10     6783     6790     6805     6682     6601     6603
# 11     7161     7017     6975     6939     6935     6942
# 12     6542     6551     6556     6601     6750     6580
# 13     5825     5940     6050     6243     6286     6289
# 14     6997     7006     6966     6887     7035     7037
# 15     7668     7683     7717     7715     7723     7665
# 16     7826     7285     7285     7343     7343     7343

# %%
last_df
# Out:
#      지역명    연도   월     분양가격   평당분양가격       전용면적
# 0     서울  2015  10   5841.0  19275.3         전체
# 1     서울  2015  10   5652.0  18651.6        60㎡
# 2     서울  2015  10   5882.0  19410.6   60㎡~ 85㎡
# 3     서울  2015  10   5721.0  18879.3  85㎡~ 102㎡
# 4     서울  2015  10   5879.0  19400.7      102㎡~
# 5     인천  2015  10   3163.0  10437.9         전체
# 6     인천  2015  10   3488.0  11510.4        60㎡
# 7     인천  2015  10   3119.0  10292.7   60㎡~ 85㎡
# 8     인천  2015  10   3545.0  11698.5  85㎡~ 102㎡
# 9     인천  2015  10   3408.0  11246.4      102㎡~
# 10    경기  2015  10   3138.0  10355.4         전체
# 11    경기  2015  10   3126.0  10315.8        60㎡
# 12    경기  2015  10   3239.0  10688.7   60㎡~ 85㎡
# 13    경기  2015  10   3496.0  11536.8  85㎡~ 102㎡
# 14    경기  2015  10   3680.0  12144.0      102㎡~
# 15    부산  2015  10   3112.0  10269.6         전체
# 16    부산  2015  10   2950.0   9735.0        60㎡
# 17    부산  2015  10   2999.0   9896.7   60㎡~ 85㎡
# 18    부산  2015  10   2957.0   9758.1  85㎡~ 102㎡
# 19    부산  2015  10   3500.0  11550.0      102㎡~
# 20    대구  2015  10   2682.0   8850.6         전체
# 21    대구  2015  10   2614.0   8626.2        60㎡
# 22    대구  2015  10   2696.0   8896.8   60㎡~ 85㎡
# 23    대구  2015  10   2557.0   8438.1  85㎡~ 102㎡
# 24    대구  2015  10   2598.0   8573.4      102㎡~
# 25    광주  2015  10   2420.0   7986.0         전체
# 26    광주  2015  10   2253.0   7434.9        60㎡
# 27    광주  2015  10   2439.0   8048.7   60㎡~ 85㎡
# 28    광주  2015  10      NaN      NaN  85㎡~ 102㎡
# 29    광주  2015  10      NaN      NaN      102㎡~
# 30    대전  2015  10   2454.0   8098.2         전체
# 31    대전  2015  10   2585.0   8530.5        60㎡
# 32    대전  2015  10   2428.0   8012.4   60㎡~ 85㎡
# 33    대전  2015  10   2461.0   8121.3  85㎡~ 102㎡
# 34    대전  2015  10      NaN      NaN      102㎡~
# 35    울산  2015  10   3053.0  10074.9         전체
# 36    울산  2015  10   2422.0   7992.6        60㎡
# 37    울산  2015  10   3040.0  10032.0   60㎡~ 85㎡
# 38    울산  2015  10   2951.0   9738.3  85㎡~ 102㎡
# 39    울산  2015  10   2690.0   8877.0      102㎡~
# 40    세종  2015  10   2642.0   8718.6         전체
# 41    세종  2015  10   2572.0   8487.6        60㎡
# 42    세종  2015  10   2657.0   8768.1   60㎡~ 85㎡
# 43    세종  2015  10   2644.0   8725.2  85㎡~ 102㎡
# 44    세종  2015  10   2692.0   8883.6      102㎡~
# 45    강원  2015  10   2167.0   7151.1         전체
# 46    강원  2015  10   2286.0   7543.8        60㎡
# 47    강원  2015  10   2212.0   7299.6   60㎡~ 85㎡
# 48    강원  2015  10   2061.0   6801.3  85㎡~ 102㎡
# 49    강원  2015  10   2171.0   7164.3      102㎡~
# 50    충북  2015  10   2032.0   6705.6         전체
# 51    충북  2015  10   1919.0   6332.7        60㎡
# 52    충북  2015  10   2033.0   6708.9   60㎡~ 85㎡
# 53    충북  2015  10   2102.0   6936.6  85㎡~ 102㎡
# 54    충북  2015  10   2369.0   7817.7      102㎡~
# 55    충남  2015  10   2099.0   6926.7         전체
# 56    충남  2015  10   2206.0   7279.8        60㎡
# 57    충남  2015  10   2101.0   6933.3   60㎡~ 85㎡
# 58    충남  2015  10   2743.0   9051.9  85㎡~ 102㎡
# 59    충남  2015  10   2442.0   8058.6      102㎡~
# 60    전북  2015  10   2054.0   6778.2         전체
# 61    전북  2015  10   2127.0   7019.1        60㎡
# 62    전북  2015  10   2056.0   6784.8   60㎡~ 85㎡
# 63    전북  2015  10   2377.0   7844.1  85㎡~ 102㎡
# 64    전북  2015  10   2250.0   7425.0      102㎡~
# 65    전남  2015  10   1925.0   6352.5         전체
# 66    전남  2015  10   1999.0   6596.7        60㎡
# 67    전남  2015  10   1922.0   6342.6   60㎡~ 85㎡
# 68    전남  2015  10   2262.0   7464.6  85㎡~ 102㎡
# 69    전남  2015  10   2292.0   7563.6      102㎡~
# 70    경북  2015  10   2148.0   7088.4         전체
# 71    경북  2015  10   2204.0   7273.2        60㎡
# 72    경북  2015  10   2145.0   7078.5   60㎡~ 85㎡
# 73    경북  2015  10   2308.0   7616.4  85㎡~ 102㎡
# 74    경북  2015  10   2222.0   7332.6      102㎡~
# 75    경남  2015  10   2291.0   7560.3         전체
# 76    경남  2015  10   2239.0   7388.7        60㎡
# 77    경남  2015  10   2305.0   7606.5   60㎡~ 85㎡
# 78    경남  2015  10   2890.0   9537.0  85㎡~ 102㎡
# 79    경남  2015  10   3014.0   9946.2      102㎡~
# 80    제주  2015  10   2232.0   7365.6         전체
# 81    제주  2015  10      NaN      NaN        60㎡
# 82    제주  2015  10   2225.0   7342.5   60㎡~ 85㎡
# 83    제주  2015  10   2583.0   8523.9  85㎡~ 102㎡
# 84    제주  2015  10   2574.0   8494.2      102㎡~
# 85    서울  2015  11   6050.0  19965.0         전체
# 86    서울  2015  11   6320.0  20856.0        60㎡
# 87    서울  2015  11   5964.0  19681.2   60㎡~ 85㎡
# 88    서울  2015  11   7092.0  23403.6  85㎡~ 102㎡
# 89    서울  2015  11   6551.0  21618.3      102㎡~
# 90    인천  2015  11   3184.0  10507.2         전체
# 91    인천  2015  11   3328.0  10982.4        60㎡
# 92    인천  2015  11   3119.0  10292.7   60㎡~ 85㎡
# 93    인천  2015  11   3545.0  11698.5  85㎡~ 102㎡
# 94    인천  2015  11   3408.0  11246.4      102㎡~
# 95    경기  2015  11   3098.0  10223.4         전체
# 96    경기  2015  11   3079.0  10160.7        60㎡
# 97    경기  2015  11   3202.0  10566.6   60㎡~ 85㎡
# 98    경기  2015  11   3391.0  11190.3  85㎡~ 102㎡
# 99    경기  2015  11   3724.0  12289.2      102㎡~
# 100   부산  2015  11   3131.0  10332.3         전체
# 101   부산  2015  11   2982.0   9840.6        60㎡
# 102   부산  2015  11   3037.0  10022.1   60㎡~ 85㎡
# 103   부산  2015  11   2957.0   9758.1  85㎡~ 102㎡
# 104   부산  2015  11   3739.0  12338.7      102㎡~
# 105   대구  2015  11   2749.0   9071.7         전체
# 106   대구  2015  11   2503.0   8259.9        60㎡
# 107   대구  2015  11   2806.0   9259.8   60㎡~ 85㎡
# 108   대구  2015  11   2557.0   8438.1  85㎡~ 102㎡
# 109   대구  2015  11   2743.0   9051.9      102㎡~
# 110   광주  2015  11   2424.0   7999.2         전체
# 111   광주  2015  11   2251.0   7428.3        60㎡
# 112   광주  2015  11   2444.0   8065.2   60㎡~ 85㎡
# 113   광주  2015  11      NaN      NaN  85㎡~ 102㎡
# 114   광주  2015  11      NaN      NaN      102㎡~
# 115   대전  2015  11   2454.0   8098.2         전체
# 116   대전  2015  11   2585.0   8530.5        60㎡
# 117   대전  2015  11   2428.0   8012.4   60㎡~ 85㎡
# 118   대전  2015  11   2461.0   8121.3  85㎡~ 102㎡
# 119   대전  2015  11      NaN      NaN      102㎡~
# 120   울산  2015  11   3043.0  10041.9         전체
# 121   울산  2015  11   2584.0   8527.2        60㎡
# 122   울산  2015  11   3048.0  10058.4   60㎡~ 85㎡
# 123   울산  2015  11   2663.0   8787.9  85㎡~ 102㎡
# 124   울산  2015  11   2874.0   9484.2      102㎡~
# 125   세종  2015  11   2648.0   8738.4         전체
# 126   세종  2015  11   2572.0   8487.6        60㎡
# 127   세종  2015  11   2666.0   8797.8   60㎡~ 85㎡
# 128   세종  2015  11   2644.0   8725.2  85㎡~ 102㎡
# 129   세종  2015  11   2749.0   9071.7      102㎡~
# 130   강원  2015  11   2171.0   7164.3         전체
# 131   강원  2015  11   2292.0   7563.6        60㎡
# 132   강원  2015  11   2193.0   7236.9   60㎡~ 85㎡
# 133   강원  2015  11   2061.0   6801.3  85㎡~ 102㎡
# 134   강원  2015  11   2171.0   7164.3      102㎡~
# 135   충북  2015  11   2004.0   6613.2         전체
# 136   충북  2015  11   1921.0   6339.3        60㎡
# 137   충북  2015  11   2015.0   6649.5   60㎡~ 85㎡
# 138   충북  2015  11   1868.0   6164.4  85㎡~ 102㎡
# 139   충북  2015  11   2277.0   7514.1      102㎡~
# 140   충남  2015  11   2100.0   6930.0         전체
# 141   충남  2015  11   2214.0   7306.2        60㎡
# 142   충남  2015  11   2105.0   6946.5   60㎡~ 85㎡
# 143   충남  2015  11   2523.0   8325.9  85㎡~ 102㎡
# 144   충남  2015  11   2468.0   8144.4      102㎡~
# 145   전북  2015  11   2057.0   6788.1         전체
# 146   전북  2015  11   2129.0   7025.7        60㎡
# 147   전북  2015  11   2057.0   6788.1   60㎡~ 85㎡
# 148   전북  2015  11   2377.0   7844.1  85㎡~ 102㎡
# 149   전북  2015  11   2282.0   7530.6      102㎡~
# 150   전남  2015  11   1909.0   6299.7         전체
# 151   전남  2015  11   1999.0   6596.7        60㎡
# 152   전남  2015  11   1906.0   6289.8   60㎡~ 85㎡
# 153   전남  2015  11   2262.0   7464.6  85㎡~ 102㎡
# 154   전남  2015  11   2176.0   7180.8      102㎡~
# 155   경북  2015  11   2190.0   7227.0         전체
# 156   경북  2015  11   2210.0   7293.0        60㎡
# 157   경북  2015  11   2186.0   7213.8   60㎡~ 85㎡
# 158   경북  2015  11   2516.0   8302.8  85㎡~ 102㎡
# 159   경북  2015  11   2370.0   7821.0      102㎡~
# 160   경남  2015  11   2298.0   7583.4         전체
# 161   경남  2015  11   2200.0   7260.0        60㎡
# 162   경남  2015  11   2322.0   7662.6   60㎡~ 85㎡
# 163   경남  2015  11   2980.0   9834.0  85㎡~ 102㎡
# 164   경남  2015  11   3043.0  10041.9      102㎡~
# 165   제주  2015  11   2232.0   7365.6         전체
# 166   제주  2015  11      NaN      NaN        60㎡
# 167   제주  2015  11   2225.0   7342.5   60㎡~ 85㎡
# 168   제주  2015  11   2583.0   8523.9  85㎡~ 102㎡
# 169   제주  2015  11   2574.0   8494.2      102㎡~
# 170   서울  2015  12   6041.0  19935.3         전체
# 171   서울  2015  12   6321.0  20859.3        60㎡
# 172   서울  2015  12   5966.0  19687.8   60㎡~ 85㎡
# 173   서울  2015  12   6513.0  21492.9  85㎡~ 102㎡
# 174   서울  2015  12   6551.0  21618.3      102㎡~
# 175   인천  2015  12   3184.0  10507.2         전체
# 176   인천  2015  12   3328.0  10982.4        60㎡
# 177   인천  2015  12   3119.0  10292.7   60㎡~ 85㎡
# 178   인천  2015  12   3545.0  11698.5  85㎡~ 102㎡
# 179   인천  2015  12   3408.0  11246.4      102㎡~
# 180   경기  2015  12   3198.0  10553.4         전체
# 181   경기  2015  12   3293.0  10866.9        60㎡
# 182   경기  2015  12   3314.0  10936.2   60㎡~ 85㎡
# 183   경기  2015  12   3449.0  11381.7  85㎡~ 102㎡
# 184   경기  2015  12   3850.0  12705.0      102㎡~
# 185   부산  2015  12   3127.0  10319.1         전체
# 186   부산  2015  12   2951.0   9738.3        60㎡
# 187   부산  2015  12   3032.0  10005.6   60㎡~ 85㎡
# 188   부산  2015  12   2957.0   9758.1  85㎡~ 102㎡
# 189   부산  2015  12   3739.0  12338.7      102㎡~
# 190   대구  2015  12   2962.0   9774.6         전체
# 191   대구  2015  12   3282.0  10830.6        60㎡
# 192   대구  2015  12   2971.0   9804.3   60㎡~ 85㎡
# 193   대구  2015  12   2532.0   8355.6  85㎡~ 102㎡
# 194   대구  2015  12   2743.0   9051.9      102㎡~
# 195   광주  2015  12   2476.0   8170.8         전체
# 196   광주  2015  12   2395.0   7903.5        60㎡
# 197   광주  2015  12   2489.0   8213.7   60㎡~ 85㎡
# 198   광주  2015  12      NaN      NaN  85㎡~ 102㎡
# 199   광주  2015  12      NaN      NaN      102㎡~
# 200   대전  2015  12   2454.0   8098.2         전체
# 201   대전  2015  12   2585.0   8530.5        60㎡
# 202   대전  2015  12   2428.0   8012.4   60㎡~ 85㎡
# 203   대전  2015  12   2461.0   8121.3  85㎡~ 102㎡
# 204   대전  2015  12      NaN      NaN      102㎡~
# 205   울산  2015  12   3043.0  10041.9         전체
# 206   울산  2015  12   2584.0   8527.2        60㎡
# 207   울산  2015  12   3048.0  10058.4   60㎡~ 85㎡
# 208   울산  2015  12   2663.0   8787.9  85㎡~ 102㎡
# 209   울산  2015  12   2874.0   9484.2      102㎡~
# 210   세종  2015  12   2665.0   8794.5         전체
# 211   세종  2015  12   2601.0   8583.3        60㎡
# 212   세종  2015  12   2676.0   8830.8   60㎡~ 85㎡
# 213   세종  2015  12   2661.0   8781.3  85㎡~ 102㎡
# 214   세종  2015  12   2752.0   9081.6      102㎡~
# 215   강원  2015  12   2171.0   7164.3         전체
# 216   강원  2015  12   2292.0   7563.6        60㎡
# 217   강원  2015  12   2193.0   7236.9   60㎡~ 85㎡
# 218   강원  2015  12   2061.0   6801.3  85㎡~ 102㎡
# 219   강원  2015  12   2171.0   7164.3      102㎡~
# 220   충북  2015  12   2005.0   6616.5         전체
# 221   충북  2015  12   1941.0   6405.3        60㎡
# 222   충북  2015  12   2017.0   6656.1   60㎡~ 85㎡
# 223   충북  2015  12   2276.0   7510.8  85㎡~ 102㎡
# 224   충북  2015  12   2261.0   7461.3      102㎡~
# 225   충남  2015  12   2269.0   7487.7         전체
# 226   충남  2015  12   2438.0   8045.4        60㎡
# 227   충남  2015  12   2279.0   7520.7   60㎡~ 85㎡
# 228   충남  2015  12   2523.0   8325.9  85㎡~ 102㎡
# 229   충남  2015  12   2444.0   8065.2      102㎡~
# 230   전북  2015  12   1983.0   6543.9         전체
# 231   전북  2015  12   1925.0   6352.5        60㎡
# 232   전북  2015  12   1987.0   6557.1   60㎡~ 85㎡
# 233   전북  2015  12   2377.0   7844.1  85㎡~ 102㎡
# 234   전북  2015  12   2282.0   7530.6      102㎡~
# 235   전남  2015  12   1909.0   6299.7         전체
# 236   전남  2015  12   1999.0   6596.7        60㎡
# 237   전남  2015  12   1906.0   6289.8   60㎡~ 85㎡
# 238   전남  2015  12   2262.0   7464.6  85㎡~ 102㎡
# 239   전남  2015  12   2176.0   7180.8      102㎡~
# 240   경북  2015  12   2181.0   7197.3         전체
# 241   경북  2015  12   2178.0   7187.4        60㎡
# 242   경북  2015  12   2184.0   7207.2   60㎡~ 85㎡
# 243   경북  2015  12   2516.0   8302.8  85㎡~ 102㎡
# 244   경북  2015  12   2370.0   7821.0      102㎡~
# 245   경남  2015  12   2307.0   7613.1         전체
# 246   경남  2015  12   2280.0   7524.0        60㎡
# 247   경남  2015  12   2329.0   7685.7   60㎡~ 85㎡
# 248   경남  2015  12   2934.0   9682.2  85㎡~ 102㎡
# 249   경남  2015  12   3019.0   9962.7      102㎡~
# 250   제주  2015  12   2268.0   7484.4         전체
# 251   제주  2015  12      NaN      NaN        60㎡
# 252   제주  2015  12   2260.0   7458.0   60㎡~ 85㎡
# 253   제주  2015  12   2583.0   8523.9  85㎡~ 102㎡
# 254   제주  2015  12   2574.0   8494.2      102㎡~
# 255   서울  2016   1   6108.0  20156.4         전체
# 256   서울  2016   1   6427.0  21209.1        60㎡
# 257   서울  2016   1   6036.0  19918.8   60㎡~ 85㎡
# 258   서울  2016   1   6513.0  21492.9  85㎡~ 102㎡
# 259   서울  2016   1   6551.0  21618.3      102㎡~
# 260   인천  2016   1   3191.0  10530.3         전체
# 261   인천  2016   1   3328.0  10982.4        60㎡
# 262   인천  2016   1   3110.0  10263.0   60㎡~ 85㎡
# 263   인천  2016   1   3545.0  11698.5  85㎡~ 102㎡
# 264   인천  2016   1   3408.0  11246.4      102㎡~
# 265   경기  2016   1   3198.0  10553.4         전체
# 266   경기  2016   1   3293.0  10866.9        60㎡
# 267   경기  2016   1   3313.0  10932.9   60㎡~ 85㎡
# 268   경기  2016   1   3450.0  11385.0  85㎡~ 102㎡
# 269   경기  2016   1   3850.0  12705.0      102㎡~
# 270   부산  2016   1   3152.0  10401.6         전체
# 271   부산  2016   1   2951.0   9738.3        60㎡
# 272   부산  2016   1   3057.0  10088.1   60㎡~ 85㎡
# 273   부산  2016   1   2957.0   9758.1  85㎡~ 102㎡
# 274   부산  2016   1   3812.0  12579.6      102㎡~
# 275   대구  2016   1   3086.0  10183.8         전체
# 276   대구  2016   1   3341.0  11025.3        60㎡
# 277   대구  2016   1   3103.0  10239.9   60㎡~ 85㎡
# 278   대구  2016   1   2532.0   8355.6  85㎡~ 102㎡
# 279   대구  2016   1   2743.0   9051.9      102㎡~
# 280   광주  2016   1   2569.0   8477.7         전체
# 281   광주  2016   1   2395.0   7903.5        60㎡
# 282   광주  2016   1   2582.0   8520.6   60㎡~ 85㎡
# 283   광주  2016   1      NaN      NaN  85㎡~ 102㎡
# 284   광주  2016   1      NaN      NaN      102㎡~
# 285   대전  2016   1   2454.0   8098.2         전체
# 286   대전  2016   1   2585.0   8530.5        60㎡
# 287   대전  2016   1   2428.0   8012.4   60㎡~ 85㎡
# 288   대전  2016   1   2461.0   8121.3  85㎡~ 102㎡
# 289   대전  2016   1      NaN      NaN      102㎡~
# 290   울산  2016   1   3046.0  10051.8         전체
# 291   울산  2016   1   2584.0   8527.2        60㎡
# 292   울산  2016   1   3053.0  10074.9   60㎡~ 85㎡
# 293   울산  2016   1   2663.0   8787.9  85㎡~ 102㎡
# 294   울산  2016   1   2874.0   9484.2      102㎡~
# 295   세종  2016   1   2665.0   8794.5         전체
# 296   세종  2016   1   2601.0   8583.3        60㎡
# 297   세종  2016   1   2676.0   8830.8   60㎡~ 85㎡
# 298   세종  2016   1   2661.0   8781.3  85㎡~ 102㎡
# 299   세종  2016   1   2752.0   9081.6      102㎡~
# 300   강원  2016   1   2173.0   7170.9         전체
# 301   강원  2016   1   2290.0   7557.0        60㎡
# 302   강원  2016   1   2199.0   7256.7   60㎡~ 85㎡
# 303   강원  2016   1   2061.0   6801.3  85㎡~ 102㎡
# 304   강원  2016   1   2171.0   7164.3      102㎡~
# 305   충북  2016   1   2008.0   6626.4         전체
# 306   충북  2016   1   1952.0   6441.6        60㎡
# 307   충북  2016   1   2021.0   6669.3   60㎡~ 85㎡
# 308   충북  2016   1   2276.0   7510.8  85㎡~ 102㎡
# 309   충북  2016   1   2261.0   7461.3      102㎡~
# 310   충남  2016   1   2270.0   7491.0         전체
# 311   충남  2016   1   2481.0   8187.3        60㎡
# 312   충남  2016   1   2281.0   7527.3   60㎡~ 85㎡
# 313   충남  2016   1   2541.0   8385.3  85㎡~ 102㎡
# 314   충남  2016   1   2444.0   8065.2      102㎡~
# 315   전북  2016   1   1980.0   6534.0         전체
# 316   전북  2016   1   1908.0   6296.4        60㎡
# 317   전북  2016   1   1987.0   6557.1   60㎡~ 85㎡
# 318   전북  2016   1   2377.0   7844.1  85㎡~ 102㎡
# 319   전북  2016   1   2282.0   7530.6      102㎡~
# 320   전남  2016   1   1909.0   6299.7         전체
# 321   전남  2016   1   1999.0   6596.7        60㎡
# 322   전남  2016   1   1906.0   6289.8   60㎡~ 85㎡
# 323   전남  2016   1   2262.0   7464.6  85㎡~ 102㎡
# 324   전남  2016   1   2176.0   7180.8      102㎡~
# 325   경북  2016   1   2181.0   7197.3         전체
# 326   경북  2016   1   2178.0   7187.4        60㎡
# 327   경북  2016   1   2185.0   7210.5   60㎡~ 85㎡
# 328   경북  2016   1   2516.0   8302.8  85㎡~ 102㎡
# 329   경북  2016   1   2346.0   7741.8      102㎡~
# 330   경남  2016   1   2327.0   7679.1         전체
# 331   경남  2016   1   2270.0   7491.0        60㎡
# 332   경남  2016   1   2348.0   7748.4   60㎡~ 85㎡
# 333   경남  2016   1   2925.0   9652.5  85㎡~ 102㎡
# 334   경남  2016   1   2828.0   9332.4      102㎡~
# 335   제주  2016   1   2268.0   7484.4         전체
# 336   제주  2016   1      NaN      NaN        60㎡
# 337   제주  2016   1   2260.0   7458.0   60㎡~ 85㎡
# 338   제주  2016   1   2583.0   8523.9  85㎡~ 102㎡
# 339   제주  2016   1   2574.0   8494.2      102㎡~
# 340   서울  2016   2   6111.0  20166.3         전체
# 341   서울  2016   2   6438.0  21245.4        60㎡
# 342   서울  2016   2   6039.0  19928.7   60㎡~ 85㎡
# 343   서울  2016   2   6513.0  21492.9  85㎡~ 102㎡
# 344   서울  2016   2   6458.0  21311.4      102㎡~
# 345   인천  2016   2   3192.0  10533.6         전체
# 346   인천  2016   2   3328.0  10982.4        60㎡
# 347   인천  2016   2   3112.0  10269.6   60㎡~ 85㎡
# 348   인천  2016   2   3545.0  11698.5  85㎡~ 102㎡
# 349   인천  2016   2   3408.0  11246.4      102㎡~
# 350   경기  2016   2   3219.0  10622.7         전체
# 351   경기  2016   2   3294.0  10870.2        60㎡
# 352   경기  2016   2   3268.0  10784.4   60㎡~ 85㎡
# 353   경기  2016   2   3381.0  11157.3  85㎡~ 102㎡
# 354   경기  2016   2   3669.0  12107.7      102㎡~
# 355   부산  2016   2   3154.0  10408.2         전체
# 356   부산  2016   2   2999.0   9896.7        60㎡
# 357   부산  2016   2   3060.0  10098.0   60㎡~ 85㎡
# 358   부산  2016   2   2957.0   9758.1  85㎡~ 102㎡
# 359   부산  2016   2   3812.0  12579.6      102㎡~
# 360   대구  2016   2   3064.0  10111.2         전체
# 361   대구  2016   2   3341.0  11025.3        60㎡
# 362   대구  2016   2   3079.0  10160.7   60㎡~ 85㎡
# 363   대구  2016   2   2532.0   8355.6  85㎡~ 102㎡
# 364   대구  2016   2   2743.0   9051.9      102㎡~
# 365   광주  2016   2   2569.0   8477.7         전체
# 366   광주  2016   2   2395.0   7903.5        60㎡
# 367   광주  2016   2   2582.0   8520.6   60㎡~ 85㎡
# 368   광주  2016   2      NaN      NaN  85㎡~ 102㎡
# 369   광주  2016   2      NaN      NaN      102㎡~
# 370   대전  2016   2   2454.0   8098.2         전체
# 371   대전  2016   2   2585.0   8530.5        60㎡
# 372   대전  2016   2   2428.0   8012.4   60㎡~ 85㎡
# 373   대전  2016   2   2461.0   8121.3  85㎡~ 102㎡
# 374   대전  2016   2      NaN      NaN      102㎡~
# 375   울산  2016   2   3046.0  10051.8         전체
# 376   울산  2016   2   2584.0   8527.2        60㎡
# 377   울산  2016   2   3053.0  10074.9   60㎡~ 85㎡
# 378   울산  2016   2   2663.0   8787.9  85㎡~ 102㎡
# 379   울산  2016   2   2874.0   9484.2      102㎡~
# 380   세종  2016   2   2665.0   8794.5         전체
# 381   세종  2016   2   2601.0   8583.3        60㎡
# 382   세종  2016   2   2676.0   8830.8   60㎡~ 85㎡
# 383   세종  2016   2   2661.0   8781.3  85㎡~ 102㎡
# 384   세종  2016   2   2752.0   9081.6      102㎡~
# 385   강원  2016   2   2173.0   7170.9         전체
# 386   강원  2016   2   2290.0   7557.0        60㎡
# 387   강원  2016   2   2200.0   7260.0   60㎡~ 85㎡
# 388   강원  2016   2      NaN      NaN  85㎡~ 102㎡
# 389   강원  2016   2   2350.0   7755.0      102㎡~
# 390   충북  2016   2   2008.0   6626.4         전체
# 391   충북  2016   2   1952.0   6441.6        60㎡
# 392   충북  2016   2   2021.0   6669.3   60㎡~ 85㎡
# 393   충북  2016   2   2276.0   7510.8  85㎡~ 102㎡
# 394   충북  2016   2   2261.0   7461.3      102㎡~
# 395   충남  2016   2   2272.0   7497.6         전체
# 396   충남  2016   2   2496.0   8236.8        60㎡
# 397   충남  2016   2   2282.0   7530.6   60㎡~ 85㎡
# 398   충남  2016   2   2541.0   8385.3  85㎡~ 102㎡
# 399   충남  2016   2   2444.0   8065.2      102㎡~
# 400   전북  2016   2   1980.0   6534.0         전체
# 401   전북  2016   2   1908.0   6296.4        60㎡
# 402   전북  2016   2   1987.0   6557.1   60㎡~ 85㎡
# 403   전북  2016   2   2377.0   7844.1  85㎡~ 102㎡
# 404   전북  2016   2   2283.0   7533.9      102㎡~
# 405   전남  2016   2   1923.0   6345.9         전체
# 406   전남  2016   2   1999.0   6596.7        60㎡
# 407   전남  2016   2   1921.0   6339.3   60㎡~ 85㎡
# 408   전남  2016   2   2262.0   7464.6  85㎡~ 102㎡
# 409   전남  2016   2   2176.0   7180.8      102㎡~
# 410   경북  2016   2   2179.0   7190.7         전체
# 411   경북  2016   2   2172.0   7167.6        60㎡
# 412   경북  2016   2   2191.0   7230.3   60㎡~ 85㎡
# 413   경북  2016   2   2532.0   8355.6  85㎡~ 102㎡
# 414   경북  2016   2   2346.0   7741.8      102㎡~
# 415   경남  2016   2   2358.0   7781.4         전체
# 416   경남  2016   2   2361.0   7791.3        60㎡
# 417   경남  2016   2   2375.0   7837.5   60㎡~ 85㎡
# 418   경남  2016   2   2925.0   9652.5  85㎡~ 102㎡
# 419   경남  2016   2   2673.0   8820.9      102㎡~
# 420   제주  2016   2   2268.0   7484.4         전체
# 421   제주  2016   2      NaN      NaN        60㎡
# 422   제주  2016   2   2260.0   7458.0   60㎡~ 85㎡
# 423   제주  2016   2   2583.0   8523.9  85㎡~ 102㎡
# 424   제주  2016   2   2574.0   8494.2      102㎡~
# 425   서울  2016   3   6173.0  20370.9         전체
# 426   서울  2016   3   6550.0  21615.0        60㎡
# 427   서울  2016   3   6127.0  20219.1   60㎡~ 85㎡
# 428   서울  2016   3   7179.0  23690.7  85㎡~ 102㎡
# 429   서울  2016   3   6371.0  21024.3      102㎡~
# 430   인천  2016   3   3190.0  10527.0         전체
# 431   인천  2016   3   3323.0  10965.9        60㎡
# 432   인천  2016   3   3111.0  10266.3   60㎡~ 85㎡
# 433   인천  2016   3   3545.0  11698.5  85㎡~ 102㎡
# 434   인천  2016   3   3408.0  11246.4      102㎡~
# 435   경기  2016   3   3215.0  10609.5         전체
# 436   경기  2016   3   3441.0  11355.3        60㎡
# 437   경기  2016   3   3259.0  10754.7   60㎡~ 85㎡
# 438   경기  2016   3   3363.0  11097.9  85㎡~ 102㎡
# 439   경기  2016   3   3680.0  12144.0      102㎡~
# 440   부산  2016   3   3178.0  10487.4         전체
# 441   부산  2016   3   2951.0   9738.3        60㎡
# 442   부산  2016   3   3102.0  10236.6   60㎡~ 85㎡
# 443   부산  2016   3   2957.0   9758.1  85㎡~ 102㎡
# 444   부산  2016   3   3727.0  12299.1      102㎡~
# 445   대구  2016   3   3119.0  10292.7         전체
# 446   대구  2016   3   3341.0  11025.3        60㎡
# 447   대구  2016   3   3154.0  10408.2   60㎡~ 85㎡
# 448   대구  2016   3   2539.0   8378.7  85㎡~ 102㎡
# 449   대구  2016   3   2743.0   9051.9      102㎡~
# 450   광주  2016   3   2590.0   8547.0         전체
# 451   광주  2016   3   2470.0   8151.0        60㎡
# 452   광주  2016   3   2601.0   8583.3   60㎡~ 85㎡
# 453   광주  2016   3      NaN      NaN  85㎡~ 102㎡
# 454   광주  2016   3      NaN      NaN      102㎡~
# 455   대전  2016   3   2454.0   8098.2         전체
# 456   대전  2016   3   2585.0   8530.5        60㎡
# 457   대전  2016   3   2428.0   8012.4   60㎡~ 85㎡
# 458   대전  2016   3   2461.0   8121.3  85㎡~ 102㎡
# 459   대전  2016   3      NaN      NaN      102㎡~
# 460   울산  2016   3   3066.0  10117.8         전체
# 461   울산  2016   3   2584.0   8527.2        60㎡
# 462   울산  2016   3   3075.0  10147.5   60㎡~ 85㎡
# 463   울산  2016   3   2663.0   8787.9  85㎡~ 102㎡
# 464   울산  2016   3   3057.0  10088.1      102㎡~
# 465   세종  2016   3   2670.0   8811.0         전체
# 466   세종  2016   3   2601.0   8583.3        60㎡
# 467   세종  2016   3   2681.0   8847.3   60㎡~ 85㎡
# 468   세종  2016   3   2670.0   8811.0  85㎡~ 102㎡
# 469   세종  2016   3   2752.0   9081.6      102㎡~
# 470   강원  2016   3   2194.0   7240.2         전체
# 471   강원  2016   3   2249.0   7421.7        60㎡
# 472   강원  2016   3   2221.0   7329.3   60㎡~ 85㎡
# 473   강원  2016   3      NaN      NaN  85㎡~ 102㎡
# 474   강원  2016   3   2350.0   7755.0      102㎡~
# 475   충북  2016   3   1980.0   6534.0         전체
# 476   충북  2016   3   1925.0   6352.5        60㎡
# 477   충북  2016   3   2021.0   6669.3   60㎡~ 85㎡
# 478   충북  2016   3   2276.0   7510.8  85㎡~ 102㎡
# 479   충북  2016   3   2261.0   7461.3      102㎡~
# 480   충남  2016   3   2115.0   6979.5         전체
# 481   충남  2016   3   2226.0   7345.8        60㎡
# 482   충남  2016   3   2114.0   6976.2   60㎡~ 85㎡
# 483   충남  2016   3   2541.0   8385.3  85㎡~ 102㎡
# 484   충남  2016   3   2444.0   8065.2      102㎡~
# 485   전북  2016   3   1951.0   6438.3         전체
# 486   전북  2016   3   1910.0   6303.0        60㎡
# 487   전북  2016   3   1959.0   6464.7   60㎡~ 85㎡
# 488   전북  2016   3   2269.0   7487.7  85㎡~ 102㎡
# 489   전북  2016   3   2293.0   7566.9      102㎡~
# 490   전남  2016   3   1921.0   6339.3         전체
# 491   전남  2016   3   2002.0   6606.6        60㎡
# 492   전남  2016   3   1919.0   6332.7   60㎡~ 85㎡
# 493   전남  2016   3   2262.0   7464.6  85㎡~ 102㎡
# 494   전남  2016   3   2176.0   7180.8      102㎡~
# 495   경북  2016   3   2179.0   7190.7         전체
# 496   경북  2016   3   2173.0   7170.9        60㎡
# 497   경북  2016   3   2191.0   7230.3   60㎡~ 85㎡
# 498   경북  2016   3   2675.0   8827.5  85㎡~ 102㎡
# 499   경북  2016   3   2314.0   7636.2      102㎡~
# 500   경남  2016   3   2383.0   7863.9         전체
# 501   경남  2016   3   2366.0   7807.8        60㎡
# 502   경남  2016   3   2392.0   7893.6   60㎡~ 85㎡
# 503   경남  2016   3   3053.0  10074.9  85㎡~ 102㎡
# 504   경남  2016   3   2645.0   8728.5      102㎡~
# 505   제주  2016   3   2314.0   7636.2         전체
# 506   제주  2016   3      NaN      NaN        60㎡
# 507   제주  2016   3   2314.0   7636.2   60㎡~ 85㎡
# 508   제주  2016   3      NaN      NaN  85㎡~ 102㎡
# 509   제주  2016   3      NaN      NaN      102㎡~
# 510   서울  2016   4   6241.0  20595.3         전체
# 511   서울  2016   4   6618.0  21839.4        60㎡
# 512   서울  2016   4   6196.0  20446.8   60㎡~ 85㎡
# 513   서울  2016   4   8096.0  26716.8  85㎡~ 102㎡
# 514   서울  2016   4   6353.0  20964.9      102㎡~
# 515   인천  2016   4   3238.0  10685.4         전체
# 516   인천  2016   4   3323.0  10965.9        60㎡
# 517   인천  2016   4   3147.0  10385.1   60㎡~ 85㎡
# 518   인천  2016   4   3545.0  11698.5  85㎡~ 102㎡
# 519   인천  2016   4   4839.0  15968.7      102㎡~
# 520   경기  2016   4   3199.0  10556.7         전체
# 521   경기  2016   4   3400.0  11220.0        60㎡
# 522   경기  2016   4   3243.0  10701.9   60㎡~ 85㎡
# 523   경기  2016   4   3395.0  11203.5  85㎡~ 102㎡
# 524   경기  2016   4   3611.0  11916.3      102㎡~
# 525   부산  2016   4   3169.0  10457.7         전체
# 526   부산  2016   4   2973.0   9810.9        60㎡
# 527   부산  2016   4   3087.0  10187.1   60㎡~ 85㎡
# 528   부산  2016   4   2930.0   9669.0  85㎡~ 102㎡
# 529   부산  2016   4   3727.0  12299.1      102㎡~
# 530   대구  2016   4   3132.0  10335.6         전체
# 531   대구  2016   4   3341.0  11025.3        60㎡
# 532   대구  2016   4   3168.0  10454.4   60㎡~ 85㎡
# 533   대구  2016   4   2539.0   8378.7  85㎡~ 102㎡
# 534   대구  2016   4   2743.0   9051.9      102㎡~
# 535   광주  2016   4   2700.0   8910.0         전체
# 536   광주  2016   4   2600.0   8580.0        60㎡
# 537   광주  2016   4   2696.0   8896.8   60㎡~ 85㎡
# 538   광주  2016   4   2754.0   9088.2  85㎡~ 102㎡
# 539   광주  2016   4   3518.0  11609.4      102㎡~
# 540   대전  2016   4   2449.0   8081.7         전체
# 541   대전  2016   4   2529.0   8345.7        60㎡
# 542   대전  2016   4   2425.0   8002.5   60㎡~ 85㎡
# 543   대전  2016   4      NaN      NaN  85㎡~ 102㎡
# 544   대전  2016   4      NaN      NaN      102㎡~
# 545   울산  2016   4   3072.0  10137.6         전체
# 546   울산  2016   4   2586.0   8533.8        60㎡
# 547   울산  2016   4   3076.0  10150.8   60㎡~ 85㎡
# 548   울산  2016   4   2663.0   8787.9  85㎡~ 102㎡
# 549   울산  2016   4   2967.0   9791.1      102㎡~
# 550   세종  2016   4   2680.0   8844.0         전체
# 551   세종  2016   4   2656.0   8764.8        60㎡
# 552   세종  2016   4   2699.0   8906.7   60㎡~ 85㎡
# 553   세종  2016   4   2654.0   8758.2  85㎡~ 102㎡
# 554   세종  2016   4   2714.0   8956.2      102㎡~
# 555   강원  2016   4   2140.0   7062.0         전체
# 556   강원  2016   4   2143.0   7071.9        60㎡
# 557   강원  2016   4   2183.0   7203.9   60㎡~ 85㎡
# 558   강원  2016   4      NaN      NaN  85㎡~ 102㎡
# 559   강원  2016   4   2350.0   7755.0      102㎡~
# 560   충북  2016   4   1968.0   6494.4         전체
# 561   충북  2016   4   1915.0   6319.5        60㎡
# 562   충북  2016   4   2010.0   6633.0   60㎡~ 85㎡
# 563   충북  2016   4   2276.0   7510.8  85㎡~ 102㎡
# 564   충북  2016   4   2261.0   7461.3      102㎡~
# 565   충남  2016   4   2169.0   7157.7         전체
# 566   충남  2016   4   2295.0   7573.5        60㎡
# 567   충남  2016   4   2160.0   7128.0   60㎡~ 85㎡
# 568   충남  2016   4   2541.0   8385.3  85㎡~ 102㎡
# 569   충남  2016   4   2638.0   8705.4      102㎡~
# 570   전북  2016   4   1909.0   6299.7         전체
# 571   전북  2016   4   1900.0   6270.0        60㎡
# 572   전북  2016   4   1916.0   6322.8   60㎡~ 85㎡
# 573   전북  2016   4   2269.0   7487.7  85㎡~ 102㎡
# 574   전북  2016   4   2380.0   7854.0      102㎡~
# 575   전남  2016   4   1925.0   6352.5         전체
# 576   전남  2016   4   1989.0   6563.7        60㎡
# 577   전남  2016   4   1923.0   6345.9   60㎡~ 85㎡
# 578   전남  2016   4   2262.0   7464.6  85㎡~ 102㎡
# 579   전남  2016   4   2176.0   7180.8      102㎡~
# 580   경북  2016   4   2177.0   7184.1         전체
# 581   경북  2016   4   2171.0   7164.3        60㎡
# 582   경북  2016   4   2189.0   7223.7   60㎡~ 85㎡
# 583   경북  2016   4   2675.0   8827.5  85㎡~ 102㎡
# 584   경북  2016   4   2314.0   7636.2      102㎡~
# 585   경남  2016   4   2391.0   7890.3         전체
# 586   경남  2016   4   2413.0   7962.9        60㎡
# 587   경남  2016   4   2389.0   7883.7   60㎡~ 85㎡
# 588   경남  2016   4   3176.0  10480.8  85㎡~ 102㎡
# 589   경남  2016   4   2660.0   8778.0      102㎡~
# 590   제주  2016   4   2719.0   8972.7         전체
# 591   제주  2016   4   2853.0   9414.9        60㎡
# 592   제주  2016   4   2752.0   9081.6   60㎡~ 85㎡
# 593   제주  2016   4   2725.0   8992.5  85㎡~ 102㎡
# 594   제주  2016   4   2602.0   8586.6      102㎡~
# 595   서울  2016   5   6264.0  20671.2         전체
# 596   서울  2016   5   6638.0  21905.4        60㎡
# 597   서울  2016   5   6205.0  20476.5   60㎡~ 85㎡
# 598   서울  2016   5   7725.0  25492.5  85㎡~ 102㎡
# 599   서울  2016   5   6353.0  20964.9      102㎡~
# 600   인천  2016   5   3179.0  10490.7         전체
# 601   인천  2016   5   3323.0  10965.9        60㎡
# 602   인천  2016   5   3147.0  10385.1   60㎡~ 85㎡
# 603   인천  2016   5   3367.0  11111.1  85㎡~ 102㎡
# 604   인천  2016   5   4192.0  13833.6      102㎡~
# 605   경기  2016   5   3443.0  11361.9         전체
# 606   경기  2016   5   3720.0  12276.0        60㎡
# 607   경기  2016   5   3443.0  11361.9   60㎡~ 85㎡
# 608   경기  2016   5   3370.0  11121.0  85㎡~ 102㎡
# 609   경기  2016   5   3956.0  13054.8      102㎡~
# 610   부산  2016   5   3148.0  10388.4         전체
# 611   부산  2016   5   2977.0   9824.1        60㎡
# 612   부산  2016   5   3071.0  10134.3   60㎡~ 85㎡
# 613   부산  2016   5   3096.0  10216.8  85㎡~ 102㎡
# 614   부산  2016   5   3536.0  11668.8      102㎡~
# 615   대구  2016   5   3132.0  10335.6         전체
# 616   대구  2016   5   3385.0  11170.5        60㎡
# 617   대구  2016   5   3166.0  10447.8   60㎡~ 85㎡
# 618   대구  2016   5   2539.0   8378.7  85㎡~ 102㎡
# 619   대구  2016   5   2743.0   9051.9      102㎡~
# 620   광주  2016   5   2722.0   8982.6         전체
# 621   광주  2016   5   2567.0   8471.1        60㎡
# 622   광주  2016   5   2723.0   8985.9   60㎡~ 85㎡
# 623   광주  2016   5   2754.0   9088.2  85㎡~ 102㎡
# 624   광주  2016   5   3518.0  11609.4      102㎡~
# 625   대전  2016   5   2465.0   8134.5         전체
# 626   대전  2016   5   2582.0   8520.6        60㎡
# 627   대전  2016   5   2427.0   8009.1   60㎡~ 85㎡
# 628   대전  2016   5      NaN      NaN  85㎡~ 102㎡
# 629   대전  2016   5      NaN      NaN      102㎡~
# 630   울산  2016   5   3077.0  10154.1         전체
# 631   울산  2016   5   2600.0   8580.0        60㎡
# 632   울산  2016   5   3080.0  10164.0   60㎡~ 85㎡
# 633   울산  2016   5   2663.0   8787.9  85㎡~ 102㎡
# 634   울산  2016   5   2967.0   9791.1      102㎡~
# 635   세종  2016   5   2680.0   8844.0         전체
# 636   세종  2016   5   2656.0   8764.8        60㎡
# 637   세종  2016   5   2699.0   8906.7   60㎡~ 85㎡
# 638   세종  2016   5   2654.0   8758.2  85㎡~ 102㎡
# 639   세종  2016   5   2714.0   8956.2      102㎡~
# 640   강원  2016   5   2117.0   6986.1         전체
# 641   강원  2016   5   2113.0   6972.9        60㎡
# 642   강원  2016   5   2150.0   7095.0   60㎡~ 85㎡
# 643   강원  2016   5      NaN      NaN  85㎡~ 102㎡
# 644   강원  2016   5   2289.0   7553.7      102㎡~
# 645   충북  2016   5   1980.0   6534.0         전체
# 646   충북  2016   5   1925.0   6352.5        60㎡
# 647   충북  2016   5   2024.0   6679.2   60㎡~ 85㎡
# 648   충북  2016   5   2276.0   7510.8  85㎡~ 102㎡
# 649   충북  2016   5   2271.0   7494.3      102㎡~
# 650   충남  2016   5   2166.0   7147.8         전체
# 651   충남  2016   5   2301.0   7593.3        60㎡
# 652   충남  2016   5   2150.0   7095.0   60㎡~ 85㎡
# 653   충남  2016   5   2554.0   8428.2  85㎡~ 102㎡
# 654   충남  2016   5   2638.0   8705.4      102㎡~
# 655   전북  2016   5   1945.0   6418.5         전체
# 656   전북  2016   5   1909.0   6299.7        60㎡
# 657   전북  2016   5   1955.0   6451.5   60㎡~ 85㎡
# 658   전북  2016   5   2269.0   7487.7  85㎡~ 102㎡
# 659   전북  2016   5   2322.0   7662.6      102㎡~
# 660   전남  2016   5   1927.0   6359.1         전체
# 661   전남  2016   5   1989.0   6563.7        60㎡
# 662   전남  2016   5   1925.0   6352.5   60㎡~ 85㎡
# 663   전남  2016   5   2262.0   7464.6  85㎡~ 102㎡
# 664   전남  2016   5   2176.0   7180.8      102㎡~
# 665   경북  2016   5   2176.0   7180.8         전체
# 666   경북  2016   5   2171.0   7164.3        60㎡
# 667   경북  2016   5   2189.0   7223.7   60㎡~ 85㎡
# 668   경북  2016   5   2675.0   8827.5  85㎡~ 102㎡
# 669   경북  2016   5   2323.0   7665.9      102㎡~
# 670   경남  2016   5   2381.0   7857.3         전체
# 671   경남  2016   5   2423.0   7995.9        60㎡
# 672   경남  2016   5   2380.0   7854.0   60㎡~ 85㎡
# 673   경남  2016   5   3278.0  10817.4  85㎡~ 102㎡
# 674   경남  2016   5   2741.0   9045.3      102㎡~
# 675   제주  2016   5   2691.0   8880.3         전체
# 676   제주  2016   5   2853.0   9414.9        60㎡
# 677   제주  2016   5   2712.0   8949.6   60㎡~ 85㎡
# 678   제주  2016   5   2708.0   8936.4  85㎡~ 102㎡
# 679   제주  2016   5   2605.0   8596.5      102㎡~
# 680   서울  2016   6   6208.0  20486.4         전체
# 681   서울  2016   6   6562.0  21654.6        60㎡
# 682   서울  2016   6   6218.0  20519.4   60㎡~ 85㎡
# 683   서울  2016   6   7732.0  25515.6  85㎡~ 102㎡
# 684   서울  2016   6   6365.0  21004.5      102㎡~
# 685   인천  2016   6   3204.0  10573.2         전체
# 686   인천  2016   6   2981.0   9837.3        60㎡
# 687   인천  2016   6   3353.0  11064.9   60㎡~ 85㎡
# 688   인천  2016   6   3453.0  11394.9  85㎡~ 102㎡
# 689   인천  2016   6   3576.0  11800.8      102㎡~
# 690   경기  2016   6   3542.0  11688.6         전체
# 691   경기  2016   6   3781.0  12477.3        60㎡
# 692   경기  2016   6   3539.0  11678.7   60㎡~ 85㎡
# 693   경기  2016   6   3334.0  11002.2  85㎡~ 102㎡
# 694   경기  2016   6   4073.0  13440.9      102㎡~
# 695   부산  2016   6   3150.0  10395.0         전체
# 696   부산  2016   6   2972.0   9807.6        60㎡
# 697   부산  2016   6   3069.0  10127.7   60㎡~ 85㎡
# 698   부산  2016   6   3253.0  10734.9  85㎡~ 102㎡
# 699   부산  2016   6   3723.0  12285.9      102㎡~
# 700   대구  2016   6   3134.0  10342.2         전체
# 701   대구  2016   6   3385.0  11170.5        60㎡
# 702   대구  2016   6   3165.0  10444.5   60㎡~ 85㎡
# 703   대구  2016   6   2839.0   9368.7  85㎡~ 102㎡
# 704   대구  2016   6   2743.0   9051.9      102㎡~
# 705   광주  2016   6   2737.0   9032.1         전체
# 706   광주  2016   6   2567.0   8471.1        60㎡
# 707   광주  2016   6   2743.0   9051.9   60㎡~ 85㎡
# 708   광주  2016   6   2754.0   9088.2  85㎡~ 102㎡
# 709   광주  2016   6   3518.0  11609.4      102㎡~
# 710   대전  2016   6   2562.0   8454.6         전체
# 711   대전  2016   6   2648.0   8738.4        60㎡
# 712   대전  2016   6   2547.0   8405.1   60㎡~ 85㎡
# 713   대전  2016   6      NaN      NaN  85㎡~ 102㎡
# 714   대전  2016   6      NaN      NaN      102㎡~
# 715   울산  2016   6   3069.0  10127.7         전체
# 716   울산  2016   6   2557.0   8438.1        60㎡
# 717   울산  2016   6   3074.0  10144.2   60㎡~ 85㎡
# 718   울산  2016   6   2663.0   8787.9  85㎡~ 102㎡
# 719   울산  2016   6   2967.0   9791.1      102㎡~
# 720   세종  2016   6   2683.0   8853.9         전체
# 721   세종  2016   6   2715.0   8959.5        60㎡
# 722   세종  2016   6   2704.0   8923.2   60㎡~ 85㎡
# 723   세종  2016   6   2660.0   8778.0  85㎡~ 102㎡
# 724   세종  2016   6   2610.0   8613.0      102㎡~
# 725   강원  2016   6   2104.0   6943.2         전체
# 726   강원  2016   6   2099.0   6926.7        60㎡
# 727   강원  2016   6   2136.0   7048.8   60㎡~ 85㎡
# 728   강원  2016   6      NaN      NaN  85㎡~ 102㎡
# 729   강원  2016   6   2339.0   7718.7      102㎡~
# 730   충북  2016   6   2047.0   6755.1         전체
# 731   충북  2016   6   2007.0   6623.1        60㎡
# 732   충북  2016   6   2108.0   6956.4   60㎡~ 85㎡
# 733   충북  2016   6   2276.0   7510.8  85㎡~ 102㎡
# 734   충북  2016   6   2243.0   7401.9      102㎡~
# 735   충남  2016   6   2198.0   7253.4         전체
# 736   충남  2016   6   2299.0   7586.7        60㎡
# 737   충남  2016   6   2188.0   7220.4   60㎡~ 85㎡
# 738   충남  2016   6   2614.0   8626.2  85㎡~ 102㎡
# 739   충남  2016   6   2749.0   9071.7      102㎡~
# 740   전북  2016   6   1931.0   6372.3         전체
# 741   전북  2016   6   1909.0   6299.7        60㎡
# 742   전북  2016   6   1940.0   6402.0   60㎡~ 85㎡
# 743   전북  2016   6   2269.0   7487.7  85㎡~ 102㎡
# 744   전북  2016   6   2322.0   7662.6      102㎡~
# 745   전남  2016   6   1968.0   6494.4         전체
# 746   전남  2016   6   1989.0   6563.7        60㎡
# 747   전남  2016   6   1964.0   6481.2   60㎡~ 85㎡
# 748   전남  2016   6   2364.0   7801.2  85㎡~ 102㎡
# 749   전남  2016   6   2264.0   7471.2      102㎡~
# 750   경북  2016   6   2238.0   7385.4         전체
# 751   경북  2016   6   2133.0   7038.9        60㎡
# 752   경북  2016   6   2256.0   7444.8   60㎡~ 85㎡
# 753   경북  2016   6   2675.0   8827.5  85㎡~ 102㎡
# 754   경북  2016   6   2526.0   8335.8      102㎡~
# 755   경남  2016   6   2389.0   7883.7         전체
# 756   경남  2016   6   2463.0   8127.9        60㎡
# 757   경남  2016   6   2382.0   7860.6   60㎡~ 85㎡
# 758   경남  2016   6   3052.0  10071.6  85㎡~ 102㎡
# 759   경남  2016   6   2740.0   9042.0      102㎡~
# 760   제주  2016   6   2827.0   9329.1         전체
# 761   제주  2016   6   2853.0   9414.9        60㎡
# 762   제주  2016   6   2730.0   9009.0   60㎡~ 85㎡
# 763   제주  2016   6   3107.0  10253.1  85㎡~ 102㎡
# 764   제주  2016   6   2605.0   8596.5      102㎡~
# 765   서울  2016   7   6254.0  20638.2         전체
# 766   서울  2016   7   6611.0  21816.3        60㎡
# 767   서울  2016   7   6399.0  21116.7   60㎡~ 85㎡
# 768   서울  2016   7   7732.0  25515.6  85㎡~ 102㎡
# 769   서울  2016   7   6373.0  21030.9      102㎡~
# 770   인천  2016   7   3222.0  10632.6         전체
# 771   인천  2016   7   2970.0   9801.0        60㎡
# 772   인천  2016   7   3272.0  10797.6   60㎡~ 85㎡
# 773   인천  2016   7   3454.0  11398.2  85㎡~ 102㎡
# 774   인천  2016   7   3599.0  11876.7      102㎡~
# 775   경기  2016   7   3531.0  11652.3         전체
# 776   경기  2016   7   3785.0  12490.5        60㎡
# 777   경기  2016   7   3531.0  11652.3   60㎡~ 85㎡
# 778   경기  2016   7   3344.0  11035.2  85㎡~ 102㎡
# 779   경기  2016   7   4124.0  13609.2      102㎡~
# 780   부산  2016   7   3158.0  10421.4         전체
# 781   부산  2016   7   2999.0   9896.7        60㎡
# 782   부산  2016   7   3081.0  10167.3   60㎡~ 85㎡
# 783   부산  2016   7   3297.0  10880.1  85㎡~ 102㎡
# 784   부산  2016   7   3874.0  12784.2      102㎡~
# 785   대구  2016   7   3130.0  10329.0         전체
# 786   대구  2016   7   3385.0  11170.5        60㎡
# 787   대구  2016   7   3153.0  10404.9   60㎡~ 85㎡
# 788   대구  2016   7   2884.0   9517.2  85㎡~ 102㎡
# 789   대구  2016   7   2743.0   9051.9      102㎡~
# 790   광주  2016   7   2742.0   9048.6         전체
# 791   광주  2016   7   2567.0   8471.1        60㎡
# 792   광주  2016   7   2748.0   9068.4   60㎡~ 85㎡
# 793   광주  2016   7   2754.0   9088.2  85㎡~ 102㎡
# 794   광주  2016   7   3518.0  11609.4      102㎡~
# 795   대전  2016   7   2562.0   8454.6         전체
# 796   대전  2016   7   2648.0   8738.4        60㎡
# 797   대전  2016   7   2547.0   8405.1   60㎡~ 85㎡
# 798   대전  2016   7      NaN      NaN  85㎡~ 102㎡
# 799   대전  2016   7      NaN      NaN      102㎡~
# 800   울산  2016   7   3069.0  10127.7         전체
# 801   울산  2016   7   2557.0   8438.1        60㎡
# 802   울산  2016   7   3074.0  10144.2   60㎡~ 85㎡
# 803   울산  2016   7   2663.0   8787.9  85㎡~ 102㎡
# 804   울산  2016   7   2967.0   9791.1      102㎡~
# 805   세종  2016   7   2687.0   8867.1         전체
# 806   세종  2016   7   2715.0   8959.5        60㎡
# 807   세종  2016   7   2713.0   8952.9   60㎡~ 85㎡
# 808   세종  2016   7   2664.0   8791.2  85㎡~ 102㎡
# 809   세종  2016   7   2589.0   8543.7      102㎡~
# 810   강원  2016   7   2101.0   6933.3         전체
# 811   강원  2016   7   2069.0   6827.7        60㎡
# 812   강원  2016   7   2139.0   7058.7   60㎡~ 85㎡
# 813   강원  2016   7      NaN      NaN  85㎡~ 102㎡
# 814   강원  2016   7   2339.0   7718.7      102㎡~
# 815   충북  2016   7   2075.0   6847.5         전체
# 816   충북  2016   7   2044.0   6745.2        60㎡
# 817   충북  2016   7   2150.0   7095.0   60㎡~ 85㎡
# 818   충북  2016   7   2276.0   7510.8  85㎡~ 102㎡
# 819   충북  2016   7   2243.0   7401.9      102㎡~
# 820   충남  2016   7   2198.0   7253.4         전체
# 821   충남  2016   7   2299.0   7586.7        60㎡
# 822   충남  2016   7   2188.0   7220.4   60㎡~ 85㎡
# 823   충남  2016   7   2614.0   8626.2  85㎡~ 102㎡
# 824   충남  2016   7   2749.0   9071.7      102㎡~
# 825   전북  2016   7   1929.0   6365.7         전체
# 826   전북  2016   7   1924.0   6349.2        60㎡
# 827   전북  2016   7   1936.0   6388.8   60㎡~ 85㎡
# 828   전북  2016   7   2290.0   7557.0  85㎡~ 102㎡
# 829   전북  2016   7   2323.0   7665.9      102㎡~
# 830   전남  2016   7   1968.0   6494.4         전체
# 831   전남  2016   7   1989.0   6563.7        60㎡
# 832   전남  2016   7   1965.0   6484.5   60㎡~ 85㎡
# 833   전남  2016   7   2364.0   7801.2  85㎡~ 102㎡
# 834   전남  2016   7   2264.0   7471.2      102㎡~
# 835   경북  2016   7   2248.0   7418.4         전체
# 836   경북  2016   7   2114.0   6976.2        60㎡
# 837   경북  2016   7   2265.0   7474.5   60㎡~ 85㎡
# 838   경북  2016   7   2675.0   8827.5  85㎡~ 102㎡
# 839   경북  2016   7   2526.0   8335.8      102㎡~
# 840   경남  2016   7   2375.0   7837.5         전체
# 841   경남  2016   7   2432.0   8025.6        60㎡
# 842   경남  2016   7   2370.0   7821.0   60㎡~ 85㎡
# 843   경남  2016   7   3052.0  10071.6  85㎡~ 102㎡
# 844   경남  2016   7   2740.0   9042.0      102㎡~
# 845   제주  2016   7   2827.0   9329.1         전체
# 846   제주  2016   7   2853.0   9414.9        60㎡
# 847   제주  2016   7   2730.0   9009.0   60㎡~ 85㎡
# 848   제주  2016   7   3107.0  10253.1  85㎡~ 102㎡
# 849   제주  2016   7   2605.0   8596.5      102㎡~
# 850   서울  2016   8   6285.0  20740.5         전체
# 851   서울  2016   8   6592.0  21753.6        60㎡
# 852   서울  2016   8   6424.0  21199.2   60㎡~ 85㎡
# 853   서울  2016   8   7270.0  23991.0  85㎡~ 102㎡
# 854   서울  2016   8   6603.0  21789.9      102㎡~
# 855   인천  2016   8   3235.0  10675.5         전체
# 856   인천  2016   8   3007.0   9923.1        60㎡
# 857   인천  2016   8   3289.0  10853.7   60㎡~ 85㎡
# 858   인천  2016   8   3454.0  11398.2  85㎡~ 102㎡
# 859   인천  2016   8   3632.0  11985.6      102㎡~
# 860   경기  2016   8   3561.0  11751.3         전체
# 861   경기  2016   8   3788.0  12500.4        60㎡
# 862   경기  2016   8   3552.0  11721.6   60㎡~ 85㎡
# 863   경기  2016   8   3303.0  10899.9  85㎡~ 102㎡
# 864   경기  2016   8   4046.0  13351.8      102㎡~
# 865   부산  2016   8   3185.0  10510.5         전체
# 866   부산  2016   8   3051.0  10068.3        60㎡
# 867   부산  2016   8   3101.0  10233.3   60㎡~ 85㎡
# 868   부산  2016   8   3383.0  11163.9  85㎡~ 102㎡
# 869   부산  2016   8   3874.0  12784.2      102㎡~
# 870   대구  2016   8   3147.0  10385.1         전체
# 871   대구  2016   8   3182.0  10500.6        60㎡
# 872   대구  2016   8   3154.0  10408.2   60㎡~ 85㎡
# 873   대구  2016   8   3045.0  10048.5  85㎡~ 102㎡
# 874   대구  2016   8   3045.0  10048.5      102㎡~
# 875   광주  2016   8   2726.0   8995.8         전체
# 876   광주  2016   8   2567.0   8471.1        60㎡
# 877   광주  2016   8   2728.0   9002.4   60㎡~ 85㎡
# 878   광주  2016   8   2754.0   9088.2  85㎡~ 102㎡
# 879   광주  2016   8   3518.0  11609.4      102㎡~
# 880   대전  2016   8   2562.0   8454.6         전체
# 881   대전  2016   8   2648.0   8738.4        60㎡
# 882   대전  2016   8   2547.0   8405.1   60㎡~ 85㎡
# 883   대전  2016   8      NaN      NaN  85㎡~ 102㎡
# 884   대전  2016   8      NaN      NaN      102㎡~
# 885   울산  2016   8   2976.0   9820.8         전체
# 886   울산  2016   8   2557.0   8438.1        60㎡
# 887   울산  2016   8   2990.0   9867.0   60㎡~ 85㎡
# 888   울산  2016   8   2663.0   8787.9  85㎡~ 102㎡
# 889   울산  2016   8   2967.0   9791.1      102㎡~
# 890   세종  2016   8   2694.0   8890.2         전체
# 891   세종  2016   8   2715.0   8959.5        60㎡
# 892   세종  2016   8   2735.0   9025.5   60㎡~ 85㎡
# 893   세종  2016   8   2664.0   8791.2  85㎡~ 102㎡
# 894   세종  2016   8   2585.0   8530.5      102㎡~
# 895   강원  2016   8   2098.0   6923.4         전체
# 896   강원  2016   8   2073.0   6840.9        60㎡
# 897   강원  2016   8   2132.0   7035.6   60㎡~ 85㎡
# 898   강원  2016   8      NaN      NaN  85㎡~ 102㎡
# 899   강원  2016   8   2402.0   7926.6      102㎡~
# 900   충북  2016   8   2124.0   7009.2         전체
# 901   충북  2016   8   2044.0   6745.2        60㎡
# 902   충북  2016   8   2149.0   7091.7   60㎡~ 85㎡
# 903   충북  2016   8   2321.0   7659.3  85㎡~ 102㎡
# 904   충북  2016   8   2243.0   7401.9      102㎡~
# 905   충남  2016   8   2235.0   7375.5         전체
# 906   충남  2016   8   2328.0   7682.4        60㎡
# 907   충남  2016   8   2225.0   7342.5   60㎡~ 85㎡
# 908   충남  2016   8   2614.0   8626.2  85㎡~ 102㎡
# 909   충남  2016   8   2765.0   9124.5      102㎡~
# 910   전북  2016   8   1929.0   6365.7         전체
# 911   전북  2016   8   1929.0   6365.7        60㎡
# 912   전북  2016   8   1936.0   6388.8   60㎡~ 85㎡
# 913   전북  2016   8   2290.0   7557.0  85㎡~ 102㎡
# 914   전북  2016   8   2323.0   7665.9      102㎡~
# 915   전남  2016   8   1966.0   6487.8         전체
# 916   전남  2016   8   1989.0   6563.7        60㎡
# 917   전남  2016   8   1963.0   6477.9   60㎡~ 85㎡
# 918   전남  2016   8   2364.0   7801.2  85㎡~ 102㎡
# 919   전남  2016   8   2264.0   7471.2      102㎡~
# 920   경북  2016   8   2238.0   7385.4         전체
# 921   경북  2016   8   2106.0   6949.8        60㎡
# 922   경북  2016   8   2248.0   7418.4   60㎡~ 85㎡
# 923   경북  2016   8   2630.0   8679.0  85㎡~ 102㎡
# 924   경북  2016   8   2576.0   8500.8      102㎡~
# 925   경남  2016   8   2384.0   7867.2         전체
# 926   경남  2016   8   2432.0   8025.6        60㎡
# 927   경남  2016   8   2381.0   7857.3   60㎡~ 85㎡
# 928   경남  2016   8   3028.0   9992.4  85㎡~ 102㎡
# 929   경남  2016   8   2759.0   9104.7      102㎡~
# 930   제주  2016   8   2878.0   9497.4         전체
# 931   제주  2016   8   2853.0   9414.9        60㎡
# 932   제주  2016   8   2768.0   9134.4   60㎡~ 85㎡
# 933   제주  2016   8   3107.0  10253.1  85㎡~ 102㎡
# 934   제주  2016   8   2605.0   8596.5      102㎡~
# 935   서울  2016   9   6283.0  20733.9         전체
# 936   서울  2016   9   6565.0  21664.5        60㎡
# 937   서울  2016   9   6412.0  21159.6   60㎡~ 85㎡
# 938   서울  2016   9   7415.0  24469.5  85㎡~ 102㎡
# 939   서울  2016   9   6571.0  21684.3      102㎡~
# 940   인천  2016   9   3168.0  10454.4         전체
# 941   인천  2016   9   3002.0   9906.6        60㎡
# 942   인천  2016   9   3121.0  10299.3   60㎡~ 85㎡
# 943   인천  2016   9   3366.0  11107.8  85㎡~ 102㎡
# 944   인천  2016   9   3632.0  11985.6      102㎡~
# 945   경기  2016   9   3360.0  11088.0         전체
# 946   경기  2016   9   3444.0  11365.2        60㎡
# 947   경기  2016   9   3316.0  10942.8   60㎡~ 85㎡
# 948   경기  2016   9   3280.0  10824.0  85㎡~ 102㎡
# 949   경기  2016   9   4079.0  13460.7      102㎡~
# 950   부산  2016   9   3200.0  10560.0         전체
# 951   부산  2016   9   3047.0  10055.1        60㎡
# 952   부산  2016   9   3107.0  10253.1   60㎡~ 85㎡
# 953   부산  2016   9   3383.0  11163.9  85㎡~ 102㎡
# 954   부산  2016   9   3874.0  12784.2      102㎡~
# 955   대구  2016   9   3147.0  10385.1         전체
# 956   대구  2016   9   3182.0  10500.6        60㎡
# 957   대구  2016   9   3154.0  10408.2   60㎡~ 85㎡
# 958   대구  2016   9   3045.0  10048.5  85㎡~ 102㎡
# 959   대구  2016   9   3045.0  10048.5      102㎡~
# 960   광주  2016   9   2721.0   8979.3         전체
# 961   광주  2016   9   2567.0   8471.1        60㎡
# 962   광주  2016   9   2724.0   8989.2   60㎡~ 85㎡
# 963   광주  2016   9   2754.0   9088.2  85㎡~ 102㎡
# 964   광주  2016   9   3087.0  10187.1      102㎡~
# 965   대전  2016   9   2517.0   8306.1         전체
# 966   대전  2016   9   2602.0   8586.6        60㎡
# 967   대전  2016   9   2492.0   8223.6   60㎡~ 85㎡
# 968   대전  2016   9      NaN      NaN  85㎡~ 102㎡
# 969   대전  2016   9      NaN      NaN      102㎡~
# 970   울산  2016   9   2976.0   9820.8         전체
# 971   울산  2016   9   2557.0   8438.1        60㎡
# 972   울산  2016   9   2990.0   9867.0   60㎡~ 85㎡
# 973   울산  2016   9   2663.0   8787.9  85㎡~ 102㎡
# 974   울산  2016   9   2967.0   9791.1      102㎡~
# 975   세종  2016   9   2689.0   8873.7         전체
# 976   세종  2016   9   2698.0   8903.4        60㎡
# 977   세종  2016   9   2738.0   9035.4   60㎡~ 85㎡
# 978   세종  2016   9   2665.0   8794.5  85㎡~ 102㎡
# 979   세종  2016   9   2638.0   8705.4      102㎡~
# 980   강원  2016   9   2100.0   6930.0         전체
# 981   강원  2016   9   2075.0   6847.5        60㎡
# 982   강원  2016   9   2135.0   7045.5   60㎡~ 85㎡
# 983   강원  2016   9      NaN      NaN  85㎡~ 102㎡
# 984   강원  2016   9   2380.0   7854.0      102㎡~
# 985   충북  2016   9   2125.0   7012.5         전체
# 986   충북  2016   9   2044.0   6745.2        60㎡
# 987   충북  2016   9   2153.0   7104.9   60㎡~ 85㎡
# 988   충북  2016   9   2321.0   7659.3  85㎡~ 102㎡
# 989   충북  2016   9   2243.0   7401.9      102㎡~
# 990   충남  2016   9   2236.0   7378.8         전체
# 991   충남  2016   9   2328.0   7682.4        60㎡
# 992   충남  2016   9   2225.0   7342.5   60㎡~ 85㎡
# 993   충남  2016   9   2614.0   8626.2  85㎡~ 102㎡
# 994   충남  2016   9   2765.0   9124.5      102㎡~
# 995   전북  2016   9   1925.0   6352.5         전체
# 996   전북  2016   9   1935.0   6385.5        60㎡
# 997   전북  2016   9   1930.0   6369.0   60㎡~ 85㎡
# 998   전북  2016   9   2297.0   7580.1  85㎡~ 102㎡
# ...
# 4002  인천  2019   9   3966.0  13087.8   60㎡~ 85㎡
# 4003  인천  2019   9   3773.0  12450.9  85㎡~ 102㎡
# 4004  인천  2019   9   5188.0  17120.4      102㎡~
# 4005  경기  2019   9   4441.0  14655.3         전체
# 4006  경기  2019   9   4818.0  15899.4        60㎡
# 4007  경기  2019   9   4428.0  14612.4   60㎡~ 85㎡
# 4008  경기  2019   9   5284.0  17437.2  85㎡~ 102㎡
# 4009  경기  2019   9   5371.0  17724.3      102㎡~
# 4010  부산  2019   9   4023.0  13275.9         전체
# 4011  부산  2019   9   3921.0  12939.3        60㎡
# 4012  부산  2019   9   4019.0  13262.7   60㎡~ 85㎡
# 4013  부산  2019   9   4420.0  14586.0  85㎡~ 102㎡
# 4014  부산  2019   9   4552.0  15021.6      102㎡~
# 4015  대구  2019   9   4358.0  14381.4         전체
# 4016  대구  2019   9   4354.0  14368.2        60㎡
# 4017  대구  2019   9   4334.0  14302.2   60㎡~ 85㎡
# 4018  대구  2019   9   4450.0  14685.0  85㎡~ 102㎡
# 4019  대구  2019   9   4881.0  16107.3      102㎡~
# 4020  광주  2019   9   3721.0  12279.3         전체
# 4021  광주  2019   9   3580.0  11814.0        60㎡
# 4022  광주  2019   9   3720.0  12276.0   60㎡~ 85㎡
# 4023  광주  2019   9      NaN      NaN  85㎡~ 102㎡
# 4024  광주  2019   9   4159.0  13724.7      102㎡~
# 4025  대전  2019   9   3442.0  11358.6         전체
# 4026  대전  2019   9   3611.0  11916.3        60㎡
# 4027  대전  2019   9   3369.0  11117.7   60㎡~ 85㎡
# 4028  대전  2019   9      NaN      NaN  85㎡~ 102㎡
# 4029  대전  2019   9   4500.0  14850.0      102㎡~
# 4030  울산  2019   9   2725.0   8992.5         전체
# 4031  울산  2019   9   2755.0   9091.5        60㎡
# 4032  울산  2019   9   2716.0   8962.8   60㎡~ 85㎡
# 4033  울산  2019   9      NaN      NaN  85㎡~ 102㎡
# 4034  울산  2019   9      NaN      NaN      102㎡~
# 4035  세종  2019   9   3458.0  11411.4         전체
# 4036  세종  2019   9      NaN      NaN        60㎡
# 4037  세종  2019   9   3395.0  11203.5   60㎡~ 85㎡
# 4038  세종  2019   9   3510.0  11583.0  85㎡~ 102㎡
# 4039  세종  2019   9   3931.0  12972.3      102㎡~
# 4040  강원  2019   9   2482.0   8190.6         전체
# 4041  강원  2019   9   2547.0   8405.1        60㎡
# 4042  강원  2019   9   2458.0   8111.4   60㎡~ 85㎡
# 4043  강원  2019   9   3329.0  10985.7  85㎡~ 102㎡
# 4044  강원  2019   9   3233.0  10668.9      102㎡~
# 4045  충북  2019   9   2263.0   7467.9         전체
# 4046  충북  2019   9   2303.0   7599.9        60㎡
# 4047  충북  2019   9   2284.0   7537.2   60㎡~ 85㎡
# 4048  충북  2019   9   2576.0   8500.8  85㎡~ 102㎡
# 4049  충북  2019   9   2532.0   8355.6      102㎡~
# 4050  충남  2019   9   2583.0   8523.9         전체
# 4051  충남  2019   9   2366.0   7807.8        60㎡
# 4052  충남  2019   9   2615.0   8629.5   60㎡~ 85㎡
# 4053  충남  2019   9      NaN      NaN  85㎡~ 102㎡
# 4054  충남  2019   9   2835.0   9355.5      102㎡~
# 4055  전북  2019   9   2630.0   8679.0         전체
# 4056  전북  2019   9   2348.0   7748.4        60㎡
# 4057  전북  2019   9   2630.0   8679.0   60㎡~ 85㎡
# 4058  전북  2019   9   2724.0   8989.2  85㎡~ 102㎡
# 4059  전북  2019   9   2698.0   8903.4      102㎡~
# 4060  전남  2019   9   2481.0   8187.3         전체
# 4061  전남  2019   9   2465.0   8134.5        60㎡
# 4062  전남  2019   9   2481.0   8187.3   60㎡~ 85㎡
# 4063  전남  2019   9   2337.0   7712.1  85㎡~ 102㎡
# 4064  전남  2019   9   3053.0  10074.9      102㎡~
# 4065  경북  2019   9   2658.0   8771.4         전체
# 4066  경북  2019   9   2578.0   8507.4        60㎡
# 4067  경북  2019   9   2638.0   8705.4   60㎡~ 85㎡
# 4068  경북  2019   9   2726.0   8995.8  85㎡~ 102㎡
# 4069  경북  2019   9   3362.0  11094.6      102㎡~
# 4070  경남  2019   9   2995.0   9883.5         전체
# 4071  경남  2019   9      NaN      NaN        60㎡
# 4072  경남  2019   9   2970.0   9801.0   60㎡~ 85㎡
# 4073  경남  2019   9   3211.0  10596.3  85㎡~ 102㎡
# 4074  경남  2019   9   4303.0  14199.9      102㎡~
# 4075  제주  2019   9   3869.0  12767.7         전체
# 4076  제주  2019   9   3804.0  12553.2        60㎡
# 4077  제주  2019   9   3884.0  12817.2   60㎡~ 85㎡
# 4078  제주  2019   9      NaN      NaN  85㎡~ 102㎡
# 4079  제주  2019   9   3601.0  11883.3      102㎡~
# 4080  서울  2019  10   8091.0  26700.3         전체
# 4081  서울  2019  10   8230.0  27159.0        60㎡
# 4082  서울  2019  10   8574.0  28294.2   60㎡~ 85㎡
# 4083  서울  2019  10  12728.0  42002.4  85㎡~ 102㎡
# 4084  서울  2019  10   8903.0  29379.9      102㎡~
# 4085  인천  2019  10   3947.0  13025.1         전체
# 4086  인천  2019  10   3866.0  12757.8        60㎡
# 4087  인천  2019  10   3956.0  13054.8   60㎡~ 85㎡
# 4088  인천  2019  10   3881.0  12807.3  85㎡~ 102㎡
# 4089  인천  2019  10   5185.0  17110.5      102㎡~
# 4090  경기  2019  10   4421.0  14589.3         전체
# 4091  경기  2019  10   4876.0  16090.8        60㎡
# 4092  경기  2019  10   4353.0  14364.9   60㎡~ 85㎡
# 4093  경기  2019  10   5284.0  17437.2  85㎡~ 102㎡
# 4094  경기  2019  10   5292.0  17463.6      102㎡~
# 4095  부산  2019  10   4040.0  13332.0         전체
# 4096  부산  2019  10   3860.0  12738.0        60㎡
# 4097  부산  2019  10   4056.0  13384.8   60㎡~ 85㎡
# 4098  부산  2019  10   4401.0  14523.3  85㎡~ 102㎡
# 4099  부산  2019  10   4433.0  14628.9      102㎡~
# 4100  대구  2019  10   4405.0  14536.5         전체
# 4101  대구  2019  10   4354.0  14368.2        60㎡
# 4102  대구  2019  10   4385.0  14470.5   60㎡~ 85㎡
# 4103  대구  2019  10   4450.0  14685.0  85㎡~ 102㎡
# 4104  대구  2019  10   4830.0  15939.0      102㎡~
# 4105  광주  2019  10   3771.0  12444.3         전체
# 4106  광주  2019  10   3647.0  12035.1        60㎡
# 4107  광주  2019  10   3771.0  12444.3   60㎡~ 85㎡
# 4108  광주  2019  10      NaN      NaN  85㎡~ 102㎡
# 4109  광주  2019  10   4159.0  13724.7      102㎡~
# 4110  대전  2019  10   3632.0  11985.6         전체
# 4111  대전  2019  10   3534.0  11662.2        60㎡
# 4112  대전  2019  10   3567.0  11771.1   60㎡~ 85㎡
# 4113  대전  2019  10      NaN      NaN  85㎡~ 102㎡
# 4114  대전  2019  10   4500.0  14850.0      102㎡~
# 4115  울산  2019  10   3140.0  10362.0         전체
# 4116  울산  2019  10   3399.0  11216.7        60㎡
# 4117  울산  2019  10   3110.0  10263.0   60㎡~ 85㎡
# 4118  울산  2019  10      NaN      NaN  85㎡~ 102㎡
# 4119  울산  2019  10      NaN      NaN      102㎡~
# 4120  세종  2019  10   3458.0  11411.4         전체
# 4121  세종  2019  10      NaN      NaN        60㎡
# 4122  세종  2019  10   3395.0  11203.5   60㎡~ 85㎡
# 4123  세종  2019  10   3510.0  11583.0  85㎡~ 102㎡
# 4124  세종  2019  10   3931.0  12972.3      102㎡~
# 4125  강원  2019  10   2460.0   8118.0         전체
# 4126  강원  2019  10   2563.0   8457.9        60㎡
# 4127  강원  2019  10   2442.0   8058.6   60㎡~ 85㎡
# 4128  강원  2019  10   3329.0  10985.7  85㎡~ 102㎡
# 4129  강원  2019  10   3233.0  10668.9      102㎡~
# 4130  충북  2019  10   2272.0   7497.6         전체
# 4131  충북  2019  10   2286.0   7543.8        60㎡
# 4132  충북  2019  10   2292.0   7563.6   60㎡~ 85㎡
# 4133  충북  2019  10   2634.0   8692.2  85㎡~ 102㎡
# 4134  충북  2019  10   2532.0   8355.6      102㎡~
# 4135  충남  2019  10   2602.0   8586.6         전체
# 4136  충남  2019  10   2332.0   7695.6        60㎡
# 4137  충남  2019  10   2629.0   8675.7   60㎡~ 85㎡
# 4138  충남  2019  10   3201.0  10563.3  85㎡~ 102㎡
# 4139  충남  2019  10   2835.0   9355.5      102㎡~
# 4140  전북  2019  10   2556.0   8434.8         전체
# 4141  전북  2019  10   2387.0   7877.1        60㎡
# 4142  전북  2019  10   2542.0   8388.6   60㎡~ 85㎡
# 4143  전북  2019  10   2764.0   9121.2  85㎡~ 102㎡
# 4144  전북  2019  10   2667.0   8801.1      102㎡~
# 4145  전남  2019  10   2494.0   8230.2         전체
# 4146  전남  2019  10   2465.0   8134.5        60㎡
# 4147  전남  2019  10   2494.0   8230.2   60㎡~ 85㎡
# 4148  전남  2019  10   2337.0   7712.1  85㎡~ 102㎡
# 4149  전남  2019  10   3053.0  10074.9      102㎡~
# 4150  경북  2019  10   2914.0   9616.2         전체
# 4151  경북  2019  10   2578.0   8507.4        60㎡
# 4152  경북  2019  10   2897.0   9560.1   60㎡~ 85㎡
# 4153  경북  2019  10   2604.0   8593.2  85㎡~ 102㎡
# 4154  경북  2019  10   3457.0  11408.1      102㎡~
# 4155  경남  2019  10   3209.0  10589.7         전체
# 4156  경남  2019  10      NaN      NaN        60㎡
# 4157  경남  2019  10   3176.0  10480.8   60㎡~ 85㎡
# 4158  경남  2019  10   3247.0  10715.1  85㎡~ 102㎡
# 4159  경남  2019  10   4303.0  14199.9      102㎡~
# 4160  제주  2019  10   3869.0  12767.7         전체
# 4161  제주  2019  10   3804.0  12553.2        60㎡
# 4162  제주  2019  10   3884.0  12817.2   60㎡~ 85㎡
# 4163  제주  2019  10      NaN      NaN  85㎡~ 102㎡
# 4164  제주  2019  10   3601.0  11883.3      102㎡~
# 4165  서울  2019  11   8062.0  26604.6         전체
# 4166  서울  2019  11   8196.0  27046.8        60㎡
# 4167  서울  2019  11   8300.0  27390.0   60㎡~ 85㎡
# 4168  서울  2019  11  12728.0  42002.4  85㎡~ 102㎡
# 4169  서울  2019  11   8952.0  29541.6      102㎡~
# 4170  인천  2019  11   3922.0  12942.6         전체
# 4171  인천  2019  11   3911.0  12906.3        60㎡
# 4172  인천  2019  11   3922.0  12942.6   60㎡~ 85㎡
# 4173  인천  2019  11   3904.0  12883.2  85㎡~ 102㎡
# 4174  인천  2019  11   4768.0  15734.4      102㎡~
# 4175  경기  2019  11   4453.0  14694.9         전체
# 4176  경기  2019  11   4885.0  16120.5        60㎡
# 4177  경기  2019  11   4341.0  14325.3   60㎡~ 85㎡
# 4178  경기  2019  11   5284.0  17437.2  85㎡~ 102㎡
# 4179  경기  2019  11   5342.0  17628.6      102㎡~
# 4180  부산  2019  11   3985.0  13150.5         전체
# 4181  부산  2019  11   3749.0  12371.7        60㎡
# 4182  부산  2019  11   4010.0  13233.0   60㎡~ 85㎡
# 4183  부산  2019  11   4401.0  14523.3  85㎡~ 102㎡
# 4184  부산  2019  11   4322.0  14262.6      102㎡~
# 4185  대구  2019  11   4382.0  14460.6         전체
# 4186  대구  2019  11   4364.0  14401.2        60㎡
# 4187  대구  2019  11   4369.0  14417.7   60㎡~ 85㎡
# 4188  대구  2019  11   4389.0  14483.7  85㎡~ 102㎡
# 4189  대구  2019  11   5158.0  17021.4      102㎡~
# 4190  광주  2019  11   3836.0  12658.8         전체
# 4191  광주  2019  11   3717.0  12266.1        60㎡
# 4192  광주  2019  11   3841.0  12675.3   60㎡~ 85㎡
# 4193  광주  2019  11      NaN      NaN  85㎡~ 102㎡
# 4194  광주  2019  11   4246.0  14011.8      102㎡~
# 4195  대전  2019  11   3632.0  11985.6         전체
# 4196  대전  2019  11   3534.0  11662.2        60㎡
# 4197  대전  2019  11   3567.0  11771.1   60㎡~ 85㎡
# 4198  대전  2019  11      NaN      NaN  85㎡~ 102㎡
# 4199  대전  2019  11   4500.0  14850.0      102㎡~
# 4200  울산  2019  11   3140.0  10362.0         전체
# 4201  울산  2019  11   3399.0  11216.7        60㎡
# 4202  울산  2019  11   3110.0  10263.0   60㎡~ 85㎡
# 4203  울산  2019  11      NaN      NaN  85㎡~ 102㎡
# 4204  울산  2019  11      NaN      NaN      102㎡~
# 4205  세종  2019  11   3458.0  11411.4         전체
# 4206  세종  2019  11      NaN      NaN        60㎡
# 4207  세종  2019  11   3395.0  11203.5   60㎡~ 85㎡
# 4208  세종  2019  11   3510.0  11583.0  85㎡~ 102㎡
# 4209  세종  2019  11   3931.0  12972.3      102㎡~
# 4210  강원  2019  11   2510.0   8283.0         전체
# 4211  강원  2019  11   2561.0   8451.3        60㎡
# 4212  강원  2019  11   2489.0   8213.7   60㎡~ 85㎡
# 4213  강원  2019  11   3329.0  10985.7  85㎡~ 102㎡
# 4214  강원  2019  11   3598.0  11873.4      102㎡~
# 4215  충북  2019  11   2303.0   7599.9         전체
# 4216  충북  2019  11   2324.0   7669.2        60㎡
# 4217  충북  2019  11   2293.0   7566.9   60㎡~ 85㎡
# 4218  충북  2019  11   2634.0   8692.2  85㎡~ 102㎡
# 4219  충북  2019  11   2532.0   8355.6      102㎡~
# 4220  충남  2019  11   2602.0   8586.6         전체
# 4221  충남  2019  11   2332.0   7695.6        60㎡
# 4222  충남  2019  11   2629.0   8675.7   60㎡~ 85㎡
# 4223  충남  2019  11   3201.0  10563.3  85㎡~ 102㎡
# 4224  충남  2019  11   2835.0   9355.5      102㎡~
# 4225  전북  2019  11   2468.0   8144.4         전체
# 4226  전북  2019  11   2526.0   8335.8        60㎡
# 4227  전북  2019  11   2458.0   8111.4   60㎡~ 85㎡
# 4228  전북  2019  11   2764.0   9121.2  85㎡~ 102㎡
# 4229  전북  2019  11   2667.0   8801.1      102㎡~
# 4230  전남  2019  11   2513.0   8292.9         전체
# 4231  전남  2019  11   2529.0   8345.7        60㎡
# 4232  전남  2019  11   2514.0   8296.2   60㎡~ 85㎡
# 4233  전남  2019  11      NaN      NaN  85㎡~ 102㎡
# 4234  전남  2019  11   3053.0  10074.9      102㎡~
# 4235  경북  2019  11   2914.0   9616.2         전체
# 4236  경북  2019  11   2578.0   8507.4        60㎡
# 4237  경북  2019  11   2897.0   9560.1   60㎡~ 85㎡
# 4238  경북  2019  11   2604.0   8593.2  85㎡~ 102㎡
# 4239  경북  2019  11   3457.0  11408.1      102㎡~
# 4240  경남  2019  11   3201.0  10563.3         전체
# 4241  경남  2019  11   2780.0   9174.0        60㎡
# 4242  경남  2019  11   3174.0  10474.2   60㎡~ 85㎡
# 4243  경남  2019  11   3247.0  10715.1  85㎡~ 102㎡
# 4244  경남  2019  11   4303.0  14199.9      102㎡~
# 4245  제주  2019  11   3882.0  12810.6         전체
# 4246  제주  2019  11      NaN      NaN        60㎡
# 4247  제주  2019  11   3898.0  12863.4   60㎡~ 85㎡
# 4248  제주  2019  11      NaN      NaN  85㎡~ 102㎡
# 4249  제주  2019  11   3601.0  11883.3      102㎡~
# 4250  서울  2019  12   7955.0  26251.5         전체
# 4251  서울  2019  12   8115.0  26779.5        60㎡
# 4252  서울  2019  12   8171.0  26964.3   60㎡~ 85㎡
# 4253  서울  2019  12  12728.0  42002.4  85㎡~ 102㎡
# 4254  서울  2019  12   8989.0  29663.7      102㎡~
# 4255  인천  2019  12   4002.0  13206.6         전체
# 4256  인천  2019  12   3993.0  13176.9        60㎡
# 4257  인천  2019  12   3989.0  13163.7   60㎡~ 85㎡
# 4258  인천  2019  12   3981.0  13137.3  85㎡~ 102㎡
# 4259  인천  2019  12   4768.0  15734.4      102㎡~
# 4260  경기  2019  12   4493.0  14826.9         전체
# 4261  경기  2019  12   4931.0  16272.3        60㎡
# 4262  경기  2019  12   4390.0  14487.0   60㎡~ 85㎡
# 4263  경기  2019  12   5438.0  17945.4  85㎡~ 102㎡
# 4264  경기  2019  12   5180.0  17094.0      102㎡~
# 4265  부산  2019  12   3884.0  12817.2         전체
# 4266  부산  2019  12   3711.0  12246.3        60㎡
# 4267  부산  2019  12   3907.0  12893.1   60㎡~ 85㎡
# 4268  부산  2019  12   4401.0  14523.3  85㎡~ 102㎡
# 4269  부산  2019  12   4322.0  14262.6      102㎡~
# 4270  대구  2019  12   4372.0  14427.6         전체
# 4271  대구  2019  12   4314.0  14236.2        60㎡
# 4272  대구  2019  12   4367.0  14411.1   60㎡~ 85㎡
# 4273  대구  2019  12   4414.0  14566.2  85㎡~ 102㎡
# 4274  대구  2019  12   5130.0  16929.0      102㎡~
# 4275  광주  2019  12   3834.0  12652.2         전체
# 4276  광주  2019  12   3926.0  12955.8        60㎡
# 4277  광주  2019  12   3852.0  12711.6   60㎡~ 85㎡
# 4278  광주  2019  12      NaN      NaN  85㎡~ 102㎡
# 4279  광주  2019  12   4310.0  14223.0      102㎡~
# 4280  대전  2019  12   3632.0  11985.6         전체
# 4281  대전  2019  12   3534.0  11662.2        60㎡
# 4282  대전  2019  12   3567.0  11771.1   60㎡~ 85㎡
# 4283  대전  2019  12      NaN      NaN  85㎡~ 102㎡
# 4284  대전  2019  12   4500.0  14850.0      102㎡~
# 4285  울산  2019  12   3143.0  10371.9         전체
# 4286  울산  2019  12   3399.0  11216.7        60㎡
# 4287  울산  2019  12   3114.0  10276.2   60㎡~ 85㎡
# 4288  울산  2019  12      NaN      NaN  85㎡~ 102㎡
# 4289  울산  2019  12      NaN      NaN      102㎡~
# 4290  세종  2019  12   3458.0  11411.4         전체
# 4291  세종  2019  12      NaN      NaN        60㎡
# 4292  세종  2019  12   3395.0  11203.5   60㎡~ 85㎡
# 4293  세종  2019  12   3510.0  11583.0  85㎡~ 102㎡
# 4294  세종  2019  12   3931.0  12972.3      102㎡~
# 4295  강원  2019  12   2510.0   8283.0         전체
# 4296  강원  2019  12   2561.0   8451.3        60㎡
# 4297  강원  2019  12   2489.0   8213.7   60㎡~ 85㎡
# 4298  강원  2019  12   3329.0  10985.7  85㎡~ 102㎡
# 4299  강원  2019  12   3598.0  11873.4      102㎡~
# 4300  충북  2019  12   2305.0   7606.5         전체
# 4301  충북  2019  12   2324.0   7669.2        60㎡
# 4302  충북  2019  12   2297.0   7580.1   60㎡~ 85㎡
# 4303  충북  2019  12   2634.0   8692.2  85㎡~ 102㎡
# 4304  충북  2019  12   2532.0   8355.6      102㎡~
# 4305  충남  2019  12   2640.0   8712.0         전체
# 4306  충남  2019  12   2382.0   7860.6        60㎡
# 4307  충남  2019  12   2666.0   8797.8   60㎡~ 85㎡
# 4308  충남  2019  12   3201.0  10563.3  85㎡~ 102㎡
# 4309  충남  2019  12   2835.0   9355.5      102㎡~
# 4310  전북  2019  12   2468.0   8144.4         전체
# 4311  전북  2019  12   2526.0   8335.8        60㎡
# 4312  전북  2019  12   2458.0   8111.4   60㎡~ 85㎡
# 4313  전북  2019  12   2764.0   9121.2  85㎡~ 102㎡
# 4314  전북  2019  12   2667.0   8801.1      102㎡~
# 4315  전남  2019  12   2452.0   8091.6         전체
# 4316  전남  2019  12   2529.0   8345.7        60㎡
# 4317  전남  2019  12   2452.0   8091.6   60㎡~ 85㎡
# 4318  전남  2019  12      NaN      NaN  85㎡~ 102㎡
# 4319  전남  2019  12   3053.0  10074.9      102㎡~
# 4320  경북  2019  12   2914.0   9616.2         전체
# 4321  경북  2019  12   2578.0   8507.4        60㎡
# 4322  경북  2019  12   2897.0   9560.1   60㎡~ 85㎡
# 4323  경북  2019  12   2604.0   8593.2  85㎡~ 102㎡
# 4324  경북  2019  12   3457.0  11408.1      102㎡~
# 4325  경남  2019  12   3063.0  10107.9         전체
# 4326  경남  2019  12   2780.0   9174.0        60㎡
# 4327  경남  2019  12   3065.0  10114.5   60㎡~ 85㎡
# 4328  경남  2019  12   3247.0  10715.1  85㎡~ 102㎡
# 4329  경남  2019  12      NaN      NaN      102㎡~
# 4330  제주  2019  12   3882.0  12810.6         전체
# 4331  제주  2019  12      NaN      NaN        60㎡
# 4332  제주  2019  12   3898.0  12863.4   60㎡~ 85㎡
# 4333  제주  2019  12      NaN      NaN  85㎡~ 102㎡
# 4334  제주  2019  12   3601.0  11883.3      102㎡~

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10) ## max_rows는 10보다 큰 값을 해도 더 이상 늘어나거나 그렇지 않음

# %%
first_df
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  ...  2015년4월  2015년5월  2015년6월
# 0   서울     18189    17925    17925    18016  ...    18842    18367    18374  \
# 1   부산      8111     8111     9078     8965  ...     9327     9345     9515
# 2   대구      8080     8080     8077     8101  ...     8446     8568     8542
# 3   인천     10204    10204    10408    10408  ...     9938    10551    10443
# 4   광주      6098     7326     7611     7346  ...     7914     7877     7881
# ..  ..       ...      ...      ...      ...  ...      ...      ...      ...
# 12  전북      6282     6281     5946     5966  ...     6551     6556     6601
# 13  전남      5678     5678     5678     5696  ...     5940     6050     6243
# 14  경북      6168     6168     6234     6317  ...     7006     6966     6887
# 15  경남      6473     6485     6502     6610  ...     7683     7717     7715
# 16  제주      7674     7900     7900     7900  ...     7285     7285     7343
#
#     2015년7월  2015년8월
# 0     18152    18443
# 1      9559     9581
# 2      8542     8795
# 3     10443    10449
# 4      8089     8231
# ..      ...      ...
# 12     6750     6580
# 13     6286     6289
# 14     7035     7037
# 15     7723     7665
# 16     7343     7343
#
# [17 rows x 22 columns]

# %%
last_df
# Out:
#      지역명    연도   월    분양가격   평당분양가격       전용면적
# 0     서울  2015  10  5841.0  19275.3         전체
# 1     서울  2015  10  5652.0  18651.6        60㎡
# 2     서울  2015  10  5882.0  19410.6   60㎡~ 85㎡
# 3     서울  2015  10  5721.0  18879.3  85㎡~ 102㎡
# 4     서울  2015  10  5879.0  19400.7      102㎡~
# ...   ..   ...  ..     ...      ...        ...
# 4330  제주  2019  12  3882.0  12810.6         전체
# 4331  제주  2019  12     NaN      NaN        60㎡
# 4332  제주  2019  12  3898.0  12863.4   60㎡~ 85㎡
# 4333  제주  2019  12     NaN      NaN  85㎡~ 102㎡
# 4334  제주  2019  12  3601.0  11883.3      102㎡~
#
# [4335 rows x 6 columns]

# %%
first_df.head(2)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  ...  2015년4월  2015년5월  2015년6월
# 0  서울     18189    17925    17925    18016  ...    18842    18367    18374  \
# 1  부산      8111     8111     9078     8965  ...     9327     9345     9515
#
#    2015년7월  2015년8월
# 0    18152    18443
# 1     9559     9581
#
# [2 rows x 22 columns]

# %%
last_df.head(2)
# Out:
#   지역명    연도   월    분양가격   평당분양가격 전용면적
# 0  서울  2015  10  5841.0  19275.3   전체
# 1  서울  2015  10  5652.0  18651.6  60㎡

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     4335 non-null   object
#  1   연도      4335 non-null   int64
#  2   월       4335 non-null   int64
#  3   분양가격    3957 non-null   float64
#  4   평당분양가격  3957 non-null   float64
#  5   전용면적    4335 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 203.3+ KB

# %%
# melt를 이용해서 월별데이터를 '기간' 컬럼으로 가격은 '평당분양가격'으로 처리하여 first_df_melt로 저장

# %%
first_df_melt = first_df.melt( id_vars='지역',
                               var_name='기간',
                               value_name='평당분양가격')
first_df_melt.head(3)
# Out:
#    지역        기간  평당분양가격
# 0  서울  2013년12월   18189
# 1  부산  2013년12월    8111
# 2  대구  2013년12월    8080

# %%
first_df_melt['기간'].str.split('년')
# Out:
# 0      [2013, 12월]
# 1      [2013, 12월]
# 2      [2013, 12월]
# 3      [2013, 12월]
# 4      [2013, 12월]
#           ...
# 352     [2015, 8월]
# 353     [2015, 8월]
# 354     [2015, 8월]
# 355     [2015, 8월]
# 356     [2015, 8월]
# Name: 기간, Length: 357, dtype: object

# %%
# 기간 컬럼을 연도, 월 컬럼으로 분리

# %%
first_df_melt['연도'] = first_df_melt['기간'].str.split('년').str[0].astype(int)
first_df_melt['월'] = first_df_melt['기간'].str.split('년').str[1].str.replace('월','').astype(int)

# %%
first_df_melt.head(3)
# Out:
#    지역        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12
# 1  부산  2013년12월    8111  2013  12
# 2  대구  2013년12월    8080  2013  12

# %%
first_df_melt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      357 non-null    object
#  1   기간      357 non-null    object
#  2   평당분양가격  357 non-null    int64
#  3   연도      357 non-null    int32
#  4   월       357 non-null    int32
# dtypes: int32(2), int64(1), object(2)
# memory usage: 11.3+ KB

# %%
## last_df 전용면적에서 전체 인 데이터만 last_df_prepare로 저장

# %%
last_df_prepare = last_df[last_df['전용면적']=='전체'].copy()    ## copy()는 무조건 복사 // 본래 데이터가 수정되는것을 방지

# %%
last_df_prepare.head(2)
# Out:
#   지역명    연도   월    분양가격   평당분양가격 전용면적
# 0  서울  2015  10  5841.0  19275.3   전체
# 5  인천  2015  10  3163.0  10437.9   전체

# %%
first_df_melt.head(2)
# Out:
#    지역        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12
# 1  부산  2013년12월    8111  2013  12

# %%
## 지역명 -> 지역 컬럼으로 변경

# %%
last_df_prepare.columns
# Out:
# Index(['지역명', '연도', '월', '분양가격', '평당분양가격', '전용면적'], dtype='object')

# %%
last_df_prepare.rename(columns={'지역명':'지역'}, inplace=True)

# %%
last_df_prepare.head(2)
# Out:
#    지역    연도   월    분양가격   평당분양가격 전용면적
# 0  서울  2015  10  5841.0  19275.3   전체
# 5  인천  2015  10  3163.0  10437.9   전체

# %%
## concat으로 데이터 합치기

# %%
first = first_df_melt[['지역', '연도', '월', '평당분양가격']]
last = last_df_prepare[['지역', '연도', '월', '평당분양가격']]
df = pd.concat([first, last])
df.reset_index(drop=True, inplace=True)
df
# Out:
#       지역    연도   월   평당분양가격
# 0     서울  2013  12  18189.0
# 1     부산  2013  12   8111.0
# 2     대구  2013  12   8080.0
# 3     인천  2013  12  10204.0
# 4     광주  2013  12   6098.0
# ...   ..   ...  ..      ...
# 1219  전북  2019  12   8144.4
# 1220  전남  2019  12   8091.6
# 1221  경북  2019  12   9616.2
# 1222  경남  2019  12  10107.9
# 1223  제주  2019  12  12810.6
#
# [1224 rows x 4 columns]

# %%
df.groupby(['연도','월'])['평당분양가격'].mean().to_frame()
# Out:
#                평당분양가격
# 연도   월
# 2013 12   8059.294118
# 2014 1    8129.882353
#      2    8194.882353
#      3    8204.117647
#      4    8289.294118
# ...               ...
# 2019 8   11758.312500
#      9   11677.147059
#      10  11895.723529
#      11  11892.229412
#      12  11842.535294
#
# [72 rows x 1 columns]

# %%
df.groupby(['연도','월'])['평당분양가격'].mean().to_frame().reset_index()
# Out:
#       연도   월        평당분양가격
# 0   2013  12   8059.294118
# 1   2014   1   8129.882353
# 2   2014   2   8194.882353
# 3   2014   3   8204.117647
# 4   2014   4   8289.294118
# ..   ...  ..           ...
# 67  2019   8  11758.312500
# 68  2019   9  11677.147059
# 69  2019  10  11895.723529
# 70  2019  11  11892.229412
# 71  2019  12  11842.535294
#
# [72 rows x 3 columns]
